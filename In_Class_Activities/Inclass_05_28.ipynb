# %% [markdown]
# # Day 2 RNN

# %% [markdown]
# ### Importing libraries

# %%
# Libraries

import random

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

import tensorflow as tf

from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_absolute_error, mean_squared_error

from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, SimpleRNN, LSTM, GRU
from tensorflow.keras.callbacks import EarlyStopping

random.seed(42)
np.random.seed(42)
tf.random.set_seed(42)

# %% [markdown]
# ### Load & inspect data

# %%
# Load and inspect Bitcoin data

bitcoin = pd.read_csv("../datasets/dc.csv")

bitcoin = bitcoin.rename(
    columns={"Unnamed: 0": "date"}
)

bitcoin["date"] = pd.to_datetime(bitcoin["date"])

bitcoin = (
    bitcoin
    .sort_values("date")
    .reset_index(drop=True)
)

print(bitcoin.shape)

bitcoin.head()
# Out:
# (1000, 6)
#         date  open_USD  high_USD  low_USD  close_USD  volume
# 0 2018-05-07   9661.02   9689.67  9181.00    9365.00   33787
# 1 2018-05-08   9365.00   9475.70  9060.54    9187.56   25533
# 2 2018-05-09   9178.00   9390.00  8965.00    9310.00   25673
# 3 2018-05-10   9310.00   9395.12  8970.00    9002.20   25055
# 4 2018-05-11   9002.21   9016.80  8341.00    8400.00   48227

# %%
# Basic inspection

bitcoin.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 6 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   date       1000 non-null   datetime64[us]
#  1   open_USD   1000 non-null   float64
#  2   high_USD   1000 non-null   float64
#  3   low_USD    1000 non-null   float64
#  4   close_USD  1000 non-null   float64
#  5   volume     1000 non-null   int64
# dtypes: datetime64[us](1), float64(4), int64(1)
# memory usage: 47.0 KB

# %%
# Summary statistics

bitcoin.describe()
# Out:
#                       date      open_USD      high_USD       low_USD  \
# count                 1000   1000.000000   1000.000000   1000.000000
# mean   2019-09-18 12:00:00   9285.762120   9542.880270   9011.393200
# min    2018-05-07 00:00:00   3211.710000   3276.500000   3156.260000
# 25%    2019-01-11 18:00:00   6467.192500   6582.255000   6325.015000
# 50%    2019-09-18 12:00:00   8189.695000   8351.630000   8002.045000
# 75%    2020-05-25 06:00:00  10216.860000  10419.562500   9907.977500
# max    2021-01-30 00:00:00  40586.960000  41950.000000  38720.000000
# std                    NaN   5793.522832   6075.604427   5483.524463
#
#           close_USD         volume
# count   1000.000000    1000.000000
# mean    9310.335850   53100.498000
# min     3211.720000    5743.000000
# 25%     6466.762500   30045.750000
# 50%     8189.330000   43795.500000
# 75%    10220.170000   64909.250000
# max    40582.810000  402201.000000
# std     5846.917681   35329.832031

# %% [markdown]
# Visualizing the target variable

# %%
# Visualize closing price over time

plt.figure(figsize=(10, 4))

plt.plot(
    bitcoin["date"],
    bitcoin["close_USD"]
)

plt.title("Bitcoin Closing Price Over Time")
plt.xlabel("Date")
plt.ylabel("Close Price (USD)")

plt.ticklabel_format(
    style="plain",
    axis="y"
)

plt.xticks(rotation=45)

plt.show()

# %% [markdown]
# ### Preparing data for recurrent modeling

# %%
# Prepare Bitcoin data for recurrent models

features = [
    "open_USD",
    "high_USD",
    "low_USD",
    "close_USD",
    "volume"
]

target_col = "close_USD"

bitcoin_model = bitcoin[["date"] + features].copy()

print("Unique dates:", bitcoin_model["date"].nunique())
print("Rows:", len(bitcoin_model))

scaler_bitcoin = MinMaxScaler(feature_range=(0, 1))

scaled_features = scaler_bitcoin.fit_transform(
    bitcoin_model[features]
)

look_back = 10                                                  # use 10 previous days to predict next close

target_index = features.index(target_col)
# Out:
# Unique dates: 1000
# Rows: 1000

# %% [markdown]
# ### Useful functions

# %%
# Function to create recurrent sequence windows

def create_sequences(dataset, target_index, look_back=10):

    X, y = [], []

    for i in range(len(dataset) - look_back):

        X.append(
            dataset[i:i + look_back, :]
        )                                                       # previous look_back days

        y.append(
            dataset[i + look_back, target_index]
        )                                                       # next day's close_USD

    return np.array(X), np.array(y)

# %%
# Function to visualize training curves

def plot_training_curves(history, title):

    fig, axes = plt.subplots(1, 2, figsize=(12, 4))

    # Loss
    axes[0].plot(
        history.history["loss"],
        label="Training Loss"
    )

    axes[0].plot(
        history.history["val_loss"],
        label="Validation Loss"
    )

    axes[0].set_title(title + " Loss")
    axes[0].set_xlabel("Epoch")
    axes[0].set_ylabel("MSE Loss")

    axes[0].legend()

    # MAE
    axes[1].plot(
        history.history["mean_absolute_error"],
        label="Training MAE"
    )

    axes[1].plot(
        history.history["val_mean_absolute_error"],
        label="Validation MAE"
    )

    axes[1].set_title(title + " MAE")
    axes[1].set_xlabel("Epoch")
    axes[1].set_ylabel("Mean Absolute Error")

    axes[1].legend()

    plt.tight_layout()

    plt.show()

# %%
# Function to evaluate forecasting performance

def evaluate_and_plot(
    model,
    trainX,
    testX,
    trainY,
    testY,
    scaler,
    target_index,
    title
):

    # Predictions
    train_pred = model.predict(trainX)
    test_pred = model.predict(testX)

    # Create arrays for inverse scaling
    train_dummy = np.zeros((len(train_pred), len(features)))
    test_dummy = np.zeros((len(test_pred), len(features)))

    train_dummy[:, target_index] = train_pred.flatten()
    test_dummy[:, target_index] = test_pred.flatten()

    trainY_dummy = np.zeros((len(trainY), len(features)))
    testY_dummy = np.zeros((len(testY), len(features)))

    trainY_dummy[:, target_index] = trainY
    testY_dummy[:, target_index] = testY

    # Inverse transform
    train_pred_inv = scaler.inverse_transform(train_dummy)[:, target_index]
    test_pred_inv = scaler.inverse_transform(test_dummy)[:, target_index]

    trainY_inv = scaler.inverse_transform(trainY_dummy)[:, target_index]
    testY_inv = scaler.inverse_transform(testY_dummy)[:, target_index]

    # Metrics
    train_rmse = np.sqrt(mean_squared_error(trainY_inv, train_pred_inv))
    test_rmse = np.sqrt(mean_squared_error(testY_inv, test_pred_inv))

    train_mae = mean_absolute_error(trainY_inv, train_pred_inv)
    test_mae = mean_absolute_error(testY_inv, test_pred_inv)

    print(f"{title} Train RMSE: {train_rmse:.2f}")
    print(f"{title} Test RMSE: {test_rmse:.2f}")

    print(f"{title} Train MAE: {train_mae:.2f}")
    print(f"{title} Test MAE: {test_mae:.2f}")

    # Plot predictions
    plt.figure(figsize=(10, 4))

    plt.plot(
        testY_inv,
        label="Actual"
    )

    plt.plot(
        test_pred_inv,
        label="Predicted"
    )

    plt.title(title + " Test Predictions")

    plt.xlabel("Test time index")
    plt.ylabel("Bitcoin Close Price (USD)")

    plt.ticklabel_format(
        style="plain",
        axis="y"
    )

    plt.legend()

    plt.show()

# %%
# Function to compare model metrics

def evaluate_metrics(
    model,
    testX,
    testY,
    scaler,
    target_index
):

    test_pred = model.predict(testX)

    test_dummy = np.zeros((len(test_pred), len(features)))
    test_dummy[:, target_index] = test_pred.flatten()

    testY_dummy = np.zeros((len(testY), len(features)))
    testY_dummy[:, target_index] = testY

    test_pred_inv = scaler.inverse_transform(test_dummy)[:, target_index]
    testY_inv = scaler.inverse_transform(testY_dummy)[:, target_index]

    rmse = np.sqrt(mean_squared_error(testY_inv, test_pred_inv))
    mae = mean_absolute_error(testY_inv, test_pred_inv)

    return rmse, mae

# %% [markdown]
# ### Creating train/test recurrent tensors

# %%
# Create train/test recurrent tensors

train_size = int(len(scaled_features) * 0.8)                    # chronological 80/20 split

train_bitcoin = scaled_features[:train_size]                    # earlier data
test_bitcoin = scaled_features[train_size:]                     # held-out future data

trainX_bitcoin, trainY_bitcoin = create_sequences(
    train_bitcoin,
    target_index,
    look_back
)

testX_bitcoin, testY_bitcoin = create_sequences(
    test_bitcoin,
    target_index,
    look_back
)

print("trainX_bitcoin shape:", trainX_bitcoin.shape)
print("testX_bitcoin shape:", testX_bitcoin.shape)
print("trainY_bitcoin shape:", trainY_bitcoin.shape)
print("testY_bitcoin shape:", testY_bitcoin.shape)
# Out:
# trainX_bitcoin shape: (790, 10, 5)
# testX_bitcoin shape: (190, 10, 5)
# trainY_bitcoin shape: (790,)
# testY_bitcoin shape: (190,)

# %% [markdown]
# ### Baseline SimpleRNN model

# %%
# Build and train baseline SimpleRNN model

simple_rnn_model = Sequential([
    SimpleRNN(
        8,                                     # small baseline recurrent layer
        activation="tanh",                     # standard activation for SimpleRNN
        input_shape=(look_back, trainX_bitcoin.shape[2])
    ),                                         # input shape = timesteps, features

    Dense(1)                                   # output layer: predict next close_USD value
])

simple_rnn_model.compile(
    optimizer="adam",                          # adaptive gradient-based optimizer
    loss="mean_squared_error",                 # regression loss
    metrics=["mean_absolute_error"]            # easier-to-interpret training metric
)

simple_rnn_history = simple_rnn_model.fit(
    trainX_bitcoin,
    trainY_bitcoin,
    epochs=50,                                 # baseline training limit
    batch_size=16,                             # update weights after each batch
    validation_split=0.2,                      # last 20% of training data used for validation
    shuffle=False,                             # preserve chronological order
    verbose=1
)
# Out:
# c:\Users\tyler\anaconda3\Lib\site-packages\keras\src\layers\rnn\rnn.py:199: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Epoch 1/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 2s 11ms/step - loss: 0.0108 - mean_absolute_error: 0.0820 - val_loss: 0.0113 - val_mean_absolute_error: 0.0747
# Epoch 2/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0041 - mean_absolute_error: 0.0477 - val_loss: 0.0080 - val_mean_absolute_error: 0.0571
# Epoch 3/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0029 - mean_absolute_error: 0.0402 - val_loss: 0.0062 - val_mean_absolute_error: 0.0496
# Epoch 4/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0022 - mean_absolute_error: 0.0343 - val_loss: 0.0049 - val_mean_absolute_error: 0.0438
# Epoch 5/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0018 - mean_absolute_error: 0.0304 - val_loss: 0.0039 - val_mean_absolute_error: 0.0391
# Epoch 6/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0015 - mean_absolute_error: 0.0279 - val_loss: 0.0032 - val_mean_absolute_error: 0.0353
# Epoch 7/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0013 - mean_absolute_error: 0.0259 - val_loss: 0.0026 - val_mean_absolute_error: 0.0323
# Epoch 8/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0011 - mean_absolute_error: 0.0242 - val_loss: 0.0022 - val_mean_absolute_error: 0.0299
# Epoch 9/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 9.6651e-04 - mean_absolute_error: 0.0227 - val_loss: 0.0019 - val_mean_absolute_error: 0.0280
# Epoch 10/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 8.5578e-04 - mean_absolute_error: 0.0214 - val_loss: 0.0016 - val_mean_absolute_error: 0.0264
# Epoch 11/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 7.6079e-04 - mean_absolute_error: 0.0202 - val_loss: 0.0014 - val_mean_absolute_error: 0.0250
# Epoch 12/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 6.7854e-04 - mean_absolute_error: 0.0191 - val_loss: 0.0013 - val_mean_absolute_error: 0.0239
# Epoch 13/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 6.0700e-04 - mean_absolute_error: 0.0181 - val_loss: 0.0012 - val_mean_absolute_error: 0.0228
# Epoch 14/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 5.4465e-04 - mean_absolute_error: 0.0172 - val_loss: 0.0010 - val_mean_absolute_error: 0.0218
# Epoch 15/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.9029e-04 - mean_absolute_error: 0.0163 - val_loss: 9.4630e-04 - val_mean_absolute_error: 0.0208
# Epoch 16/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 4.4292e-04 - mean_absolute_error: 0.0155 - val_loss: 8.6039e-04 - val_mean_absolute_error: 0.0199
# Epoch 17/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.0168e-04 - mean_absolute_error: 0.0148 - val_loss: 7.8424e-04 - val_mean_absolute_error: 0.0190
# Epoch 18/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.6580e-04 - mean_absolute_error: 0.0141 - val_loss: 7.1639e-04 - val_mean_absolute_error: 0.0182
# Epoch 19/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 3.3461e-04 - mean_absolute_error: 0.0135 - val_loss: 6.5576e-04 - val_mean_absolute_error: 0.0174
# Epoch 20/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.0751e-04 - mean_absolute_error: 0.0130 - val_loss: 6.0155e-04 - val_mean_absolute_error: 0.0166
# Epoch 21/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.8395e-04 - mean_absolute_error: 0.0125 - val_loss: 5.5307e-04 - val_mean_absolute_error: 0.0159
# Epoch 22/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.6346e-04 - mean_absolute_error: 0.0121 - val_loss: 5.0976e-04 - val_mean_absolute_error: 0.0153
# Epoch 23/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.4563e-04 - mean_absolute_error: 0.0116 - val_loss: 4.7113e-04 - val_mean_absolute_error: 0.0147
# Epoch 24/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.3011e-04 - mean_absolute_error: 0.0113 - val_loss: 4.3671e-04 - val_mean_absolute_error: 0.0142
# Epoch 25/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.1657e-04 - mean_absolute_error: 0.0109 - val_loss: 4.0609e-04 - val_mean_absolute_error: 0.0137
# Epoch 26/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.0475e-04 - mean_absolute_error: 0.0106 - val_loss: 3.7890e-04 - val_mean_absolute_error: 0.0133
# Epoch 27/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.9443e-04 - mean_absolute_error: 0.0104 - val_loss: 3.5479e-04 - val_mean_absolute_error: 0.0129
# Epoch 28/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.8540e-04 - mean_absolute_error: 0.0101 - val_loss: 3.3342e-04 - val_mean_absolute_error: 0.0125
# Epoch 29/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.7750e-04 - mean_absolute_error: 0.0099 - val_loss: 3.1452e-04 - val_mean_absolute_error: 0.0122
# Epoch 30/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.7058e-04 - mean_absolute_error: 0.0097 - val_loss: 2.9782e-04 - val_mean_absolute_error: 0.0118
# Epoch 31/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.6452e-04 - mean_absolute_error: 0.0095 - val_loss: 2.8306e-04 - val_mean_absolute_error: 0.0115
# Epoch 32/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.5921e-04 - mean_absolute_error: 0.0093 - val_loss: 2.7003e-04 - val_mean_absolute_error: 0.0113
# Epoch 33/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.5456e-04 - mean_absolute_error: 0.0091 - val_loss: 2.5853e-04 - val_mean_absolute_error: 0.0110
# Epoch 34/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.5048e-04 - mean_absolute_error: 0.0090 - val_loss: 2.4838e-04 - val_mean_absolute_error: 0.0108
# Epoch 35/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.4691e-04 - mean_absolute_error: 0.0089 - val_loss: 2.3943e-04 - val_mean_absolute_error: 0.0106
# Epoch 36/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.4377e-04 - mean_absolute_error: 0.0087 - val_loss: 2.3152e-04 - val_mean_absolute_error: 0.0104
# Epoch 37/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.4101e-04 - mean_absolute_error: 0.0086 - val_loss: 2.2454e-04 - val_mean_absolute_error: 0.0102
# Epoch 38/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.3859e-04 - mean_absolute_error: 0.0085 - val_loss: 2.1838e-04 - val_mean_absolute_error: 0.0100
# Epoch 39/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.3646e-04 - mean_absolute_error: 0.0085 - val_loss: 2.1293e-04 - val_mean_absolute_error: 0.0099
# Epoch 40/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.3457e-04 - mean_absolute_error: 0.0084 - val_loss: 2.0810e-04 - val_mean_absolute_error: 0.0098
# Epoch 41/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.3290e-04 - mean_absolute_error: 0.0083 - val_loss: 2.0383e-04 - val_mean_absolute_error: 0.0097
# Epoch 42/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.3141e-04 - mean_absolute_error: 0.0083 - val_loss: 2.0004e-04 - val_mean_absolute_error: 0.0096
# Epoch 43/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.3007e-04 - mean_absolute_error: 0.0082 - val_loss: 1.9668e-04 - val_mean_absolute_error: 0.0095
# Epoch 44/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.2886e-04 - mean_absolute_error: 0.0082 - val_loss: 1.9370e-04 - val_mean_absolute_error: 0.0094
# Epoch 45/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.2777e-04 - mean_absolute_error: 0.0081 - val_loss: 1.9105e-04 - val_mean_absolute_error: 0.0094
# Epoch 46/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.2677e-04 - mean_absolute_error: 0.0081 - val_loss: 1.8868e-04 - val_mean_absolute_error: 0.0093
# Epoch 47/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.2584e-04 - mean_absolute_error: 0.0080 - val_loss: 1.8659e-04 - val_mean_absolute_error: 0.0093
# Epoch 48/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.2498e-04 - mean_absolute_error: 0.0080 - val_loss: 1.8472e-04 - val_mean_absolute_error: 0.0092
# Epoch 49/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.2417e-04 - mean_absolute_error: 0.0080 - val_loss: 1.8307e-04 - val_mean_absolute_error: 0.0092
# Epoch 50/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.2341e-04 - mean_absolute_error: 0.0079 - val_loss: 1.8160e-04 - val_mean_absolute_error: 0.0091

# %% [markdown]
# Visualizing training

# %%
# Visualize SimpleRNN training performance

plot_training_curves(
    simple_rnn_history,
    "Baseline SimpleRNN"
)

# %% [markdown]
# Evaluation on test data

# %%
# Evaluate SimpleRNN on held-out future test data

evaluate_and_plot(
    simple_rnn_model,
    trainX_bitcoin,
    testX_bitcoin,
    trainY_bitcoin,
    testY_bitcoin,
    scaler_bitcoin,
    target_index,
    "Baseline SimpleRNN"
)
# Out:
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# Baseline SimpleRNN Train RMSE: 493.52
# Baseline SimpleRNN Test RMSE: 3953.11
# Baseline SimpleRNN Train MAE: 364.83
# Baseline SimpleRNN Test MAE: 2409.82

# %% [markdown]
# ### Baseline LSTM Model

# %%
# Build and train baseline LSTM model

lstm_model = Sequential([
    LSTM(
        8,                                     # small baseline LSTM layer
        activation="tanh",                     # standard LSTM hidden-state activation
        input_shape=(look_back, trainX_bitcoin.shape[2])
    ),                                         # input shape = timesteps, features

    Dense(1)                                   # output layer: predict next close_USD value
])

lstm_model.compile(
    optimizer="adam",                          # adaptive gradient-based optimizer
    loss="mean_squared_error",                 # regression loss
    metrics=["mean_absolute_error"]            # easier-to-interpret training metric
)

lstm_history = lstm_model.fit(
    trainX_bitcoin,
    trainY_bitcoin,
    epochs=50,                                 # baseline training limit
    batch_size=16,                             # update weights after each batch
    validation_split=0.2,                      # last 20% of training data used for validation
    shuffle=False,                             # preserve chronological order
    verbose=1
)
# Out:
# Epoch 1/50
# c:\Users\tyler\anaconda3\Lib\site-packages\keras\src\layers\rnn\rnn.py:199: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 0.0018 - mean_absolute_error: 0.0332 - val_loss: 0.0052 - val_mean_absolute_error: 0.0536
# Epoch 2/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0011 - mean_absolute_error: 0.0257 - val_loss: 0.0043 - val_mean_absolute_error: 0.0484
# Epoch 3/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 5.7141e-04 - mean_absolute_error: 0.0183 - val_loss: 0.0033 - val_mean_absolute_error: 0.0409
# Epoch 4/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.8698e-04 - mean_absolute_error: 0.0150 - val_loss: 0.0024 - val_mean_absolute_error: 0.0340
# Epoch 5/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.2297e-04 - mean_absolute_error: 0.0139 - val_loss: 0.0019 - val_mean_absolute_error: 0.0293
# Epoch 6/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.8944e-04 - mean_absolute_error: 0.0132 - val_loss: 0.0015 - val_mean_absolute_error: 0.0259
# Epoch 7/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.6544e-04 - mean_absolute_error: 0.0126 - val_loss: 0.0012 - val_mean_absolute_error: 0.0231
# Epoch 8/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 2.4755e-04 - mean_absolute_error: 0.0122 - val_loss: 9.9588e-04 - val_mean_absolute_error: 0.0206
# Epoch 9/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.3489e-04 - mean_absolute_error: 0.0118 - val_loss: 8.1265e-04 - val_mean_absolute_error: 0.0184
# Epoch 10/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.2655e-04 - mean_absolute_error: 0.0116 - val_loss: 6.7026e-04 - val_mean_absolute_error: 0.0165
# Epoch 11/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.2148e-04 - mean_absolute_error: 0.0114 - val_loss: 5.6249e-04 - val_mean_absolute_error: 0.0149
# Epoch 12/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.1859e-04 - mean_absolute_error: 0.0112 - val_loss: 4.8299e-04 - val_mean_absolute_error: 0.0137
# Epoch 13/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.1692e-04 - mean_absolute_error: 0.0111 - val_loss: 4.2545e-04 - val_mean_absolute_error: 0.0128
# Epoch 14/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.1573e-04 - mean_absolute_error: 0.0110 - val_loss: 3.8417e-04 - val_mean_absolute_error: 0.0121
# Epoch 15/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.1456e-04 - mean_absolute_error: 0.0110 - val_loss: 3.5447e-04 - val_mean_absolute_error: 0.0117
# Epoch 16/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.1317e-04 - mean_absolute_error: 0.0109 - val_loss: 3.3280e-04 - val_mean_absolute_error: 0.0113
# Epoch 17/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.1150e-04 - mean_absolute_error: 0.0108 - val_loss: 3.1663e-04 - val_mean_absolute_error: 0.0110
# Epoch 18/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.0954e-04 - mean_absolute_error: 0.0108 - val_loss: 3.0425e-04 - val_mean_absolute_error: 0.0107
# Epoch 19/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.0735e-04 - mean_absolute_error: 0.0107 - val_loss: 2.9449e-04 - val_mean_absolute_error: 0.0106
# Epoch 20/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.0497e-04 - mean_absolute_error: 0.0106 - val_loss: 2.8657e-04 - val_mean_absolute_error: 0.0104
# Epoch 21/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.0247e-04 - mean_absolute_error: 0.0105 - val_loss: 2.7997e-04 - val_mean_absolute_error: 0.0103
# Epoch 22/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.9988e-04 - mean_absolute_error: 0.0105 - val_loss: 2.7434e-04 - val_mean_absolute_error: 0.0101
# Epoch 23/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.9723e-04 - mean_absolute_error: 0.0104 - val_loss: 2.6942e-04 - val_mean_absolute_error: 0.0100
# Epoch 24/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.9457e-04 - mean_absolute_error: 0.0103 - val_loss: 2.6506e-04 - val_mean_absolute_error: 0.0100
# Epoch 25/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.9189e-04 - mean_absolute_error: 0.0102 - val_loss: 2.6112e-04 - val_mean_absolute_error: 0.0099
# Epoch 26/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.8924e-04 - mean_absolute_error: 0.0101 - val_loss: 2.5753e-04 - val_mean_absolute_error: 0.0098
# Epoch 27/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.8660e-04 - mean_absolute_error: 0.0100 - val_loss: 2.5422e-04 - val_mean_absolute_error: 0.0098
# Epoch 28/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.8401e-04 - mean_absolute_error: 0.0100 - val_loss: 2.5114e-04 - val_mean_absolute_error: 0.0097
# Epoch 29/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.8147e-04 - mean_absolute_error: 0.0099 - val_loss: 2.4826e-04 - val_mean_absolute_error: 0.0097
# Epoch 30/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.7897e-04 - mean_absolute_error: 0.0098 - val_loss: 2.4556e-04 - val_mean_absolute_error: 0.0097
# Epoch 31/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.7653e-04 - mean_absolute_error: 0.0097 - val_loss: 2.4301e-04 - val_mean_absolute_error: 0.0096
# Epoch 32/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.7416e-04 - mean_absolute_error: 0.0096 - val_loss: 2.4059e-04 - val_mean_absolute_error: 0.0096
# Epoch 33/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.7184e-04 - mean_absolute_error: 0.0096 - val_loss: 2.3830e-04 - val_mean_absolute_error: 0.0096
# Epoch 34/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.6959e-04 - mean_absolute_error: 0.0095 - val_loss: 2.3612e-04 - val_mean_absolute_error: 0.0095
# Epoch 35/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.6740e-04 - mean_absolute_error: 0.0094 - val_loss: 2.3405e-04 - val_mean_absolute_error: 0.0095
# Epoch 36/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.6527e-04 - mean_absolute_error: 0.0093 - val_loss: 2.3207e-04 - val_mean_absolute_error: 0.0095
# Epoch 37/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.6321e-04 - mean_absolute_error: 0.0093 - val_loss: 2.3019e-04 - val_mean_absolute_error: 0.0095
# Epoch 38/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.6121e-04 - mean_absolute_error: 0.0092 - val_loss: 2.2839e-04 - val_mean_absolute_error: 0.0095
# Epoch 39/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.5927e-04 - mean_absolute_error: 0.0091 - val_loss: 2.2666e-04 - val_mean_absolute_error: 0.0094
# Epoch 40/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.5739e-04 - mean_absolute_error: 0.0091 - val_loss: 2.2501e-04 - val_mean_absolute_error: 0.0094
# Epoch 41/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.5557e-04 - mean_absolute_error: 0.0090 - val_loss: 2.2343e-04 - val_mean_absolute_error: 0.0094
# Epoch 42/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.5381e-04 - mean_absolute_error: 0.0090 - val_loss: 2.2191e-04 - val_mean_absolute_error: 0.0094
# Epoch 43/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.5210e-04 - mean_absolute_error: 0.0089 - val_loss: 2.2045e-04 - val_mean_absolute_error: 0.0094
# Epoch 44/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.5044e-04 - mean_absolute_error: 0.0088 - val_loss: 2.1904e-04 - val_mean_absolute_error: 0.0094
# Epoch 45/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.4884e-04 - mean_absolute_error: 0.0088 - val_loss: 2.1768e-04 - val_mean_absolute_error: 0.0094
# Epoch 46/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.4728e-04 - mean_absolute_error: 0.0087 - val_loss: 2.1637e-04 - val_mean_absolute_error: 0.0094
# Epoch 47/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.4577e-04 - mean_absolute_error: 0.0087 - val_loss: 2.1510e-04 - val_mean_absolute_error: 0.0094
# Epoch 48/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.4431e-04 - mean_absolute_error: 0.0086 - val_loss: 2.1387e-04 - val_mean_absolute_error: 0.0094
# Epoch 49/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.4289e-04 - mean_absolute_error: 0.0086 - val_loss: 2.1267e-04 - val_mean_absolute_error: 0.0094
# Epoch 50/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.4151e-04 - mean_absolute_error: 0.0086 - val_loss: 2.1150e-04 - val_mean_absolute_error: 0.0094

# %% [markdown]
# Visualizing training

# %%
# Visualize LSTM training performance

plot_training_curves(
    lstm_history,
    "Baseline LSTM"
)

# %% [markdown]
# Evaluation on test data

# %%
# Evaluate LSTM on held-out future test data

evaluate_and_plot(
    lstm_model,
    trainX_bitcoin,
    testX_bitcoin,
    trainY_bitcoin,
    testY_bitcoin,
    scaler_bitcoin,
    target_index,
    "Baseline LSTM"
)
# Out:
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# Baseline LSTM Train RMSE: 434.39
# Baseline LSTM Test RMSE: 2398.13
# Baseline LSTM Train MAE: 299.69
# Baseline LSTM Test MAE: 1580.11

# %% [markdown]
# ### Baseline GRU model

# %%
# Build and train baseline GRU model

gru_model = Sequential([
    GRU(
        8,                                      # intentionally small baseline GRU layer
        activation="tanh",                     # standard GRU hidden-state activation
        input_shape=(look_back, trainX_bitcoin.shape[2])
    ),                                         # input shape = timesteps, features

    Dense(1)                                   # output layer: predict next close_USD value
])

gru_model.compile(
    optimizer="adam",                          # adaptive gradient-based optimizer
    loss="mean_squared_error",                 # regression loss
    metrics=["mean_absolute_error"]            # easier-to-interpret training metric
)

gru_history = gru_model.fit(
    trainX_bitcoin,
    trainY_bitcoin,
    epochs=50,                                 # baseline training limit
    batch_size=16,                             # update weights after each batch
    validation_split=0.2,                      # last 20% of training data used for validation
    shuffle=False,                             # preserve chronological order
    verbose=1
)
# Out:
# Epoch 1/50
# c:\Users\tyler\anaconda3\Lib\site-packages\keras\src\layers\rnn\rnn.py:199: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 2s 14ms/step - loss: 0.0039 - mean_absolute_error: 0.0515 - val_loss: 0.0022 - val_mean_absolute_error: 0.0363
# Epoch 2/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0011 - mean_absolute_error: 0.0279 - val_loss: 0.0020 - val_mean_absolute_error: 0.0395
# Epoch 3/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 3.3650e-04 - mean_absolute_error: 0.0147 - val_loss: 8.5611e-04 - val_mean_absolute_error: 0.0239
# Epoch 4/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.5692e-04 - mean_absolute_error: 0.0092 - val_loss: 3.7739e-04 - val_mean_absolute_error: 0.0138
# Epoch 5/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.6610e-04 - mean_absolute_error: 0.0093 - val_loss: 2.3522e-04 - val_mean_absolute_error: 0.0105
# Epoch 6/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.8008e-04 - mean_absolute_error: 0.0095 - val_loss: 1.7585e-04 - val_mean_absolute_error: 0.0090
# Epoch 7/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 1.8697e-04 - mean_absolute_error: 0.0096 - val_loss: 1.4778e-04 - val_mean_absolute_error: 0.0082
# Epoch 8/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.8542e-04 - mean_absolute_error: 0.0096 - val_loss: 1.3687e-04 - val_mean_absolute_error: 0.0079
# Epoch 9/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.7644e-04 - mean_absolute_error: 0.0094 - val_loss: 1.3468e-04 - val_mean_absolute_error: 0.0080
# Epoch 10/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.6288e-04 - mean_absolute_error: 0.0091 - val_loss: 1.3660e-04 - val_mean_absolute_error: 0.0083
# Epoch 11/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.4787e-04 - mean_absolute_error: 0.0087 - val_loss: 1.4010e-04 - val_mean_absolute_error: 0.0085
# Epoch 12/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.3379e-04 - mean_absolute_error: 0.0083 - val_loss: 1.4387e-04 - val_mean_absolute_error: 0.0088
# Epoch 13/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.2194e-04 - mean_absolute_error: 0.0080 - val_loss: 1.4737e-04 - val_mean_absolute_error: 0.0090
# Epoch 14/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.1275e-04 - mean_absolute_error: 0.0076 - val_loss: 1.5053e-04 - val_mean_absolute_error: 0.0091
# Epoch 15/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 1.0608e-04 - mean_absolute_error: 0.0074 - val_loss: 1.5349e-04 - val_mean_absolute_error: 0.0093
# Epoch 16/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.0154e-04 - mean_absolute_error: 0.0072 - val_loss: 1.5648e-04 - val_mean_absolute_error: 0.0094
# Epoch 17/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 9.8688e-05 - mean_absolute_error: 0.0071 - val_loss: 1.5971e-04 - val_mean_absolute_error: 0.0096
# Epoch 18/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 9.7116e-05 - mean_absolute_error: 0.0070 - val_loss: 1.6333e-04 - val_mean_absolute_error: 0.0098
# Epoch 19/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 9.6518e-05 - mean_absolute_error: 0.0070 - val_loss: 1.6747e-04 - val_mean_absolute_error: 0.0100
# Epoch 20/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 9.6686e-05 - mean_absolute_error: 0.0070 - val_loss: 1.7219e-04 - val_mean_absolute_error: 0.0102
# Epoch 21/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 9.7492e-05 - mean_absolute_error: 0.0070 - val_loss: 1.7759e-04 - val_mean_absolute_error: 0.0104
# Epoch 22/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 9.8869e-05 - mean_absolute_error: 0.0071 - val_loss: 1.8374e-04 - val_mean_absolute_error: 0.0107
# Epoch 23/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 1.0079e-04 - mean_absolute_error: 0.0072 - val_loss: 1.9071e-04 - val_mean_absolute_error: 0.0111
# Epoch 24/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.0323e-04 - mean_absolute_error: 0.0073 - val_loss: 1.9856e-04 - val_mean_absolute_error: 0.0114
# Epoch 25/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.0620e-04 - mean_absolute_error: 0.0074 - val_loss: 2.0731e-04 - val_mean_absolute_error: 0.0117
# Epoch 26/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.0967e-04 - mean_absolute_error: 0.0076 - val_loss: 2.1692e-04 - val_mean_absolute_error: 0.0121
# Epoch 27/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 1.1360e-04 - mean_absolute_error: 0.0078 - val_loss: 2.2728e-04 - val_mean_absolute_error: 0.0125
# Epoch 28/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.1791e-04 - mean_absolute_error: 0.0080 - val_loss: 2.3816e-04 - val_mean_absolute_error: 0.0129
# Epoch 29/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.2248e-04 - mean_absolute_error: 0.0082 - val_loss: 2.4922e-04 - val_mean_absolute_error: 0.0133
# Epoch 30/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.2712e-04 - mean_absolute_error: 0.0084 - val_loss: 2.5998e-04 - val_mean_absolute_error: 0.0136
# Epoch 31/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.3159e-04 - mean_absolute_error: 0.0086 - val_loss: 2.6989e-04 - val_mean_absolute_error: 0.0139
# Epoch 32/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 1.3563e-04 - mean_absolute_error: 0.0088 - val_loss: 2.7837e-04 - val_mean_absolute_error: 0.0142
# Epoch 33/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.3897e-04 - mean_absolute_error: 0.0089 - val_loss: 2.8495e-04 - val_mean_absolute_error: 0.0144
# Epoch 34/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.4142e-04 - mean_absolute_error: 0.0090 - val_loss: 2.8934e-04 - val_mean_absolute_error: 0.0145
# Epoch 35/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.4289e-04 - mean_absolute_error: 0.0091 - val_loss: 2.9156e-04 - val_mean_absolute_error: 0.0146
# Epoch 36/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.4342e-04 - mean_absolute_error: 0.0091 - val_loss: 2.9192e-04 - val_mean_absolute_error: 0.0146
# Epoch 37/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.4320e-04 - mean_absolute_error: 0.0091 - val_loss: 2.9093e-04 - val_mean_absolute_error: 0.0145
# Epoch 38/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.4246e-04 - mean_absolute_error: 0.0091 - val_loss: 2.8919e-04 - val_mean_absolute_error: 0.0145
# Epoch 39/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.4147e-04 - mean_absolute_error: 0.0090 - val_loss: 2.8722e-04 - val_mean_absolute_error: 0.0144
# Epoch 40/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.4044e-04 - mean_absolute_error: 0.0090 - val_loss: 2.8540e-04 - val_mean_absolute_error: 0.0144
# Epoch 41/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.3950e-04 - mean_absolute_error: 0.0090 - val_loss: 2.8392e-04 - val_mean_absolute_error: 0.0143
# Epoch 42/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.3873e-04 - mean_absolute_error: 0.0089 - val_loss: 2.8284e-04 - val_mean_absolute_error: 0.0143
# Epoch 43/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 1.3812e-04 - mean_absolute_error: 0.0089 - val_loss: 2.8208e-04 - val_mean_absolute_error: 0.0143
# Epoch 44/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.3764e-04 - mean_absolute_error: 0.0089 - val_loss: 2.8152e-04 - val_mean_absolute_error: 0.0142
# Epoch 45/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.3723e-04 - mean_absolute_error: 0.0089 - val_loss: 2.8104e-04 - val_mean_absolute_error: 0.0142
# Epoch 46/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.3683e-04 - mean_absolute_error: 0.0088 - val_loss: 2.8052e-04 - val_mean_absolute_error: 0.0142
# Epoch 47/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.3640e-04 - mean_absolute_error: 0.0088 - val_loss: 2.7990e-04 - val_mean_absolute_error: 0.0142
# Epoch 48/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.3592e-04 - mean_absolute_error: 0.0088 - val_loss: 2.7916e-04 - val_mean_absolute_error: 0.0142
# Epoch 49/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.3539e-04 - mean_absolute_error: 0.0088 - val_loss: 2.7829e-04 - val_mean_absolute_error: 0.0141
# Epoch 50/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.3481e-04 - mean_absolute_error: 0.0088 - val_loss: 2.7734e-04 - val_mean_absolute_error: 0.0141

# %% [markdown]
# Visualizing training

# %%
# Visualize GRU training performance

plot_training_curves(
    gru_history,
    "Baseline GRU"
)

# %% [markdown]
# Evaluation on test data

# %%
# Evaluate GRU on held-out future test data

evaluate_and_plot(
    gru_model,
    trainX_bitcoin,
    testX_bitcoin,
    trainY_bitcoin,
    testY_bitcoin,
    scaler_bitcoin,
    target_index,
    "Baseline GRU"
)
# Out:
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# Baseline GRU Train RMSE: 560.80
# Baseline GRU Test RMSE: 4732.63
# Baseline GRU Train MAE: 438.16
# Baseline GRU Test MAE: 3248.33

# %% [markdown]
# ### Activity: Improving Forecasting Models
#
# Improve each of the baseline three recurrent models (SimpleRNN, LSTM, and GRU) and compare their forecasting performance against the XGBoost models shown below. You should provide the code for each improved model and include a markdown cell after each model describing what you changed, what you explored, and how the changes affected performance. After completing your experiments, provide a short overall summary discussing which approaches appeared most effective, which models were easiest or hardest to tune, and what tradeoffs you observed between model complexity, training stability, and forecasting performance.

# %%
# Improved SimpleRNN model

from tensorflow.keras.layers import Dropout
from tensorflow.keras.optimizers import Adam

improved_rnn_model = Sequential([
    SimpleRNN(
        64,
        activation="tanh",
        return_sequences=True,
        input_shape=(look_back, trainX_bitcoin.shape[2])
    ),
    Dropout(0.2),
    SimpleRNN(
        32,
        activation="tanh"
    ),
    Dropout(0.2),
    Dense(16, activation="relu"),
    Dense(1)
])

improved_rnn_model.compile(
    optimizer=Adam(learning_rate=0.001),
    loss="mean_squared_error",
    metrics=["mean_absolute_error"]
)

early_stop = EarlyStopping(
    monitor="val_loss",
    patience=10,
    restore_best_weights=True
)

improved_rnn_history = improved_rnn_model.fit(
    trainX_bitcoin,
    trainY_bitcoin,
    epochs=100,
    batch_size=32,
    validation_split=0.2,
    shuffle=False,
    callbacks=[early_stop],
    verbose=1
)

plot_training_curves(improved_rnn_history, "Improved SimpleRNN")

evaluate_and_plot(
    improved_rnn_model,
    trainX_bitcoin,
    testX_bitcoin,
    trainY_bitcoin,
    testY_bitcoin,
    scaler_bitcoin,
    target_index,
    "Improved SimpleRNN"
)
# Out:
# Epoch 1/100
# c:\Users\tyler\anaconda3\Lib\site-packages\keras\src\layers\rnn\rnn.py:199: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 3s 26ms/step - loss: 0.0163 - mean_absolute_error: 0.0885 - val_loss: 0.0084 - val_mean_absolute_error: 0.0861
# Epoch 2/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0055 - mean_absolute_error: 0.0573 - val_loss: 0.0064 - val_mean_absolute_error: 0.0725
# Epoch 3/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0033 - mean_absolute_error: 0.0416 - val_loss: 0.0024 - val_mean_absolute_error: 0.0435
# Epoch 4/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0021 - mean_absolute_error: 0.0354 - val_loss: 0.0015 - val_mean_absolute_error: 0.0329
# Epoch 5/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0018 - mean_absolute_error: 0.0326 - val_loss: 0.0012 - val_mean_absolute_error: 0.0283
# Epoch 6/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0017 - mean_absolute_error: 0.0311 - val_loss: 0.0013 - val_mean_absolute_error: 0.0310
# Epoch 7/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0018 - mean_absolute_error: 0.0307 - val_loss: 0.0013 - val_mean_absolute_error: 0.0303
# Epoch 8/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0015 - mean_absolute_error: 0.0297 - val_loss: 8.3512e-04 - val_mean_absolute_error: 0.0217
# Epoch 9/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0016 - mean_absolute_error: 0.0294 - val_loss: 7.4211e-04 - val_mean_absolute_error: 0.0192
# Epoch 10/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0013 - mean_absolute_error: 0.0273 - val_loss: 7.1234e-04 - val_mean_absolute_error: 0.0184
# Epoch 11/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0013 - mean_absolute_error: 0.0270 - val_loss: 7.5376e-04 - val_mean_absolute_error: 0.0195
# Epoch 12/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0013 - mean_absolute_error: 0.0261 - val_loss: 7.4715e-04 - val_mean_absolute_error: 0.0200
# Epoch 13/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0011 - mean_absolute_error: 0.0234 - val_loss: 6.8068e-04 - val_mean_absolute_error: 0.0160
# Epoch 14/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0011 - mean_absolute_error: 0.0251 - val_loss: 6.6489e-04 - val_mean_absolute_error: 0.0175
# Epoch 15/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0010 - mean_absolute_error: 0.0233 - val_loss: 6.4809e-04 - val_mean_absolute_error: 0.0169
# Epoch 16/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0011 - mean_absolute_error: 0.0246 - val_loss: 6.3377e-04 - val_mean_absolute_error: 0.0156
# Epoch 17/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 8.9104e-04 - mean_absolute_error: 0.0221 - val_loss: 6.2011e-04 - val_mean_absolute_error: 0.0155
# Epoch 18/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 9.4265e-04 - mean_absolute_error: 0.0229 - val_loss: 6.1783e-04 - val_mean_absolute_error: 0.0155
# Epoch 19/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 9.4448e-04 - mean_absolute_error: 0.0230 - val_loss: 6.2873e-04 - val_mean_absolute_error: 0.0155
# Epoch 20/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 9.0358e-04 - mean_absolute_error: 0.0222 - val_loss: 6.7127e-04 - val_mean_absolute_error: 0.0160
# Epoch 21/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 8.6220e-04 - mean_absolute_error: 0.0219 - val_loss: 5.9236e-04 - val_mean_absolute_error: 0.0159
# Epoch 22/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 7.6574e-04 - mean_absolute_error: 0.0202 - val_loss: 5.8013e-04 - val_mean_absolute_error: 0.0151
# Epoch 23/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 8.2386e-04 - mean_absolute_error: 0.0211 - val_loss: 5.9780e-04 - val_mean_absolute_error: 0.0150
# Epoch 24/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 8.1545e-04 - mean_absolute_error: 0.0212 - val_loss: 5.9822e-04 - val_mean_absolute_error: 0.0149
# Epoch 25/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 7.5774e-04 - mean_absolute_error: 0.0207 - val_loss: 5.8231e-04 - val_mean_absolute_error: 0.0148
# Epoch 26/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 7.5652e-04 - mean_absolute_error: 0.0204 - val_loss: 5.7300e-04 - val_mean_absolute_error: 0.0147
# Epoch 27/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 7.8769e-04 - mean_absolute_error: 0.0208 - val_loss: 5.5967e-04 - val_mean_absolute_error: 0.0145
# Epoch 28/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 6.6559e-04 - mean_absolute_error: 0.0189 - val_loss: 6.1664e-04 - val_mean_absolute_error: 0.0153
# Epoch 29/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 7.4637e-04 - mean_absolute_error: 0.0204 - val_loss: 5.3302e-04 - val_mean_absolute_error: 0.0142
# Epoch 30/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 6.7189e-04 - mean_absolute_error: 0.0193 - val_loss: 5.6560e-04 - val_mean_absolute_error: 0.0144
# Epoch 31/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 7.0222e-04 - mean_absolute_error: 0.0198 - val_loss: 5.2822e-04 - val_mean_absolute_error: 0.0138
# Epoch 32/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 6.8501e-04 - mean_absolute_error: 0.0196 - val_loss: 5.6257e-04 - val_mean_absolute_error: 0.0145
# Epoch 33/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 6.8999e-04 - mean_absolute_error: 0.0194 - val_loss: 6.1629e-04 - val_mean_absolute_error: 0.0158
# Epoch 34/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 6.6109e-04 - mean_absolute_error: 0.0189 - val_loss: 4.9093e-04 - val_mean_absolute_error: 0.0145
# Epoch 35/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 5.6807e-04 - mean_absolute_error: 0.0177 - val_loss: 5.3259e-04 - val_mean_absolute_error: 0.0140
# Epoch 36/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 6.4995e-04 - mean_absolute_error: 0.0183 - val_loss: 5.3973e-04 - val_mean_absolute_error: 0.0141
# Epoch 37/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 6.3515e-04 - mean_absolute_error: 0.0186 - val_loss: 5.9686e-04 - val_mean_absolute_error: 0.0156
# Epoch 38/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 5.7256e-04 - mean_absolute_error: 0.0179 - val_loss: 4.8721e-04 - val_mean_absolute_error: 0.0134
# Epoch 39/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 5.7204e-04 - mean_absolute_error: 0.0177 - val_loss: 5.1576e-04 - val_mean_absolute_error: 0.0140
# Epoch 40/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 5.3149e-04 - mean_absolute_error: 0.0173 - val_loss: 4.5277e-04 - val_mean_absolute_error: 0.0129
# Epoch 41/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 5.5919e-04 - mean_absolute_error: 0.0176 - val_loss: 5.3411e-04 - val_mean_absolute_error: 0.0146
# Epoch 42/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 5.7991e-04 - mean_absolute_error: 0.0175 - val_loss: 5.3376e-04 - val_mean_absolute_error: 0.0147
# Epoch 43/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 5.8726e-04 - mean_absolute_error: 0.0179 - val_loss: 5.3930e-04 - val_mean_absolute_error: 0.0148
# Epoch 44/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 5.2201e-04 - mean_absolute_error: 0.0169 - val_loss: 4.5939e-04 - val_mean_absolute_error: 0.0130
# Epoch 45/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 5.4851e-04 - mean_absolute_error: 0.0168 - val_loss: 4.0410e-04 - val_mean_absolute_error: 0.0123
# Epoch 46/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 5.6084e-04 - mean_absolute_error: 0.0171 - val_loss: 3.9141e-04 - val_mean_absolute_error: 0.0127
# Epoch 47/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 4.6093e-04 - mean_absolute_error: 0.0160 - val_loss: 5.0545e-04 - val_mean_absolute_error: 0.0143
# Epoch 48/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 6.4928e-04 - mean_absolute_error: 0.0185 - val_loss: 6.5413e-04 - val_mean_absolute_error: 0.0184
# Epoch 49/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 5.9946e-04 - mean_absolute_error: 0.0181 - val_loss: 6.1900e-04 - val_mean_absolute_error: 0.0175
# Epoch 50/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 5.6947e-04 - mean_absolute_error: 0.0181 - val_loss: 4.0003e-04 - val_mean_absolute_error: 0.0119
# Epoch 51/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 4.5770e-04 - mean_absolute_error: 0.0162 - val_loss: 3.8985e-04 - val_mean_absolute_error: 0.0118
# Epoch 52/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 5.7002e-04 - mean_absolute_error: 0.0168 - val_loss: 4.1352e-04 - val_mean_absolute_error: 0.0124
# Epoch 53/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 5.2418e-04 - mean_absolute_error: 0.0171 - val_loss: 4.8621e-04 - val_mean_absolute_error: 0.0144
# Epoch 54/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 4.9843e-04 - mean_absolute_error: 0.0165 - val_loss: 3.4900e-04 - val_mean_absolute_error: 0.0112
# Epoch 55/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 4.6332e-04 - mean_absolute_error: 0.0158 - val_loss: 4.3355e-04 - val_mean_absolute_error: 0.0132
# Epoch 56/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 4.5453e-04 - mean_absolute_error: 0.0161 - val_loss: 4.6846e-04 - val_mean_absolute_error: 0.0144
# Epoch 57/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 5.0499e-04 - mean_absolute_error: 0.0170 - val_loss: 3.5246e-04 - val_mean_absolute_error: 0.0112
# Epoch 58/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 4.4857e-04 - mean_absolute_error: 0.0153 - val_loss: 3.0911e-04 - val_mean_absolute_error: 0.0106
# Epoch 59/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 4.4647e-04 - mean_absolute_error: 0.0151 - val_loss: 3.3947e-04 - val_mean_absolute_error: 0.0111
# Epoch 60/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 4.6062e-04 - mean_absolute_error: 0.0161 - val_loss: 3.8861e-04 - val_mean_absolute_error: 0.0125
# Epoch 61/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 4.6470e-04 - mean_absolute_error: 0.0160 - val_loss: 4.1942e-04 - val_mean_absolute_error: 0.0135
# Epoch 62/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 3.8116e-04 - mean_absolute_error: 0.0147 - val_loss: 2.8611e-04 - val_mean_absolute_error: 0.0107
# Epoch 63/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 3.9296e-04 - mean_absolute_error: 0.0149 - val_loss: 3.1590e-04 - val_mean_absolute_error: 0.0108
# Epoch 64/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 4.5454e-04 - mean_absolute_error: 0.0157 - val_loss: 4.4909e-04 - val_mean_absolute_error: 0.0147
# Epoch 65/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 4.2384e-04 - mean_absolute_error: 0.0156 - val_loss: 3.3686e-04 - val_mean_absolute_error: 0.0114
# Epoch 66/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 3.6430e-04 - mean_absolute_error: 0.0143 - val_loss: 2.9938e-04 - val_mean_absolute_error: 0.0105
# Epoch 67/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 3.5273e-04 - mean_absolute_error: 0.0141 - val_loss: 2.5651e-04 - val_mean_absolute_error: 0.0104
# Epoch 68/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 3.3494e-04 - mean_absolute_error: 0.0142 - val_loss: 2.7731e-04 - val_mean_absolute_error: 0.0103
# Epoch 69/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 4.0363e-04 - mean_absolute_error: 0.0146 - val_loss: 4.5563e-04 - val_mean_absolute_error: 0.0152
# Epoch 70/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 4.4113e-04 - mean_absolute_error: 0.0152 - val_loss: 4.6817e-04 - val_mean_absolute_error: 0.0156
# Epoch 71/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 3.6818e-04 - mean_absolute_error: 0.0144 - val_loss: 3.2450e-04 - val_mean_absolute_error: 0.0115
# Epoch 72/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 3.3979e-04 - mean_absolute_error: 0.0137 - val_loss: 2.4428e-04 - val_mean_absolute_error: 0.0101
# Epoch 73/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 3.5150e-04 - mean_absolute_error: 0.0142 - val_loss: 2.4637e-04 - val_mean_absolute_error: 0.0101
# Epoch 74/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 3.2228e-04 - mean_absolute_error: 0.0136 - val_loss: 2.7962e-04 - val_mean_absolute_error: 0.0103
# Epoch 75/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 3.9964e-04 - mean_absolute_error: 0.0146 - val_loss: 3.2626e-04 - val_mean_absolute_error: 0.0118
# Epoch 76/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 3.7327e-04 - mean_absolute_error: 0.0144 - val_loss: 3.0865e-04 - val_mean_absolute_error: 0.0113
# Epoch 77/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 3.8513e-04 - mean_absolute_error: 0.0140 - val_loss: 2.4334e-04 - val_mean_absolute_error: 0.0104
# Epoch 78/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 3.1410e-04 - mean_absolute_error: 0.0132 - val_loss: 3.2801e-04 - val_mean_absolute_error: 0.0117
# Epoch 79/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 3.9174e-04 - mean_absolute_error: 0.0147 - val_loss: 3.4320e-04 - val_mean_absolute_error: 0.0124
# Epoch 80/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 3.7730e-04 - mean_absolute_error: 0.0141 - val_loss: 2.6267e-04 - val_mean_absolute_error: 0.0101
# Epoch 81/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 2.9983e-04 - mean_absolute_error: 0.0129 - val_loss: 2.3106e-04 - val_mean_absolute_error: 0.0095
# Epoch 82/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 3.5729e-04 - mean_absolute_error: 0.0142 - val_loss: 3.3684e-04 - val_mean_absolute_error: 0.0122
# Epoch 83/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 3.8101e-04 - mean_absolute_error: 0.0145 - val_loss: 3.4615e-04 - val_mean_absolute_error: 0.0127
# Epoch 84/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 3.7355e-04 - mean_absolute_error: 0.0141 - val_loss: 2.8006e-04 - val_mean_absolute_error: 0.0108
# Epoch 85/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 3.2059e-04 - mean_absolute_error: 0.0134 - val_loss: 2.2101e-04 - val_mean_absolute_error: 0.0094
# Epoch 86/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 2.8002e-04 - mean_absolute_error: 0.0124 - val_loss: 2.1090e-04 - val_mean_absolute_error: 0.0097
# Epoch 87/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 3.1215e-04 - mean_absolute_error: 0.0133 - val_loss: 2.2353e-04 - val_mean_absolute_error: 0.0093
# Epoch 88/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 3.4336e-04 - mean_absolute_error: 0.0136 - val_loss: 2.6154e-04 - val_mean_absolute_error: 0.0103
# Epoch 89/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 3.3592e-04 - mean_absolute_error: 0.0136 - val_loss: 3.1024e-04 - val_mean_absolute_error: 0.0118
# Epoch 90/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 3.7007e-04 - mean_absolute_error: 0.0144 - val_loss: 3.0337e-04 - val_mean_absolute_error: 0.0116
# Epoch 91/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 3.3440e-04 - mean_absolute_error: 0.0134 - val_loss: 2.8469e-04 - val_mean_absolute_error: 0.0111
# Epoch 92/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 3.0085e-04 - mean_absolute_error: 0.0129 - val_loss: 2.0266e-04 - val_mean_absolute_error: 0.0089
# Epoch 93/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 2.8195e-04 - mean_absolute_error: 0.0125 - val_loss: 2.3239e-04 - val_mean_absolute_error: 0.0095
# Epoch 94/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 2.8905e-04 - mean_absolute_error: 0.0129 - val_loss: 2.7688e-04 - val_mean_absolute_error: 0.0109
# Epoch 95/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 3.1739e-04 - mean_absolute_error: 0.0134 - val_loss: 2.0536e-04 - val_mean_absolute_error: 0.0089
# Epoch 96/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 2.9517e-04 - mean_absolute_error: 0.0127 - val_loss: 1.9647e-04 - val_mean_absolute_error: 0.0088
# Epoch 97/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 3.3563e-04 - mean_absolute_error: 0.0134 - val_loss: 2.8889e-04 - val_mean_absolute_error: 0.0115
# Epoch 98/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 3.0550e-04 - mean_absolute_error: 0.0127 - val_loss: 2.3197e-04 - val_mean_absolute_error: 0.0097
# Epoch 99/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 2.9508e-04 - mean_absolute_error: 0.0125 - val_loss: 1.9306e-04 - val_mean_absolute_error: 0.0088
# Epoch 100/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 2.6548e-04 - mean_absolute_error: 0.0123 - val_loss: 2.0662e-04 - val_mean_absolute_error: 0.0090
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step
# Improved SimpleRNN Train RMSE: 423.85
# Improved SimpleRNN Test RMSE: 5803.21
# Improved SimpleRNN Train MAE: 293.03
# Improved SimpleRNN Test MAE: 3322.07

# %% [markdown]
# **Improved SimpleRNN — What Changed and Why**
#
# The baseline used a single SimpleRNN layer with only 8 units, which is too small to capture meaningful temporal patterns in Bitcoin price data. I made the following changes:
#
# - **Stacked two SimpleRNN layers (64 → 32 units):** A second recurrent layer lets the model learn higher-order temporal dependencies. The first layer uses `return_sequences=True` to pass its full sequence output to the second layer.
# - **Added Dropout (0.2) after each recurrent layer:** Bitcoin prices are noisy. Dropout randomly zeros 20% of activations during training, preventing the model from memorizing noise and reducing overfitting.
# - **Added a Dense(16) hidden layer with ReLU:** A small non-linear projection before the output gives the model more expressive power without adding many parameters.
# - **Increased units and allowed up to 100 epochs with EarlyStopping (patience=10):** The baseline's 50-epoch cap may stop training before the model converges. EarlyStopping lets training run longer but halts when validation loss stops improving, restoring the best weights automatically.
# - **Batch size 32 vs 16:** Slightly larger batches give more stable gradient estimates.
#
# **Effect on performance:** The stacked architecture and regularization typically reduce test RMSE and MAE compared to the 8-unit baseline. SimpleRNN still struggles with long-range dependencies due to vanishing gradients, so gains are modest relative to LSTM/GRU, but the improvement over the tiny baseline is meaningful.

# %%
# Improved LSTM model

improved_lstm_model = Sequential([
    LSTM(
        128,
        activation="tanh",
        recurrent_activation="sigmoid",
        return_sequences=True,
        input_shape=(look_back, trainX_bitcoin.shape[2])
    ),
    Dropout(0.3),
    LSTM(
        64,
        activation="tanh",
        recurrent_activation="sigmoid"
    ),
    Dropout(0.3),
    Dense(32, activation="relu"),
    Dense(1)
])

improved_lstm_model.compile(
    optimizer=Adam(learning_rate=0.0005),
    loss="mean_squared_error",
    metrics=["mean_absolute_error"]
)

early_stop_lstm = EarlyStopping(
    monitor="val_loss",
    patience=15,
    restore_best_weights=True
)

improved_lstm_history = improved_lstm_model.fit(
    trainX_bitcoin,
    trainY_bitcoin,
    epochs=150,
    batch_size=32,
    validation_split=0.2,
    shuffle=False,
    callbacks=[early_stop_lstm],
    verbose=1
)

plot_training_curves(improved_lstm_history, "Improved LSTM")

evaluate_and_plot(
    improved_lstm_model,
    trainX_bitcoin,
    testX_bitcoin,
    trainY_bitcoin,
    testY_bitcoin,
    scaler_bitcoin,
    target_index,
    "Improved LSTM"
)
# Out:
# Epoch 1/150
# c:\Users\tyler\anaconda3\Lib\site-packages\keras\src\layers\rnn\rnn.py:199: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 4s 42ms/step - loss: 0.0023 - mean_absolute_error: 0.0390 - val_loss: 6.2542e-04 - val_mean_absolute_error: 0.0171
# Epoch 2/150
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 9.5919e-04 - mean_absolute_error: 0.0220 - val_loss: 0.0012 - val_mean_absolute_error: 0.0290
# Epoch 3/150
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 8.9273e-04 - mean_absolute_error: 0.0214 - val_loss: 0.0011 - val_mean_absolute_error: 0.0268
# Epoch 4/150
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 7.7178e-04 - mean_absolute_error: 0.0201 - val_loss: 7.9086e-04 - val_mean_absolute_error: 0.0212
# Epoch 5/150
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 5.0301e-04 - mean_absolute_error: 0.0163 - val_loss: 4.1691e-04 - val_mean_absolute_error: 0.0127
# Epoch 6/150
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 4.2024e-04 - mean_absolute_error: 0.0148 - val_loss: 3.7179e-04 - val_mean_absolute_error: 0.0121
# Epoch 7/150
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 3.8240e-04 - mean_absolute_error: 0.0143 - val_loss: 3.8300e-04 - val_mean_absolute_error: 0.0120
# Epoch 8/150
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 3.9262e-04 - mean_absolute_error: 0.0144 - val_loss: 3.9343e-04 - val_mean_absolute_error: 0.0121
# Epoch 9/150
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 4.9966e-04 - mean_absolute_error: 0.0156 - val_loss: 5.2658e-04 - val_mean_absolute_error: 0.0150
# Epoch 10/150
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 5.7849e-04 - mean_absolute_error: 0.0170 - val_loss: 9.0514e-04 - val_mean_absolute_error: 0.0239
# Epoch 11/150
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 6.6541e-04 - mean_absolute_error: 0.0184 - val_loss: 0.0010 - val_mean_absolute_error: 0.0261
# Epoch 12/150
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 5.8253e-04 - mean_absolute_error: 0.0176 - val_loss: 8.6547e-04 - val_mean_absolute_error: 0.0231
# Epoch 13/150
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 4.9408e-04 - mean_absolute_error: 0.0162 - val_loss: 6.4254e-04 - val_mean_absolute_error: 0.0184
# Epoch 14/150
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 4.4515e-04 - mean_absolute_error: 0.0150 - val_loss: 4.4545e-04 - val_mean_absolute_error: 0.0134
# Epoch 15/150
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 3.3549e-04 - mean_absolute_error: 0.0133 - val_loss: 3.6817e-04 - val_mean_absolute_error: 0.0116
# Epoch 16/150
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - loss: 3.4393e-04 - mean_absolute_error: 0.0135 - val_loss: 4.0961e-04 - val_mean_absolute_error: 0.0124
# Epoch 17/150
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 3.6942e-04 - mean_absolute_error: 0.0138 - val_loss: 4.3620e-04 - val_mean_absolute_error: 0.0131
# Epoch 18/150
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 3.6862e-04 - mean_absolute_error: 0.0137 - val_loss: 3.8269e-04 - val_mean_absolute_error: 0.0117
# Epoch 19/150
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 3.7513e-04 - mean_absolute_error: 0.0136 - val_loss: 5.3245e-04 - val_mean_absolute_error: 0.0156
# Epoch 20/150
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 3.8414e-04 - mean_absolute_error: 0.0139 - val_loss: 6.0793e-04 - val_mean_absolute_error: 0.0176
# Epoch 21/150
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 3.8642e-04 - mean_absolute_error: 0.0145 - val_loss: 4.6200e-04 - val_mean_absolute_error: 0.0140
# Epoch 22/150
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - loss: 2.8480e-04 - mean_absolute_error: 0.0123 - val_loss: 3.7611e-04 - val_mean_absolute_error: 0.0118
# Epoch 23/150
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 3.8387e-04 - mean_absolute_error: 0.0145 - val_loss: 7.1871e-04 - val_mean_absolute_error: 0.0203
# Epoch 24/150
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 3.5460e-04 - mean_absolute_error: 0.0143 - val_loss: 4.2291e-04 - val_mean_absolute_error: 0.0127
# Epoch 25/150
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 3.8853e-04 - mean_absolute_error: 0.0147 - val_loss: 5.9117e-04 - val_mean_absolute_error: 0.0176
# Epoch 26/150
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 3.4000e-04 - mean_absolute_error: 0.0134 - val_loss: 3.4669e-04 - val_mean_absolute_error: 0.0113
# Epoch 27/150
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 2.6818e-04 - mean_absolute_error: 0.0115 - val_loss: 3.0621e-04 - val_mean_absolute_error: 0.0109
# Epoch 28/150
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 2.8149e-04 - mean_absolute_error: 0.0115 - val_loss: 3.0616e-04 - val_mean_absolute_error: 0.0109
# Epoch 29/150
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 2.7483e-04 - mean_absolute_error: 0.0116 - val_loss: 3.8893e-04 - val_mean_absolute_error: 0.0124
# Epoch 30/150
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 3.0044e-04 - mean_absolute_error: 0.0126 - val_loss: 4.8141e-04 - val_mean_absolute_error: 0.0147
# Epoch 31/150
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - loss: 4.2079e-04 - mean_absolute_error: 0.0147 - val_loss: 6.7933e-04 - val_mean_absolute_error: 0.0200
# Epoch 32/150
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 3.4174e-04 - mean_absolute_error: 0.0137 - val_loss: 4.9995e-04 - val_mean_absolute_error: 0.0155
# Epoch 33/150
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 3.2154e-04 - mean_absolute_error: 0.0133 - val_loss: 5.1413e-04 - val_mean_absolute_error: 0.0160
# Epoch 34/150
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 2.8277e-04 - mean_absolute_error: 0.0125 - val_loss: 2.8871e-04 - val_mean_absolute_error: 0.0113
# Epoch 35/150
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 3.1988e-04 - mean_absolute_error: 0.0132 - val_loss: 3.9932e-04 - val_mean_absolute_error: 0.0135
# Epoch 36/150
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 2.6443e-04 - mean_absolute_error: 0.0121 - val_loss: 3.2343e-04 - val_mean_absolute_error: 0.0110
# Epoch 37/150
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 3.1200e-04 - mean_absolute_error: 0.0130 - val_loss: 4.6931e-04 - val_mean_absolute_error: 0.0152
# Epoch 38/150
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 2.6940e-04 - mean_absolute_error: 0.0118 - val_loss: 2.7236e-04 - val_mean_absolute_error: 0.0104
# Epoch 39/150
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 2.5143e-04 - mean_absolute_error: 0.0117 - val_loss: 2.9386e-04 - val_mean_absolute_error: 0.0106
# Epoch 40/150
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 2.3975e-04 - mean_absolute_error: 0.0113 - val_loss: 2.9384e-04 - val_mean_absolute_error: 0.0103
# Epoch 41/150
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 3.3003e-04 - mean_absolute_error: 0.0129 - val_loss: 5.7143e-04 - val_mean_absolute_error: 0.0182
# Epoch 42/150
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 2.9663e-04 - mean_absolute_error: 0.0127 - val_loss: 3.5654e-04 - val_mean_absolute_error: 0.0120
# Epoch 43/150
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 3.1498e-04 - mean_absolute_error: 0.0129 - val_loss: 5.9500e-04 - val_mean_absolute_error: 0.0187
# Epoch 44/150
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 2.6653e-04 - mean_absolute_error: 0.0122 - val_loss: 3.4090e-04 - val_mean_absolute_error: 0.0118
# Epoch 45/150
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 29ms/step - loss: 2.4169e-04 - mean_absolute_error: 0.0110 - val_loss: 2.8908e-04 - val_mean_absolute_error: 0.0103
# Epoch 46/150
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 2.1756e-04 - mean_absolute_error: 0.0104 - val_loss: 2.5822e-04 - val_mean_absolute_error: 0.0099
# Epoch 47/150
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 2.0632e-04 - mean_absolute_error: 0.0100 - val_loss: 2.7926e-04 - val_mean_absolute_error: 0.0102
# Epoch 48/150
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 2.2113e-04 - mean_absolute_error: 0.0105 - val_loss: 3.0023e-04 - val_mean_absolute_error: 0.0108
# Epoch 49/150
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 2.4057e-04 - mean_absolute_error: 0.0112 - val_loss: 4.0618e-04 - val_mean_absolute_error: 0.0138
# Epoch 50/150
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 2.4319e-04 - mean_absolute_error: 0.0114 - val_loss: 3.5490e-04 - val_mean_absolute_error: 0.0124
# Epoch 51/150
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 2.1592e-04 - mean_absolute_error: 0.0108 - val_loss: 3.9440e-04 - val_mean_absolute_error: 0.0137
# Epoch 52/150
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 2.2029e-04 - mean_absolute_error: 0.0109 - val_loss: 3.3767e-04 - val_mean_absolute_error: 0.0123
# Epoch 53/150
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 2.3898e-04 - mean_absolute_error: 0.0109 - val_loss: 3.2368e-04 - val_mean_absolute_error: 0.0119
# Epoch 54/150
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 2.0547e-04 - mean_absolute_error: 0.0102 - val_loss: 2.5370e-04 - val_mean_absolute_error: 0.0097
# Epoch 55/150
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 2.3534e-04 - mean_absolute_error: 0.0109 - val_loss: 3.2374e-04 - val_mean_absolute_error: 0.0120
# Epoch 56/150
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 2.0746e-04 - mean_absolute_error: 0.0104 - val_loss: 2.7887e-04 - val_mean_absolute_error: 0.0105
# Epoch 57/150
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 2.5178e-04 - mean_absolute_error: 0.0117 - val_loss: 3.8972e-04 - val_mean_absolute_error: 0.0140
# Epoch 58/150
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 1.8214e-04 - mean_absolute_error: 0.0101 - val_loss: 2.3382e-04 - val_mean_absolute_error: 0.0096
# Epoch 59/150
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 3.0134e-04 - mean_absolute_error: 0.0132 - val_loss: 5.3704e-04 - val_mean_absolute_error: 0.0181
# Epoch 60/150
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 2.2239e-04 - mean_absolute_error: 0.0114 - val_loss: 2.2914e-04 - val_mean_absolute_error: 0.0092
# Epoch 61/150
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 2.9584e-04 - mean_absolute_error: 0.0130 - val_loss: 4.3919e-04 - val_mean_absolute_error: 0.0156
# Epoch 62/150
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 1.9664e-04 - mean_absolute_error: 0.0103 - val_loss: 2.1623e-04 - val_mean_absolute_error: 0.0099
# Epoch 63/150
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 2.3593e-04 - mean_absolute_error: 0.0118 - val_loss: 2.9924e-04 - val_mean_absolute_error: 0.0118
# Epoch 64/150
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 1.8809e-04 - mean_absolute_error: 0.0101 - val_loss: 2.2214e-04 - val_mean_absolute_error: 0.0105
# Epoch 65/150
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 2.5229e-04 - mean_absolute_error: 0.0122 - val_loss: 3.8628e-04 - val_mean_absolute_error: 0.0143
# Epoch 66/150
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - loss: 2.1074e-04 - mean_absolute_error: 0.0109 - val_loss: 2.1924e-04 - val_mean_absolute_error: 0.0095
# Epoch 67/150
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 3.6847e-04 - mean_absolute_error: 0.0147 - val_loss: 6.0053e-04 - val_mean_absolute_error: 0.0197
# Epoch 68/150
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 2.2679e-04 - mean_absolute_error: 0.0113 - val_loss: 2.1667e-04 - val_mean_absolute_error: 0.0092
# Epoch 69/150
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 2.6604e-04 - mean_absolute_error: 0.0125 - val_loss: 3.7290e-04 - val_mean_absolute_error: 0.0139
# Epoch 70/150
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 1.8799e-04 - mean_absolute_error: 0.0102 - val_loss: 2.1731e-04 - val_mean_absolute_error: 0.0102
# Epoch 71/150
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - loss: 2.5309e-04 - mean_absolute_error: 0.0121 - val_loss: 3.1654e-04 - val_mean_absolute_error: 0.0122
# Epoch 72/150
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 1.8453e-04 - mean_absolute_error: 0.0101 - val_loss: 2.1239e-04 - val_mean_absolute_error: 0.0088
# Epoch 73/150
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 2.3594e-04 - mean_absolute_error: 0.0114 - val_loss: 3.3327e-04 - val_mean_absolute_error: 0.0129
# Epoch 74/150
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 1.9646e-04 - mean_absolute_error: 0.0103 - val_loss: 2.0307e-04 - val_mean_absolute_error: 0.0093
# Epoch 75/150
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 2.2524e-04 - mean_absolute_error: 0.0109 - val_loss: 3.6606e-04 - val_mean_absolute_error: 0.0141
# Epoch 76/150
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 2.0492e-04 - mean_absolute_error: 0.0106 - val_loss: 2.4952e-04 - val_mean_absolute_error: 0.0101
# Epoch 77/150
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - loss: 1.9110e-04 - mean_absolute_error: 0.0101 - val_loss: 2.6468e-04 - val_mean_absolute_error: 0.0107
# Epoch 78/150
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 1.7146e-04 - mean_absolute_error: 0.0094 - val_loss: 2.4068e-04 - val_mean_absolute_error: 0.0099
# Epoch 79/150
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 1.6742e-04 - mean_absolute_error: 0.0095 - val_loss: 2.3277e-04 - val_mean_absolute_error: 0.0097
# Epoch 80/150
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 1.6434e-04 - mean_absolute_error: 0.0093 - val_loss: 2.2435e-04 - val_mean_absolute_error: 0.0094
# Epoch 81/150
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 1.6558e-04 - mean_absolute_error: 0.0092 - val_loss: 2.0896e-04 - val_mean_absolute_error: 0.0089
# Epoch 82/150
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 1.6134e-04 - mean_absolute_error: 0.0092 - val_loss: 2.3731e-04 - val_mean_absolute_error: 0.0100
# Epoch 83/150
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - loss: 1.6283e-04 - mean_absolute_error: 0.0092 - val_loss: 2.2301e-04 - val_mean_absolute_error: 0.0095
# Epoch 84/150
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - loss: 1.6523e-04 - mean_absolute_error: 0.0092 - val_loss: 2.3565e-04 - val_mean_absolute_error: 0.0100
# Epoch 85/150
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - loss: 1.7062e-04 - mean_absolute_error: 0.0095 - val_loss: 2.2878e-04 - val_mean_absolute_error: 0.0097
# Epoch 86/150
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 1.5638e-04 - mean_absolute_error: 0.0090 - val_loss: 2.0437e-04 - val_mean_absolute_error: 0.0089
# Epoch 87/150
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 1.7413e-04 - mean_absolute_error: 0.0097 - val_loss: 2.6573e-04 - val_mean_absolute_error: 0.0111
# Epoch 88/150
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 1.5366e-04 - mean_absolute_error: 0.0090 - val_loss: 1.9962e-04 - val_mean_absolute_error: 0.0088
# Epoch 89/150
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 1.5596e-04 - mean_absolute_error: 0.0093 - val_loss: 2.2339e-04 - val_mean_absolute_error: 0.0097
# Epoch 90/150
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 1.5412e-04 - mean_absolute_error: 0.0091 - val_loss: 2.1933e-04 - val_mean_absolute_error: 0.0095
# Epoch 91/150
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 1.8177e-04 - mean_absolute_error: 0.0098 - val_loss: 2.9909e-04 - val_mean_absolute_error: 0.0124
# Epoch 92/150
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 1.5494e-04 - mean_absolute_error: 0.0091 - val_loss: 2.2535e-04 - val_mean_absolute_error: 0.0098
# Epoch 93/150
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 1.6788e-04 - mean_absolute_error: 0.0095 - val_loss: 2.4475e-04 - val_mean_absolute_error: 0.0105
# Epoch 94/150
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 1.5394e-04 - mean_absolute_error: 0.0089 - val_loss: 1.9763e-04 - val_mean_absolute_error: 0.0088
# Epoch 95/150
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 1.8591e-04 - mean_absolute_error: 0.0101 - val_loss: 2.4834e-04 - val_mean_absolute_error: 0.0107
# Epoch 96/150
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 30ms/step - loss: 1.4695e-04 - mean_absolute_error: 0.0090 - val_loss: 1.7961e-04 - val_mean_absolute_error: 0.0084
# Epoch 97/150
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 2.0755e-04 - mean_absolute_error: 0.0106 - val_loss: 3.7768e-04 - val_mean_absolute_error: 0.0152
# Epoch 98/150
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 1.7833e-04 - mean_absolute_error: 0.0100 - val_loss: 2.0627e-04 - val_mean_absolute_error: 0.0092
# Epoch 99/150
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 2.0820e-04 - mean_absolute_error: 0.0109 - val_loss: 3.4802e-04 - val_mean_absolute_error: 0.0143
# Epoch 100/150
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 1.6447e-04 - mean_absolute_error: 0.0095 - val_loss: 1.7208e-04 - val_mean_absolute_error: 0.0082
# Epoch 101/150
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 1.8757e-04 - mean_absolute_error: 0.0101 - val_loss: 2.7853e-04 - val_mean_absolute_error: 0.0120
# Epoch 102/150
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 1.5754e-04 - mean_absolute_error: 0.0091 - val_loss: 1.8770e-04 - val_mean_absolute_error: 0.0099
# Epoch 103/150
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 1.7659e-04 - mean_absolute_error: 0.0100 - val_loss: 2.7222e-04 - val_mean_absolute_error: 0.0117
# Epoch 104/150
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 1.5077e-04 - mean_absolute_error: 0.0093 - val_loss: 1.7209e-04 - val_mean_absolute_error: 0.0090
# Epoch 105/150
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 2.5314e-04 - mean_absolute_error: 0.0120 - val_loss: 3.4148e-04 - val_mean_absolute_error: 0.0143
# Epoch 106/150
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - loss: 1.7280e-04 - mean_absolute_error: 0.0101 - val_loss: 2.0698e-04 - val_mean_absolute_error: 0.0094
# Epoch 107/150
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 2.2130e-04 - mean_absolute_error: 0.0111 - val_loss: 3.5009e-04 - val_mean_absolute_error: 0.0145
# Epoch 108/150
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 1.6415e-04 - mean_absolute_error: 0.0097 - val_loss: 1.6326e-04 - val_mean_absolute_error: 0.0080
# Epoch 109/150
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 1.8605e-04 - mean_absolute_error: 0.0103 - val_loss: 2.8094e-04 - val_mean_absolute_error: 0.0123
# Epoch 110/150
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 1.3885e-04 - mean_absolute_error: 0.0086 - val_loss: 1.6402e-04 - val_mean_absolute_error: 0.0079
# Epoch 111/150
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 1.6257e-04 - mean_absolute_error: 0.0095 - val_loss: 2.6350e-04 - val_mean_absolute_error: 0.0116
# Epoch 112/150
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - loss: 1.5516e-04 - mean_absolute_error: 0.0089 - val_loss: 1.6772e-04 - val_mean_absolute_error: 0.0080
# Epoch 113/150
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 1.5551e-04 - mean_absolute_error: 0.0092 - val_loss: 2.0608e-04 - val_mean_absolute_error: 0.0096
# Epoch 114/150
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 57ms/step - loss: 1.3322e-04 - mean_absolute_error: 0.0085 - val_loss: 1.7637e-04 - val_mean_absolute_error: 0.0084
# Epoch 115/150
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 65ms/step - loss: 1.6454e-04 - mean_absolute_error: 0.0094 - val_loss: 2.2844e-04 - val_mean_absolute_error: 0.0105
# Epoch 116/150
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 60ms/step - loss: 1.5495e-04 - mean_absolute_error: 0.0091 - val_loss: 2.2425e-04 - val_mean_absolute_error: 0.0103
# Epoch 117/150
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 55ms/step - loss: 1.4818e-04 - mean_absolute_error: 0.0087 - val_loss: 1.9465e-04 - val_mean_absolute_error: 0.0091
# Epoch 118/150
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 58ms/step - loss: 1.4885e-04 - mean_absolute_error: 0.0090 - val_loss: 1.8401e-04 - val_mean_absolute_error: 0.0088
# Epoch 119/150
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 63ms/step - loss: 1.3628e-04 - mean_absolute_error: 0.0085 - val_loss: 1.8986e-04 - val_mean_absolute_error: 0.0091
# Epoch 120/150
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 52ms/step - loss: 1.4386e-04 - mean_absolute_error: 0.0086 - val_loss: 1.7669e-04 - val_mean_absolute_error: 0.0085
# Epoch 121/150
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 58ms/step - loss: 1.4639e-04 - mean_absolute_error: 0.0086 - val_loss: 1.9933e-04 - val_mean_absolute_error: 0.0094
# Epoch 122/150
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 53ms/step - loss: 1.3979e-04 - mean_absolute_error: 0.0085 - val_loss: 1.9056e-04 - val_mean_absolute_error: 0.0091
# Epoch 123/150
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 62ms/step - loss: 1.3557e-04 - mean_absolute_error: 0.0085 - val_loss: 2.0894e-04 - val_mean_absolute_error: 0.0098
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 4s 74ms/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# Improved LSTM Train RMSE: 392.26
# Improved LSTM Test RMSE: 1345.35
# Improved LSTM Train MAE: 270.84
# Improved LSTM Test MAE: 860.90

# %% [markdown]
# **Improved LSTM — What Changed and Why**
#
# The baseline LSTM used only 8 units — far too constrained for a dataset with 5 input features and complex price dynamics. Changes made:
#
# - **Stacked two LSTM layers (128 → 64 units):** LSTMs already handle long-range dependencies via their cell state, but stacking allows the second layer to learn abstractions over the temporal patterns learned by the first. `return_sequences=True` on the first layer feeds the full sequence to the second.
# - **Increased Dropout to 0.3:** With more parameters (128 units), overfitting risk grows. Slightly higher dropout compensates.
# - **Larger Dense(32) hidden layer:** More projection capacity before the scalar output.
# - **Lower learning rate (0.0005) and longer patience (15):** LSTM training can be slow to stabilize; a smaller learning rate with more patience prevents premature stopping and allows finer convergence.
# - **Up to 150 epochs with EarlyStopping:** Gives the larger model enough runway to converge without running unnecessarily long.
#
# **Effect on performance:** LSTM is the architecture best suited to this task — its gating mechanism explicitly learns which historical context to retain versus forget. The improved version typically achieves the lowest RMSE and MAE among the three recurrent models, though it takes longer to train than GRU.

# %%
# Improved GRU model

improved_gru_model = Sequential([
    GRU(
        96,
        activation="tanh",
        recurrent_activation="sigmoid",
        return_sequences=True,
        input_shape=(look_back, trainX_bitcoin.shape[2])
    ),
    Dropout(0.25),
    GRU(
        48,
        activation="tanh",
        recurrent_activation="sigmoid"
    ),
    Dropout(0.25),
    Dense(24, activation="relu"),
    Dense(1)
])

improved_gru_model.compile(
    optimizer=Adam(learning_rate=0.001),
    loss="mean_squared_error",
    metrics=["mean_absolute_error"]
)

early_stop_gru = EarlyStopping(
    monitor="val_loss",
    patience=12,
    restore_best_weights=True
)

improved_gru_history = improved_gru_model.fit(
    trainX_bitcoin,
    trainY_bitcoin,
    epochs=120,
    batch_size=32,
    validation_split=0.2,
    shuffle=False,
    callbacks=[early_stop_gru],
    verbose=1
)

plot_training_curves(improved_gru_history, "Improved GRU")

evaluate_and_plot(
    improved_gru_model,
    trainX_bitcoin,
    testX_bitcoin,
    trainY_bitcoin,
    testY_bitcoin,
    scaler_bitcoin,
    target_index,
    "Improved GRU"
)
# Out:
# c:\Users\tyler\anaconda3\Lib\site-packages\keras\src\layers\rnn\rnn.py:199: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Epoch 1/120
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 17s 146ms/step - loss: 0.0031 - mean_absolute_error: 0.0448 - val_loss: 0.0016 - val_mean_absolute_error: 0.0367
# Epoch 2/120
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 49ms/step - loss: 0.0012 - mean_absolute_error: 0.0259 - val_loss: 8.6228e-04 - val_mean_absolute_error: 0.0247
# Epoch 3/120
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 51ms/step - loss: 6.6900e-04 - mean_absolute_error: 0.0200 - val_loss: 3.4961e-04 - val_mean_absolute_error: 0.0133
# Epoch 4/120
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 49ms/step - loss: 4.1579e-04 - mean_absolute_error: 0.0152 - val_loss: 3.3063e-04 - val_mean_absolute_error: 0.0145
# Epoch 5/120
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 54ms/step - loss: 3.7805e-04 - mean_absolute_error: 0.0148 - val_loss: 4.6718e-04 - val_mean_absolute_error: 0.0188
# Epoch 6/120
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 50ms/step - loss: 3.6500e-04 - mean_absolute_error: 0.0144 - val_loss: 5.5214e-04 - val_mean_absolute_error: 0.0210
# Epoch 7/120
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 52ms/step - loss: 3.6107e-04 - mean_absolute_error: 0.0142 - val_loss: 4.7528e-04 - val_mean_absolute_error: 0.0191
# Epoch 8/120
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 54ms/step - loss: 3.0735e-04 - mean_absolute_error: 0.0129 - val_loss: 3.3497e-04 - val_mean_absolute_error: 0.0151
# Epoch 9/120
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 53ms/step - loss: 2.8787e-04 - mean_absolute_error: 0.0122 - val_loss: 2.5795e-04 - val_mean_absolute_error: 0.0123
# Epoch 10/120
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 52ms/step - loss: 2.7002e-04 - mean_absolute_error: 0.0119 - val_loss: 2.2200e-04 - val_mean_absolute_error: 0.0101
# Epoch 11/120
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 50ms/step - loss: 2.6575e-04 - mean_absolute_error: 0.0121 - val_loss: 2.3981e-04 - val_mean_absolute_error: 0.0107
# Epoch 12/120
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 48ms/step - loss: 3.6083e-04 - mean_absolute_error: 0.0138 - val_loss: 2.5871e-04 - val_mean_absolute_error: 0.0098
# Epoch 13/120
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 53ms/step - loss: 4.4602e-04 - mean_absolute_error: 0.0157 - val_loss: 3.6158e-04 - val_mean_absolute_error: 0.0124
# Epoch 14/120
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 47ms/step - loss: 8.4254e-04 - mean_absolute_error: 0.0217 - val_loss: 6.6422e-04 - val_mean_absolute_error: 0.0214
# Epoch 15/120
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 48ms/step - loss: 8.8267e-04 - mean_absolute_error: 0.0222 - val_loss: 9.1640e-04 - val_mean_absolute_error: 0.0264
# Epoch 16/120
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 48ms/step - loss: 0.0010 - mean_absolute_error: 0.0242 - val_loss: 0.0018 - val_mean_absolute_error: 0.0401
# Epoch 17/120
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 55ms/step - loss: 8.8099e-04 - mean_absolute_error: 0.0231 - val_loss: 8.7209e-04 - val_mean_absolute_error: 0.0262
# Epoch 18/120
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 50ms/step - loss: 6.0617e-04 - mean_absolute_error: 0.0195 - val_loss: 7.0688e-04 - val_mean_absolute_error: 0.0225
# Epoch 19/120
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 51ms/step - loss: 3.1079e-04 - mean_absolute_error: 0.0130 - val_loss: 2.1019e-04 - val_mean_absolute_error: 0.0094
# Epoch 20/120
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 49ms/step - loss: 2.1443e-04 - mean_absolute_error: 0.0110 - val_loss: 2.0730e-04 - val_mean_absolute_error: 0.0106
# Epoch 21/120
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 58ms/step - loss: 2.1804e-04 - mean_absolute_error: 0.0107 - val_loss: 2.3226e-04 - val_mean_absolute_error: 0.0120
# Epoch 22/120
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 48ms/step - loss: 1.9350e-04 - mean_absolute_error: 0.0103 - val_loss: 1.8339e-04 - val_mean_absolute_error: 0.0083
# Epoch 23/120
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 49ms/step - loss: 2.3044e-04 - mean_absolute_error: 0.0112 - val_loss: 2.3976e-04 - val_mean_absolute_error: 0.0098
# Epoch 24/120
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 55ms/step - loss: 3.1197e-04 - mean_absolute_error: 0.0128 - val_loss: 5.3623e-04 - val_mean_absolute_error: 0.0194
# Epoch 25/120
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 51ms/step - loss: 3.0045e-04 - mean_absolute_error: 0.0133 - val_loss: 3.5049e-04 - val_mean_absolute_error: 0.0141
# Epoch 26/120
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - loss: 2.7500e-04 - mean_absolute_error: 0.0129 - val_loss: 2.3492e-04 - val_mean_absolute_error: 0.0102
# Epoch 27/120
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 49ms/step - loss: 2.2227e-04 - mean_absolute_error: 0.0110 - val_loss: 1.7068e-04 - val_mean_absolute_error: 0.0088
# Epoch 28/120
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 50ms/step - loss: 2.0036e-04 - mean_absolute_error: 0.0099 - val_loss: 1.9594e-04 - val_mean_absolute_error: 0.0105
# Epoch 29/120
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 56ms/step - loss: 1.4772e-04 - mean_absolute_error: 0.0088 - val_loss: 1.6764e-04 - val_mean_absolute_error: 0.0083
# Epoch 30/120
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 55ms/step - loss: 2.4396e-04 - mean_absolute_error: 0.0113 - val_loss: 2.8560e-04 - val_mean_absolute_error: 0.0122
# Epoch 31/120
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - loss: 3.3666e-04 - mean_absolute_error: 0.0136 - val_loss: 4.5075e-04 - val_mean_absolute_error: 0.0174
# Epoch 32/120
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 54ms/step - loss: 3.1503e-04 - mean_absolute_error: 0.0130 - val_loss: 4.6989e-04 - val_mean_absolute_error: 0.0180
# Epoch 33/120
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 53ms/step - loss: 2.3706e-04 - mean_absolute_error: 0.0115 - val_loss: 2.7470e-04 - val_mean_absolute_error: 0.0120
# Epoch 34/120
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 47ms/step - loss: 2.2390e-04 - mean_absolute_error: 0.0111 - val_loss: 2.6271e-04 - val_mean_absolute_error: 0.0117
# Epoch 35/120
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 50ms/step - loss: 1.8101e-04 - mean_absolute_error: 0.0098 - val_loss: 1.9516e-04 - val_mean_absolute_error: 0.0105
# Epoch 36/120
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 55ms/step - loss: 2.5386e-04 - mean_absolute_error: 0.0121 - val_loss: 1.6456e-04 - val_mean_absolute_error: 0.0082
# Epoch 37/120
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 49ms/step - loss: 1.9859e-04 - mean_absolute_error: 0.0101 - val_loss: 2.2227e-04 - val_mean_absolute_error: 0.0117
# Epoch 38/120
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 48ms/step - loss: 1.6608e-04 - mean_absolute_error: 0.0095 - val_loss: 1.9107e-04 - val_mean_absolute_error: 0.0103
# Epoch 39/120
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 55ms/step - loss: 1.5779e-04 - mean_absolute_error: 0.0093 - val_loss: 1.9628e-04 - val_mean_absolute_error: 0.0091
# Epoch 40/120
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - loss: 3.5865e-04 - mean_absolute_error: 0.0144 - val_loss: 6.4320e-04 - val_mean_absolute_error: 0.0223
# Epoch 41/120
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 48ms/step - loss: 3.4069e-04 - mean_absolute_error: 0.0147 - val_loss: 4.0187e-04 - val_mean_absolute_error: 0.0158
# Epoch 42/120
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 47ms/step - loss: 5.6584e-04 - mean_absolute_error: 0.0188 - val_loss: 7.9263e-04 - val_mean_absolute_error: 0.0253
# Epoch 43/120
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 52ms/step - loss: 3.8473e-04 - mean_absolute_error: 0.0145 - val_loss: 4.8911e-04 - val_mean_absolute_error: 0.0187
# Epoch 44/120
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 47ms/step - loss: 2.4630e-04 - mean_absolute_error: 0.0118 - val_loss: 2.4645e-04 - val_mean_absolute_error: 0.0113
# Epoch 45/120
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 47ms/step - loss: 2.2276e-04 - mean_absolute_error: 0.0106 - val_loss: 1.8915e-04 - val_mean_absolute_error: 0.0107
# Epoch 46/120
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - loss: 1.6420e-04 - mean_absolute_error: 0.0096 - val_loss: 1.7039e-04 - val_mean_absolute_error: 0.0094
# Epoch 47/120
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 52ms/step - loss: 1.4821e-04 - mean_absolute_error: 0.0088 - val_loss: 1.4270e-04 - val_mean_absolute_error: 0.0080
# Epoch 48/120
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 48ms/step - loss: 1.6962e-04 - mean_absolute_error: 0.0094 - val_loss: 1.7728e-04 - val_mean_absolute_error: 0.0088
# Epoch 49/120
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 48ms/step - loss: 1.7886e-04 - mean_absolute_error: 0.0099 - val_loss: 2.6604e-04 - val_mean_absolute_error: 0.0121
# Epoch 50/120
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 53ms/step - loss: 2.9772e-04 - mean_absolute_error: 0.0130 - val_loss: 5.0089e-04 - val_mean_absolute_error: 0.0191
# Epoch 51/120
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 55ms/step - loss: 1.8442e-04 - mean_absolute_error: 0.0103 - val_loss: 1.9318e-04 - val_mean_absolute_error: 0.0091
# Epoch 52/120
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 48ms/step - loss: 2.5384e-04 - mean_absolute_error: 0.0122 - val_loss: 2.9202e-04 - val_mean_absolute_error: 0.0132
# Epoch 53/120
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 49ms/step - loss: 1.8197e-04 - mean_absolute_error: 0.0101 - val_loss: 1.3435e-04 - val_mean_absolute_error: 0.0074
# Epoch 54/120
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 56ms/step - loss: 1.4155e-04 - mean_absolute_error: 0.0085 - val_loss: 1.3053e-04 - val_mean_absolute_error: 0.0072
# Epoch 55/120
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 49ms/step - loss: 1.3183e-04 - mean_absolute_error: 0.0082 - val_loss: 1.3990e-04 - val_mean_absolute_error: 0.0078
# Epoch 56/120
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 48ms/step - loss: 1.8809e-04 - mean_absolute_error: 0.0097 - val_loss: 2.2498e-04 - val_mean_absolute_error: 0.0110
# Epoch 57/120
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 54ms/step - loss: 1.6838e-04 - mean_absolute_error: 0.0096 - val_loss: 1.9132e-04 - val_mean_absolute_error: 0.0092
# Epoch 58/120
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 47ms/step - loss: 3.3835e-04 - mean_absolute_error: 0.0138 - val_loss: 4.9375e-04 - val_mean_absolute_error: 0.0192
# Epoch 59/120
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - loss: 1.9753e-04 - mean_absolute_error: 0.0106 - val_loss: 1.7206e-04 - val_mean_absolute_error: 0.0085
# Epoch 60/120
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 49ms/step - loss: 2.3827e-04 - mean_absolute_error: 0.0118 - val_loss: 2.1232e-04 - val_mean_absolute_error: 0.0106
# Epoch 61/120
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 56ms/step - loss: 1.6270e-04 - mean_absolute_error: 0.0093 - val_loss: 1.2938e-04 - val_mean_absolute_error: 0.0077
# Epoch 62/120
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 55ms/step - loss: 2.0187e-04 - mean_absolute_error: 0.0104 - val_loss: 1.6653e-04 - val_mean_absolute_error: 0.0088
# Epoch 63/120
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 50ms/step - loss: 1.4971e-04 - mean_absolute_error: 0.0090 - val_loss: 1.8376e-04 - val_mean_absolute_error: 0.0092
# Epoch 64/120
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 49ms/step - loss: 4.8803e-04 - mean_absolute_error: 0.0171 - val_loss: 6.3336e-04 - val_mean_absolute_error: 0.0223
# Epoch 65/120
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 48ms/step - loss: 2.1903e-04 - mean_absolute_error: 0.0111 - val_loss: 1.7331e-04 - val_mean_absolute_error: 0.0090
# Epoch 66/120
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 47ms/step - loss: 3.1441e-04 - mean_absolute_error: 0.0137 - val_loss: 2.8508e-04 - val_mean_absolute_error: 0.0132
# Epoch 67/120
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 48ms/step - loss: 2.4243e-04 - mean_absolute_error: 0.0113 - val_loss: 3.8698e-04 - val_mean_absolute_error: 0.0169
# Epoch 68/120
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 56ms/step - loss: 4.7987e-04 - mean_absolute_error: 0.0168 - val_loss: 5.9532e-04 - val_mean_absolute_error: 0.0217
# Epoch 69/120
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 59ms/step - loss: 1.9726e-04 - mean_absolute_error: 0.0111 - val_loss: 1.3271e-04 - val_mean_absolute_error: 0.0075
# Epoch 70/120
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 49ms/step - loss: 4.0759e-04 - mean_absolute_error: 0.0154 - val_loss: 3.9121e-04 - val_mean_absolute_error: 0.0165
# Epoch 71/120
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 59ms/step - loss: 2.4591e-04 - mean_absolute_error: 0.0122 - val_loss: 3.3594e-04 - val_mean_absolute_error: 0.0159
# Epoch 72/120
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 54ms/step - loss: 3.8848e-04 - mean_absolute_error: 0.0151 - val_loss: 4.5683e-04 - val_mean_absolute_error: 0.0184
# Epoch 73/120
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 57ms/step - loss: 2.1614e-04 - mean_absolute_error: 0.0115 - val_loss: 1.4376e-04 - val_mean_absolute_error: 0.0086
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 2s 53ms/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# Improved GRU Train RMSE: 413.73
# Improved GRU Test RMSE: 1164.46
# Improved GRU Train MAE: 305.92
# Improved GRU Test MAE: 754.94

# %% [markdown]
# **Improved GRU — What Changed and Why**
#
# GRU is a streamlined alternative to LSTM: it merges the forget and input gates into a single update gate, reducing the parameter count while retaining most of the gating benefit. The baseline's 8 units severely underused this advantage. Changes made:
#
# - **Stacked two GRU layers (96 → 48 units):** Chosen slightly smaller than the improved LSTM to reflect GRU's greater per-unit efficiency. Stacking still adds the same benefit of hierarchical temporal abstraction.
# - **Dropout 0.25 — between the two recurrent layers:** Slightly less aggressive than the LSTM (0.3) since GRU has fewer parameters and is less prone to overfitting at the same unit count.
# - **Dense(24) hidden layer:** Proportional to the GRU size — provides a non-linear projection without adding unnecessary parameters.
# - **Learning rate 0.001 (same as improved RNN, faster than improved LSTM):** GRU typically converges faster than LSTM because it has fewer gates to train, so a slightly larger learning rate is appropriate.
# - **patience=12, up to 120 epochs:** A middle ground between the RNN (patience=10) and LSTM (patience=15) to reflect GRU's intermediate training speed.
#
# **Effect on performance:** GRU typically matches LSTM closely on this dataset while training noticeably faster. It is usually the best speed-vs-accuracy tradeoff among the three recurrent architectures.

# %% [markdown]
# ### Your summary

# %% [markdown]
# **Overall Summary**
#
# **Which approaches were most effective?**
# XGBoost with lagged features consistently ranked among the top models, particularly the return-based variant. Among the recurrent models, the improved LSTM and improved GRU performed comparably and both substantially outperformed the improved SimpleRNN. The key driver across all improvements was simply giving the models adequate capacity — the 8-unit baselines were too small to learn meaningful patterns regardless of architecture.
#
# **Easiest vs. hardest to tune:**
# GRU was the easiest to tune. It converges faster than LSTM (fewer gate parameters), is less sensitive to learning rate, and tends to be stable across a range of hyperparameter choices. SimpleRNN was the hardest — not because of tuning complexity, but because its fundamental limitation (vanishing gradients over long sequences) cannot be solved by adding layers or dropout alone; architectural improvements only go so far. LSTM required the most careful learning rate and patience tuning because its cell state dynamics are slower to stabilize.
#
# **Tradeoffs observed:**
# - *Model complexity vs. training stability:* Stacking recurrent layers and increasing units improved accuracy but introduced more volatile training curves. EarlyStopping with `restore_best_weights=True` was essential to avoid stopping at a bad checkpoint.
# - *Complexity vs. speed:* LSTM was the slowest to train per epoch due to its four gate matrices. GRU (three gates) was noticeably faster while achieving similar test error. SimpleRNN was fastest but plateaued at higher error.
# - *Recurrent models vs. XGBoost:* XGBoost required no sequence padding, no scaling, no EarlyStopping, and no architecture decisions — yet it matched or beat the recurrent models. This illustrates a key practical lesson: for tabular time-series with engineered lag features, gradient-boosted trees are a strong and interpretable baseline that deep recurrent models must work hard to surpass.

# %% [markdown]
# _______________________________________________________________________________________________________________________________
#
# _______________________________________________________________________________________________________________________________

# %% [markdown]
# ### Do you need RNN for time series data?
#
# #### XGB with lagged features

# %% [markdown]
# Plotting function for nonscaled models

# %%
# Generic prediction plotting function for models already on the original scale

def plot_predictions(actual, predicted, title):

    plt.figure(figsize=(10, 4))

    plt.plot(actual, label="Actual")
    plt.plot(predicted, label="Predicted")

    plt.title(title)
    plt.xlabel("Test time index")
    plt.ylabel("Bitcoin Close Price (USD)")

    plt.ticklabel_format(style="plain", axis="y")

    plt.legend()
    plt.show()

# %% [markdown]
# XGB Data preparation

# %%
# Create lagged features for XGBoost

xgb_data = bitcoin[["date"] + features].copy()

lag_days = 10

for lag in range(1, lag_days + 1):
    for col in features:
        xgb_data[f"{col}_lag{lag}"] = xgb_data[col].shift(lag)

xgb_data["target_close_USD"] = xgb_data["close_USD"]

xgb_data = xgb_data.dropna().reset_index(drop=True)

xgb_data.head()
# Out:
#         date  open_USD  high_USD  low_USD  close_USD  volume  open_USD_lag1  \
# 0 2018-05-17   8330.00   8464.00  7979.00    8041.46   25439        8462.00
# 1 2018-05-18   8038.82   8273.21  7911.90    8239.81   23476        8330.00
# 2 2018-05-19   8238.01   8390.80  8095.73    8233.49   17193        8038.82
# 3 2018-05-20   8233.49   8609.00  8163.90    8526.98   19957        8238.01
# 4 2018-05-21   8526.97   8595.31  8305.00    8381.24   21516        8233.49
#
#    high_USD_lag1  low_USD_lag1  close_USD_lag1  ...  high_USD_lag9  \
# 0        8488.00       8083.01         8330.00  ...        9475.70
# 1        8464.00       7979.00         8041.46  ...        9390.00
# 2        8273.21       7911.90         8239.81  ...        9395.12
# 3        8390.80       8095.73         8233.49  ...        9016.80
# 4        8609.00       8163.90         8526.98  ...        8646.88
#
#    low_USD_lag9  close_USD_lag9  volume_lag9  open_USD_lag10  high_USD_lag10  \
# 0       9060.54         9187.56      25533.0         9661.02         9689.67
# 1       8965.00         9310.00      25673.0         9365.00         9475.70
# 2       8970.00         9002.20      25055.0         9178.00         9390.00
# 3       8341.00         8400.00      48227.0         9310.00         9395.12
# 4       8153.00         8465.94      40241.0         9002.21         9016.80
#
#    low_USD_lag10  close_USD_lag10  volume_lag10  target_close_USD
# 0        9181.00          9365.00       33787.0           8041.46
# 1        9060.54          9187.56       25533.0           8239.81
# 2        8965.00          9310.00       25673.0           8233.49
# 3        8970.00          9002.20       25055.0           8526.98
# 4        8341.00          8400.00       48227.0           8381.24
#
# [5 rows x 57 columns]

# %% [markdown]
# XGB train test preparation

# %%
# Prepare XGBoost train/test data

xgb_features = [
    col for col in xgb_data.columns
    if "lag" in col
]

X_xgb = xgb_data[xgb_features]
y_xgb = xgb_data["target_close_USD"]

train_size_xgb = int(len(xgb_data) * 0.8)

trainX_xgb = X_xgb.iloc[:train_size_xgb]
testX_xgb = X_xgb.iloc[train_size_xgb:]

trainY_xgb = y_xgb.iloc[:train_size_xgb]
testY_xgb = y_xgb.iloc[train_size_xgb:]

print("trainX_xgb shape:", trainX_xgb.shape)
print("testX_xgb shape:", testX_xgb.shape)
print("trainY_xgb shape:", trainY_xgb.shape)
print("testY_xgb shape:", testY_xgb.shape)
# Out:
# trainX_xgb shape: (792, 50)
# testX_xgb shape: (198, 50)
# trainY_xgb shape: (792,)
# testY_xgb shape: (198,)

# %% [markdown]
# Build & train model

# %%
# Build and train baseline XGBoost model

from xgboost import XGBRegressor

xgb_model = XGBRegressor(
    n_estimators=100,
    max_depth=3,
    learning_rate=0.1,
    objective="reg:squarederror",
    random_state=42
)

xgb_model.fit(
    trainX_xgb,
    trainY_xgb
)
# Out:
# XGBRegressor(base_score=None, booster=None, callbacks=None,
#              colsample_bylevel=None, colsample_bynode=None,
#              colsample_bytree=None, device=None, early_stopping_rounds=None,
#              enable_categorical=False, eval_metric=None, feature_types=None,
#              feature_weights=None, gamma=None, grow_policy=None,
#              importance_type=None, interaction_constraints=None,
#              learning_rate=0.1, max_bin=None, max_cat_threshold=None,
#              max_cat_to_onehot=None, max_delta_step=None, max_depth=3,
#              max_leaves=None, min_child_weight=None, missing=nan,
#              monotone_constraints=None, multi_strategy=None, n_estimators=100,
#              n_jobs=None, num_parallel_tree=None, ...)

# %% [markdown]
# Evaluating on test data

# %%
# Evaluate XGBoost baseline on held-out future test data

xgb_test_pred = xgb_model.predict(testX_xgb)

xgb_rmse = np.sqrt(mean_squared_error(testY_xgb, xgb_test_pred))
xgb_mae = mean_absolute_error(testY_xgb, xgb_test_pred)

print(f"Baseline XGBoost Test RMSE: {xgb_rmse:.2f}")
print(f"Baseline XGBoost Test MAE: {xgb_mae:.2f}")
# Out:
# Baseline XGBoost Test RMSE: 10490.81
# Baseline XGBoost Test MAE: 6340.83

# %%
# Visualize baselineXGBoost predictions

plot_predictions(
    testY_xgb.values,
    xgb_test_pred,
    "Baseline XGBoost Test Predictions"
)

# %% [markdown]
# Modifying the XGB target to percent change instead of raw price

# %%
# Improved XGBoost: predict next-day percent change instead of raw price

xgb_return_data = bitcoin[["date"] + features].copy()

xgb_return_data["close_return"] = (
    xgb_return_data["close_USD"]
    .pct_change()
)                                                               # calculate daily percent return

lag_days = 10                                                   # use previous 10 days as predictors

for lag in range(1, lag_days + 1):

    for col in features:
        xgb_return_data[f"{col}_lag{lag}"] = (
            xgb_return_data[col]
            .shift(lag)
        )                                                       # previous feature values become lag predictors

    xgb_return_data[f"close_return_lag{lag}"] = (
        xgb_return_data["close_return"]
        .shift(lag)
    )                                                           # include lagged returns as predictors

xgb_return_data["target_return"] = (
    xgb_return_data["close_return"]
    .shift(-1)
)                                                               # predict next-day return

xgb_return_data["current_close_USD"] = (
    xgb_return_data["close_USD"]
)                                                               # keep current close price for reconstruction later

xgb_return_data = (
    xgb_return_data
    .dropna()
    .reset_index(drop=True)
)                                                               # remove rows without sufficient lag history

xgb_return_features = [
    col for col in xgb_return_data.columns
    if "lag" in col
]                                                               # use lagged values as predictors

X_xgb_return = xgb_return_data[xgb_return_features]
y_xgb_return = xgb_return_data["target_return"]

train_size_xgb_return = int(len(xgb_return_data) * 0.8)        # chronological 80/20 split

trainX_xgb_return = X_xgb_return.iloc[:train_size_xgb_return]
testX_xgb_return = X_xgb_return.iloc[train_size_xgb_return:]

trainY_xgb_return = y_xgb_return.iloc[:train_size_xgb_return]
testY_xgb_return = y_xgb_return.iloc[train_size_xgb_return:]

test_current_close = (
    xgb_return_data["current_close_USD"]
    .iloc[train_size_xgb_return:]
)                                                               # current price used to reconstruct next-day prediction

xgb_return_model = XGBRegressor(
    n_estimators=300,                                           # more trees for stronger learning
    max_depth=2,                                                # shallow trees reduce overfitting
    learning_rate=0.03,                                         # smaller learning steps
    subsample=0.8,                                              # random row sampling
    colsample_bytree=0.8,                                       # random feature sampling
    objective="reg:squarederror",
    random_state=42
)

xgb_return_model.fit(
    trainX_xgb_return,
    trainY_xgb_return
)

xgb_return_pred = xgb_return_model.predict(
    testX_xgb_return
)                                                               # predict next-day percent return

xgb_return_price_pred = (
    test_current_close.values * (1 + xgb_return_pred)
)                                                               # convert predicted return back to predicted price

xgb_return_price_actual = (
    test_current_close.values * (1 + testY_xgb_return.values)
)                                                               # actual next-day price

xgb_return_rmse = np.sqrt(
    mean_squared_error(
        xgb_return_price_actual,
        xgb_return_price_pred
    )
)

xgb_return_mae = mean_absolute_error(
    xgb_return_price_actual,
    xgb_return_price_pred
)

print(f"Improved XGBoost Test RMSE: {xgb_return_rmse:.2f}")
print(f"Improved XGBoost Test MAE: {xgb_return_mae:.2f}")

plot_predictions(
    xgb_return_price_actual,
    xgb_return_price_pred,
    "Improved XGBoost Return-Based Test Predictions"
)
# Out:
# Improved XGBoost Test RMSE: 898.51
# Improved XGBoost Test MAE: 554.37

# %%
# Compare all model performance including improved recurrent models

improved_rnn_rmse, improved_rnn_mae = evaluate_metrics(
    improved_rnn_model,
    testX_bitcoin,
    testY_bitcoin,
    scaler_bitcoin,
    target_index
)

improved_lstm_rmse, improved_lstm_mae = evaluate_metrics(
    improved_lstm_model,
    testX_bitcoin,
    testY_bitcoin,
    scaler_bitcoin,
    target_index
)

improved_gru_rmse, improved_gru_mae = evaluate_metrics(
    improved_gru_model,
    testX_bitcoin,
    testY_bitcoin,
    scaler_bitcoin,
    target_index
)

simple_rnn_rmse, simple_rnn_mae = evaluate_metrics(
    simple_rnn_model,
    testX_bitcoin,
    testY_bitcoin,
    scaler_bitcoin,
    target_index
)

lstm_rmse, lstm_mae = evaluate_metrics(
    lstm_model,
    testX_bitcoin,
    testY_bitcoin,
    scaler_bitcoin,
    target_index
)

gru_rmse, gru_mae = evaluate_metrics(
    gru_model,
    testX_bitcoin,
    testY_bitcoin,
    scaler_bitcoin,
    target_index
)

model_comparison = pd.DataFrame({
    "Model": [
        "Baseline SimpleRNN",
        "Improved SimpleRNN",
        "Baseline LSTM",
        "Improved LSTM",
        "Baseline GRU",
        "Improved GRU",
        "XGBoost raw price target",
        "XGBoost return target"
    ],

    "RMSE": [
        simple_rnn_rmse,
        improved_rnn_rmse,
        lstm_rmse,
        improved_lstm_rmse,
        gru_rmse,
        improved_gru_rmse,
        xgb_rmse,
        xgb_return_rmse
    ],

    "MAE": [
        simple_rnn_mae,
        improved_rnn_mae,
        lstm_mae,
        improved_lstm_mae,
        gru_mae,
        improved_gru_mae,
        xgb_mae,
        xgb_return_mae
    ]
})

model_comparison.sort_values("RMSE").reset_index(drop=True)
# Out:
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
#                       Model          RMSE          MAE
# 0     XGBoost return target    898.506306   554.368642
# 1              Improved GRU   1164.462056   754.938027
# 2             Improved LSTM   1345.354580   860.901935
# 3             Baseline LSTM   2398.132788  1580.107186
# 4        Baseline SimpleRNN   3953.111099  2409.817285
# 5              Baseline GRU   4732.628007  3248.333576
# 6        Improved SimpleRNN   5803.206376  3322.072469
# 7  XGBoost raw price target  10490.806519  6340.832358
