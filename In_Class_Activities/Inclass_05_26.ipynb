# %% [markdown]
# # RNN Day 1 Housing Data

# %% [markdown]
# ### Importing Libraries

# %%
import pandas as pd                                 # table/dataframe handling
import numpy as np                                  # numerical operations
import matplotlib.pyplot as plt                     # plotting

from sklearn.preprocessing import MinMaxScaler      # scales values to 0-1 range
from sklearn.metrics import mean_absolute_error, mean_squared_error 
                                                    # RMSE and MAE calculation

import tensorflow as tf
import random

from tensorflow.keras.models import Sequential      # sequential neural network API

from tensorflow.keras.layers import (
    Dense,                                          # standard fully connected layer
    SimpleRNN,                                      # recurrent neural network layer
    Conv1D,                                         # 1D convolution layer
    Flatten                                         # flatten multidimensional output
)

random.seed(42)
np.random.seed(42)
tf.random.set_seed(42)

# %% [markdown]
# ### Loading the data

# %%
house = pd.read_csv("../datasets/ma_lga_12345.csv")   # load housing dataset

house.head()                              # inspect first few rows
# Out:
#      saledate      MA   type  bedrooms
# 0  30/09/2007  441854  house         2
# 1  31/12/2007  441854  house         2
# 2  31/03/2008  441854  house         2
# 3  30/06/2008  441854  house         2
# 4  30/09/2008  451583  house         2

# %% [markdown]
# ### Inspecting the temporal nature of the data

# %%
print(house.shape)            # number of rows and columns
print(house.dtypes)           # variable data types
print(house.isna().sum())     # missing values per column

house.describe()              # summary statistics
# Out:
# (347, 4)
# saledate      str
# MA          int64
# type          str
# bedrooms    int64
# dtype: object
# saledate    0
# MA          0
# type        0
# bedrooms    0
# dtype: int64
#                  MA    bedrooms
# count  3.470000e+02  347.000000
# mean   5.481320e+05    2.867435
# std    1.701934e+05    1.239875
# min    3.167510e+05    1.000000
# 25%    4.277395e+05    2.000000
# 50%    5.077440e+05    3.000000
# 75%    6.275155e+05    4.000000
# max    1.017752e+06    5.000000

# %% [markdown]
# ## Defining useful functions

# %% [markdown]
# Formatting data for rolling windows

# %%
def create_sequences(dataset, look_back=2):

    X, y = [], []                          # containers for windows and targets

    for i in range(len(dataset) - look_back):

        X.append(dataset[i:i + look_back, :])   # rolling window
        y.append(dataset[i + look_back, 0])     # next timestep target

    return np.array(X), np.array(y)

# %% [markdown]
# Plotting training curves

# %%
def plot_training_curves(history, title):

    fig, axes = plt.subplots(1, 2, figsize=(12, 4))

    axes[0].plot(history.history["loss"], label="Training Loss")
    axes[0].plot(history.history["val_loss"], label="Validation Loss")
    axes[0].set_title(title + " Loss")
    axes[0].set_xlabel("Epoch")
    axes[0].set_ylabel("MSE Loss")
    axes[0].set_ylim(0, 0.4)
    axes[0].legend()

    axes[1].plot(history.history["mean_absolute_error"], label="Training MAE")
    axes[1].plot(history.history["val_mean_absolute_error"], label="Validation MAE")
    axes[1].set_title(title + " MAE")
    axes[1].set_xlabel("Epoch")
    axes[1].set_ylabel("Mean Absolute Error")
    axes[1].set_ylim(0, 0.65)
    axes[1].legend()

    plt.tight_layout()
    plt.show()

# %% [markdown]
# Evaluating model performance on test data

# %%
def evaluate_and_plot(model, trainX, testX, trainY, testY, scaler, title):

    # Make predictions
    train_pred = model.predict(trainX)
    test_pred = model.predict(testX)

    # Convert scaled values back to original MA scale
    train_pred_inv = scaler.inverse_transform(train_pred)
    test_pred_inv = scaler.inverse_transform(test_pred)
    trainY_inv = scaler.inverse_transform(trainY.reshape(-1, 1))
    testY_inv = scaler.inverse_transform(testY.reshape(-1, 1))

    # Calculate RMSE on original scale
    train_rmse = np.sqrt(mean_squared_error(trainY_inv, train_pred_inv))
    test_rmse = np.sqrt(mean_squared_error(testY_inv, test_pred_inv))

    print(f"{title} Train RMSE: {train_rmse:.2f}")
    print(f"{title} Test RMSE: {test_rmse:.2f}")

    # Plot held-out future test predictions
    plt.figure(figsize=(10, 4))
    plt.plot(testY_inv, label="Actual")
    plt.plot(test_pred_inv, label="Predicted")

    plt.title(title + " Test Predictions")
    plt.xlabel("Test time index")
    plt.ylabel("MA")
    plt.ylim(0, 1200000)
    plt.ticklabel_format(style="plain", axis="y")
    plt.legend()
    plt.show()

# %% [markdown]
# Comparing forcasting performance metrics

# %%
def evaluate_metrics(model, testX, testY, scaler):

    test_pred = model.predict(testX)

    test_pred_inv = scaler.inverse_transform(test_pred)
    testY_inv = scaler.inverse_transform(testY.reshape(-1, 1))

    rmse = np.sqrt(mean_squared_error(testY_inv, test_pred_inv))
    mae = mean_absolute_error(testY_inv, test_pred_inv)

    return rmse, mae

# %% [markdown]
# ### Initial RNN & Performance

# %%
# Initial RNN

ma_sequence = house.copy()
ma_sequence = ma_sequence.sort_values("saledate").reset_index(drop=True)
                                                                # preserve chronological order

df_initial = ma_sequence[["MA"]].copy()                         # univariate forecasting feature

scaler_initial = MinMaxScaler(feature_range=(0, 1))
scaled_initial = scaler_initial.fit_transform(df_initial)
                                                                # neural networks train better on scaled values

look_back = 2                                                   # use previous 2 timesteps to predict next timestep

train_size = int(len(scaled_initial) * 0.8)

train_initial = scaled_initial[:train_size]                     # earlier historical data
test_initial = scaled_initial[train_size:]                      # held-out future data

trainX_initial, trainY_initial = create_sequences(
    train_initial,
    look_back
)                                                               # rolling training windows

testX_initial, testY_initial = create_sequences(
    test_initial,
    look_back
)                                                               # rolling future test windows

print("trainX shape:", trainX_initial.shape)
print("testX shape:", testX_initial.shape)

initial_model = Sequential([
    SimpleRNN(
        16,
        activation="tanh",
        input_shape=(look_back, trainX_initial.shape[2])
    ),                                                          # recurrent hidden layer

    Dense(1)                                                    # regression output layer
])

initial_model.compile(
    optimizer="adam",
    loss="mean_squared_error",
    metrics=["mean_absolute_error"]
)

initial_history = initial_model.fit(
    trainX_initial,
    trainY_initial,
    epochs=100,
    batch_size=8,
    validation_split=0.2,
    shuffle=False,                                              # preserve temporal order
    verbose=1
)
# Out:
# trainX shape: (275, 2, 1)
# testX shape: (68, 2, 1)
# WARNING:tensorflow:TensorFlow GPU support is not available on native Windows for TensorFlow >= 2.11. Even if CUDA/cuDNN are installed, GPU will not be used. Please use WSL2 or the TensorFlow-DirectML plugin.
# Epoch 1/100
# c:\Users\tyler\anaconda3\Lib\site-packages\keras\src\layers\rnn\rnn.py:199: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - loss: 0.0837 - mean_absolute_error: 0.2303 - val_loss: 0.0884 - val_mean_absolute_error: 0.2418
# Epoch 2/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0671 - mean_absolute_error: 0.2065 - val_loss: 0.0744 - val_mean_absolute_error: 0.2194
# Epoch 3/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0588 - mean_absolute_error: 0.1904 - val_loss: 0.0669 - val_mean_absolute_error: 0.2029
# Epoch 4/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0547 - mean_absolute_error: 0.1817 - val_loss: 0.0631 - val_mean_absolute_error: 0.1940
# Epoch 5/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0528 - mean_absolute_error: 0.1778 - val_loss: 0.0613 - val_mean_absolute_error: 0.1888
# Epoch 6/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0518 - mean_absolute_error: 0.1758 - val_loss: 0.0604 - val_mean_absolute_error: 0.1859
# Epoch 7/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0513 - mean_absolute_error: 0.1746 - val_loss: 0.0600 - val_mean_absolute_error: 0.1844
# Epoch 8/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0510 - mean_absolute_error: 0.1738 - val_loss: 0.0598 - val_mean_absolute_error: 0.1836
# Epoch 9/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0508 - mean_absolute_error: 0.1733 - val_loss: 0.0596 - val_mean_absolute_error: 0.1830
# Epoch 10/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0507 - mean_absolute_error: 0.1729 - val_loss: 0.0595 - val_mean_absolute_error: 0.1826
# Epoch 11/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0506 - mean_absolute_error: 0.1725 - val_loss: 0.0595 - val_mean_absolute_error: 0.1823
# Epoch 12/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0505 - mean_absolute_error: 0.1722 - val_loss: 0.0594 - val_mean_absolute_error: 0.1821
# Epoch 13/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0504 - mean_absolute_error: 0.1720 - val_loss: 0.0594 - val_mean_absolute_error: 0.1819
# Epoch 14/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0503 - mean_absolute_error: 0.1718 - val_loss: 0.0593 - val_mean_absolute_error: 0.1818
# Epoch 15/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0502 - mean_absolute_error: 0.1716 - val_loss: 0.0593 - val_mean_absolute_error: 0.1816
# Epoch 16/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0501 - mean_absolute_error: 0.1714 - val_loss: 0.0592 - val_mean_absolute_error: 0.1815
# Epoch 17/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0501 - mean_absolute_error: 0.1713 - val_loss: 0.0592 - val_mean_absolute_error: 0.1813
# Epoch 18/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0500 - mean_absolute_error: 0.1711 - val_loss: 0.0592 - val_mean_absolute_error: 0.1812
# Epoch 19/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0500 - mean_absolute_error: 0.1710 - val_loss: 0.0591 - val_mean_absolute_error: 0.1811
# Epoch 20/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0499 - mean_absolute_error: 0.1709 - val_loss: 0.0591 - val_mean_absolute_error: 0.1810
# Epoch 21/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0499 - mean_absolute_error: 0.1707 - val_loss: 0.0590 - val_mean_absolute_error: 0.1809
# Epoch 22/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0498 - mean_absolute_error: 0.1706 - val_loss: 0.0590 - val_mean_absolute_error: 0.1807
# Epoch 23/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0497 - mean_absolute_error: 0.1705 - val_loss: 0.0589 - val_mean_absolute_error: 0.1806
# Epoch 24/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0497 - mean_absolute_error: 0.1704 - val_loss: 0.0589 - val_mean_absolute_error: 0.1805
# Epoch 25/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0496 - mean_absolute_error: 0.1703 - val_loss: 0.0588 - val_mean_absolute_error: 0.1804
# Epoch 26/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0496 - mean_absolute_error: 0.1702 - val_loss: 0.0588 - val_mean_absolute_error: 0.1803
# Epoch 27/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0495 - mean_absolute_error: 0.1701 - val_loss: 0.0587 - val_mean_absolute_error: 0.1802
# Epoch 28/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0495 - mean_absolute_error: 0.1700 - val_loss: 0.0587 - val_mean_absolute_error: 0.1801
# Epoch 29/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0495 - mean_absolute_error: 0.1699 - val_loss: 0.0586 - val_mean_absolute_error: 0.1801
# Epoch 30/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0494 - mean_absolute_error: 0.1698 - val_loss: 0.0586 - val_mean_absolute_error: 0.1800
# Epoch 31/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0494 - mean_absolute_error: 0.1697 - val_loss: 0.0585 - val_mean_absolute_error: 0.1799
# Epoch 32/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0493 - mean_absolute_error: 0.1696 - val_loss: 0.0584 - val_mean_absolute_error: 0.1798
# Epoch 33/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0493 - mean_absolute_error: 0.1695 - val_loss: 0.0584 - val_mean_absolute_error: 0.1797
# Epoch 34/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0492 - mean_absolute_error: 0.1694 - val_loss: 0.0583 - val_mean_absolute_error: 0.1796
# Epoch 35/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0492 - mean_absolute_error: 0.1693 - val_loss: 0.0582 - val_mean_absolute_error: 0.1795
# Epoch 36/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0491 - mean_absolute_error: 0.1692 - val_loss: 0.0582 - val_mean_absolute_error: 0.1794
# Epoch 37/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0491 - mean_absolute_error: 0.1691 - val_loss: 0.0581 - val_mean_absolute_error: 0.1793
# Epoch 38/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0490 - mean_absolute_error: 0.1690 - val_loss: 0.0581 - val_mean_absolute_error: 0.1792
# Epoch 39/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0489 - mean_absolute_error: 0.1689 - val_loss: 0.0580 - val_mean_absolute_error: 0.1790
# Epoch 40/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0489 - mean_absolute_error: 0.1689 - val_loss: 0.0579 - val_mean_absolute_error: 0.1789
# Epoch 41/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0488 - mean_absolute_error: 0.1688 - val_loss: 0.0578 - val_mean_absolute_error: 0.1788
# Epoch 42/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0488 - mean_absolute_error: 0.1687 - val_loss: 0.0578 - val_mean_absolute_error: 0.1787
# Epoch 43/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0487 - mean_absolute_error: 0.1686 - val_loss: 0.0577 - val_mean_absolute_error: 0.1786
# Epoch 44/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0487 - mean_absolute_error: 0.1685 - val_loss: 0.0576 - val_mean_absolute_error: 0.1785
# Epoch 45/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0486 - mean_absolute_error: 0.1684 - val_loss: 0.0575 - val_mean_absolute_error: 0.1784
# Epoch 46/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0486 - mean_absolute_error: 0.1683 - val_loss: 0.0575 - val_mean_absolute_error: 0.1783
# Epoch 47/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0485 - mean_absolute_error: 0.1682 - val_loss: 0.0574 - val_mean_absolute_error: 0.1782
# Epoch 48/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0484 - mean_absolute_error: 0.1681 - val_loss: 0.0573 - val_mean_absolute_error: 0.1781
# Epoch 49/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0484 - mean_absolute_error: 0.1680 - val_loss: 0.0572 - val_mean_absolute_error: 0.1780
# Epoch 50/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0483 - mean_absolute_error: 0.1679 - val_loss: 0.0571 - val_mean_absolute_error: 0.1779
# Epoch 51/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0483 - mean_absolute_error: 0.1678 - val_loss: 0.0571 - val_mean_absolute_error: 0.1778
# Epoch 52/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0482 - mean_absolute_error: 0.1677 - val_loss: 0.0570 - val_mean_absolute_error: 0.1777
# Epoch 53/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0481 - mean_absolute_error: 0.1676 - val_loss: 0.0569 - val_mean_absolute_error: 0.1776
# Epoch 54/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0481 - mean_absolute_error: 0.1675 - val_loss: 0.0568 - val_mean_absolute_error: 0.1774
# Epoch 55/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0480 - mean_absolute_error: 0.1674 - val_loss: 0.0567 - val_mean_absolute_error: 0.1774
# Epoch 56/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0480 - mean_absolute_error: 0.1673 - val_loss: 0.0566 - val_mean_absolute_error: 0.1773
# Epoch 57/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0479 - mean_absolute_error: 0.1671 - val_loss: 0.0565 - val_mean_absolute_error: 0.1772
# Epoch 58/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0478 - mean_absolute_error: 0.1670 - val_loss: 0.0564 - val_mean_absolute_error: 0.1771
# Epoch 59/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0478 - mean_absolute_error: 0.1669 - val_loss: 0.0564 - val_mean_absolute_error: 0.1770
# Epoch 60/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0477 - mean_absolute_error: 0.1668 - val_loss: 0.0563 - val_mean_absolute_error: 0.1769
# Epoch 61/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0476 - mean_absolute_error: 0.1667 - val_loss: 0.0562 - val_mean_absolute_error: 0.1769
# Epoch 62/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0476 - mean_absolute_error: 0.1666 - val_loss: 0.0561 - val_mean_absolute_error: 0.1768
# Epoch 63/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0475 - mean_absolute_error: 0.1665 - val_loss: 0.0560 - val_mean_absolute_error: 0.1767
# Epoch 64/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0474 - mean_absolute_error: 0.1664 - val_loss: 0.0559 - val_mean_absolute_error: 0.1766
# Epoch 65/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0474 - mean_absolute_error: 0.1662 - val_loss: 0.0558 - val_mean_absolute_error: 0.1765
# Epoch 66/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0473 - mean_absolute_error: 0.1661 - val_loss: 0.0557 - val_mean_absolute_error: 0.1765
# Epoch 67/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0472 - mean_absolute_error: 0.1660 - val_loss: 0.0556 - val_mean_absolute_error: 0.1764
# Epoch 68/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0472 - mean_absolute_error: 0.1659 - val_loss: 0.0555 - val_mean_absolute_error: 0.1763
# Epoch 69/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0471 - mean_absolute_error: 0.1658 - val_loss: 0.0554 - val_mean_absolute_error: 0.1762
# Epoch 70/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0471 - mean_absolute_error: 0.1657 - val_loss: 0.0553 - val_mean_absolute_error: 0.1762
# Epoch 71/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0470 - mean_absolute_error: 0.1655 - val_loss: 0.0552 - val_mean_absolute_error: 0.1761
# Epoch 72/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0469 - mean_absolute_error: 0.1654 - val_loss: 0.0551 - val_mean_absolute_error: 0.1760
# Epoch 73/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0469 - mean_absolute_error: 0.1653 - val_loss: 0.0550 - val_mean_absolute_error: 0.1759
# Epoch 74/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0468 - mean_absolute_error: 0.1652 - val_loss: 0.0550 - val_mean_absolute_error: 0.1759
# Epoch 75/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0467 - mean_absolute_error: 0.1651 - val_loss: 0.0549 - val_mean_absolute_error: 0.1758
# Epoch 76/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0467 - mean_absolute_error: 0.1649 - val_loss: 0.0548 - val_mean_absolute_error: 0.1757
# Epoch 77/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0466 - mean_absolute_error: 0.1648 - val_loss: 0.0547 - val_mean_absolute_error: 0.1756
# Epoch 78/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0466 - mean_absolute_error: 0.1647 - val_loss: 0.0546 - val_mean_absolute_error: 0.1755
# Epoch 79/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0465 - mean_absolute_error: 0.1646 - val_loss: 0.0545 - val_mean_absolute_error: 0.1754
# Epoch 80/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0464 - mean_absolute_error: 0.1645 - val_loss: 0.0544 - val_mean_absolute_error: 0.1754
# Epoch 81/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0464 - mean_absolute_error: 0.1644 - val_loss: 0.0543 - val_mean_absolute_error: 0.1753
# Epoch 82/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0463 - mean_absolute_error: 0.1643 - val_loss: 0.0543 - val_mean_absolute_error: 0.1752
# Epoch 83/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0463 - mean_absolute_error: 0.1642 - val_loss: 0.0542 - val_mean_absolute_error: 0.1751
# Epoch 84/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0462 - mean_absolute_error: 0.1640 - val_loss: 0.0541 - val_mean_absolute_error: 0.1750
# Epoch 85/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0462 - mean_absolute_error: 0.1639 - val_loss: 0.0540 - val_mean_absolute_error: 0.1749
# Epoch 86/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0461 - mean_absolute_error: 0.1638 - val_loss: 0.0539 - val_mean_absolute_error: 0.1748
# Epoch 87/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0461 - mean_absolute_error: 0.1637 - val_loss: 0.0539 - val_mean_absolute_error: 0.1747
# Epoch 88/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0460 - mean_absolute_error: 0.1636 - val_loss: 0.0538 - val_mean_absolute_error: 0.1746
# Epoch 89/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0460 - mean_absolute_error: 0.1635 - val_loss: 0.0537 - val_mean_absolute_error: 0.1745
# Epoch 90/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0459 - mean_absolute_error: 0.1634 - val_loss: 0.0537 - val_mean_absolute_error: 0.1744
# Epoch 91/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0459 - mean_absolute_error: 0.1633 - val_loss: 0.0536 - val_mean_absolute_error: 0.1743
# Epoch 92/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0458 - mean_absolute_error: 0.1632 - val_loss: 0.0535 - val_mean_absolute_error: 0.1742
# Epoch 93/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0458 - mean_absolute_error: 0.1632 - val_loss: 0.0535 - val_mean_absolute_error: 0.1741
# Epoch 94/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0457 - mean_absolute_error: 0.1631 - val_loss: 0.0534 - val_mean_absolute_error: 0.1740
# Epoch 95/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0457 - mean_absolute_error: 0.1630 - val_loss: 0.0533 - val_mean_absolute_error: 0.1739
# Epoch 96/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0456 - mean_absolute_error: 0.1630 - val_loss: 0.0533 - val_mean_absolute_error: 0.1738
# Epoch 97/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0456 - mean_absolute_error: 0.1629 - val_loss: 0.0532 - val_mean_absolute_error: 0.1737
# Epoch 98/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0456 - mean_absolute_error: 0.1628 - val_loss: 0.0531 - val_mean_absolute_error: 0.1736
# Epoch 99/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0455 - mean_absolute_error: 0.1628 - val_loss: 0.0531 - val_mean_absolute_error: 0.1734
# Epoch 100/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0455 - mean_absolute_error: 0.1627 - val_loss: 0.0530 - val_mean_absolute_error: 0.1733

# %% [markdown]
# Training curves

# %%
plot_training_curves(
    initial_history,
    "Initial RNN"
)

# %% [markdown]
# Test data evaluation

# %%
evaluate_and_plot(
    initial_model,
    trainX_initial,
    testX_initial,
    trainY_initial,
    testY_initial,
    scaler_initial,
    "Initial RNN"
)
# Out:
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# Initial RNN Train RMSE: 150505.92
# Initial RNN Test RMSE: 150254.05

# %% [markdown]
# ### Initial MA data re-evaluation

# %%
# Plot the original MA sequence exactly as provided

plt.figure(figsize=(10, 4))

plt.plot(
    ma_sequence["saledate"],
    ma_sequence["MA"]
)

plt.title("Original MA sequence")
plt.xlabel("Date")
plt.ylabel("MA")

plt.ylim(0, 1200000)

plt.ticklabel_format(
    style='plain',
    axis='y'
)                                        

plt.xticks(rotation=45)

plt.show()

# %%
# Plot each subgroup MA sequence separately

house["saledate"] = pd.to_datetime(
    house["saledate"],
    dayfirst=True
)

# Plot each subgroup MA sequence separately

house["saledate"] = pd.to_datetime(
    house["saledate"],
    dayfirst=True
)

plt.figure(figsize=(12, 6))

for (property_type, bedrooms), group in house.groupby(["type", "bedrooms"]):

    group = group.sort_values("saledate")      # chronological ordering

    plt.plot(
        group["saledate"],
        group["MA"],
        label=f"{property_type}, {bedrooms} bed"
    )

plt.title("MA sequences by property subgroup")

plt.xlabel("Date")
plt.ylabel("MA")

plt.ylim(0, 1200000)

plt.ticklabel_format(
    style='plain',
    axis='y'
)

plt.xticks(rotation=45)

plt.legend(
    bbox_to_anchor=(1.05, 1),
    loc="upper left"
)

plt.tight_layout()

plt.show()

# %% [markdown]
# Inspecting the first window

# %%
print("trainX_initial shape:", trainX_initial.shape)

window_id = 0

ma_sequence.iloc[
    window_id : window_id + look_back + 1
][["saledate", "type", "bedrooms", "MA"]]
# Out:
# trainX_initial shape: (275, 2, 1)
#      saledate   type  bedrooms      MA
# 0  30/06/2007  house         3  421291
# 1  30/06/2007  house         4  548969
# 2  30/06/2007   unit         2  368817

# %% [markdown]
# ### Creating market-level MA data

# %%
# Create market-level MA sequence

house["saledate"] = pd.to_datetime(
    house["saledate"],
    dayfirst=True
)                                                    # ensure dates sort chronologically

market_ma = (
    house
    .groupby("saledate")["MA"]
    .mean()
    .reset_index()
    .sort_values("saledate")
    .reset_index(drop=True)
)                                                    # average subgroup MAs per date

# Visualize market-level MA

plt.figure(figsize=(10, 4))

plt.plot(
    market_ma["saledate"],
    market_ma["MA"]
)

plt.title("Market-level MA: one average value per date")
plt.xlabel("Date")
plt.ylabel("Average MA")

plt.ylim(0, 1200000)
plt.ticklabel_format(style="plain", axis="y")
plt.xticks(rotation=45)

plt.show()

# %% [markdown]
# ### Preparing market-level MA data for variety of models

# %%
# Prepare market-level MA data for all fixed-data models

df_market = market_ma[["MA"]].copy()                            # cleaned one-value-per-date MA series

scaler_market = MinMaxScaler(feature_range=(0, 1))              # scale MA values for neural networks
scaled_market = scaler_market.fit_transform(df_market)

look_back = 2                                                   # use 2 previous timesteps to predict next timestep

train_size = int(len(scaled_market) * 0.8)                      # chronological 80/20 split

train_market = scaled_market[:train_size]                       # earlier historical data
test_market = scaled_market[train_size:]                        # held-out future data

trainX_market, trainY_market = create_sequences(
    train_market,
    look_back
)                                                               # sequence windows for RNN/CNN

testX_market, testY_market = create_sequences(
    test_market,
    look_back
)                                                               # future test windows for RNN/CNN

trainX_market_mlp = trainX_market.reshape(
    trainX_market.shape[0],
    trainX_market.shape[1] * trainX_market.shape[2]
)                                                               # flattened windows for MLP

testX_market_mlp = testX_market.reshape(
    testX_market.shape[0],
    testX_market.shape[1] * testX_market.shape[2]
)                                                               # flattened test windows for MLP

print("RNN/CNN trainX_market shape:", trainX_market.shape)
print("RNN/CNN testX_market shape:", testX_market.shape)

print("MLP trainX_market_mlp shape:", trainX_market_mlp.shape)
print("MLP testX_market_mlp shape:", testX_market_mlp.shape)
# Out:
# RNN/CNN trainX_market shape: (38, 2, 1)
# RNN/CNN testX_market shape: (9, 2, 1)
# MLP trainX_market_mlp shape: (38, 2)
# MLP testX_market_mlp shape: (9, 2)

# %% [markdown]
# ### Inspecting the tensors

# %% [markdown]
# Shape & window 0 values

# %%
print("trainX_market shape:", trainX_market.shape)

window_id = 0

market_ma.iloc[
    window_id : window_id + look_back + 1
][["saledate", "MA"]]
# Out:
# trainX_market shape: (38, 2, 1)
#     saledate             MA
# 0 2007-03-31  485130.000000
# 1 2007-06-30  446359.000000
# 2 2007-09-30  505957.666667

# %% [markdown]
# Scale window 0

# %%
# Visualize one input window and its target

window_id = 0

print("Input window:")
print(trainX_market[window_id].flatten())

print("Target:")
print(trainY_market[window_id])
# Out:
# Input window:
# [0.22095731 0.        ]
# Target:
# 0.33965492068299463

# %% [markdown]
# ### Market-level RNN model & evaluation

# %%
# Build and train market-level RNN model

market_rnn_model = Sequential([
    SimpleRNN(
        16,
        activation="tanh",
        input_shape=(look_back, trainX_market.shape[2])
    ),
    Dense(1)
])

market_rnn_model.compile(
    optimizer="adam",
    loss="mean_squared_error",
    metrics=["mean_absolute_error"]
)

market_rnn_history = market_rnn_model.fit(
    trainX_market,
    trainY_market,
    epochs=100,
    batch_size=8,
    validation_split=0.2,
    shuffle=False,
    verbose=1
)
# Out:
# Epoch 1/100
# c:\Users\tyler\anaconda3\Lib\site-packages\keras\src\layers\rnn\rnn.py:199: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 74ms/step - loss: 0.0500 - mean_absolute_error: 0.2169 - val_loss: 0.1204 - val_mean_absolute_error: 0.3453
# Epoch 2/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0223 - mean_absolute_error: 0.1427 - val_loss: 0.0597 - val_mean_absolute_error: 0.2425
# Epoch 3/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0068 - mean_absolute_error: 0.0768 - val_loss: 0.0229 - val_mean_absolute_error: 0.1492
# Epoch 4/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0017 - mean_absolute_error: 0.0272 - val_loss: 0.0061 - val_mean_absolute_error: 0.0754
# Epoch 5/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0028 - mean_absolute_error: 0.0423 - val_loss: 0.0013 - val_mean_absolute_error: 0.0306
# Epoch 6/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0049 - mean_absolute_error: 0.0608 - val_loss: 6.6129e-04 - val_mean_absolute_error: 0.0215
# Epoch 7/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0052 - mean_absolute_error: 0.0612 - val_loss: 0.0013 - val_mean_absolute_error: 0.0302
# Epoch 8/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0039 - mean_absolute_error: 0.0506 - val_loss: 0.0036 - val_mean_absolute_error: 0.0565
# Epoch 9/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0026 - mean_absolute_error: 0.0368 - val_loss: 0.0077 - val_mean_absolute_error: 0.0849
# Epoch 10/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0022 - mean_absolute_error: 0.0303 - val_loss: 0.0118 - val_mean_absolute_error: 0.1063
# Epoch 11/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0022 - mean_absolute_error: 0.0339 - val_loss: 0.0140 - val_mean_absolute_error: 0.1163
# Epoch 12/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0022 - mean_absolute_error: 0.0350 - val_loss: 0.0138 - val_mean_absolute_error: 0.1150
# Epoch 13/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0021 - mean_absolute_error: 0.0324 - val_loss: 0.0117 - val_mean_absolute_error: 0.1061
# Epoch 14/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.0019 - mean_absolute_error: 0.0289 - val_loss: 0.0094 - val_mean_absolute_error: 0.0944
# Epoch 15/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0019 - mean_absolute_error: 0.0273 - val_loss: 0.0076 - val_mean_absolute_error: 0.0846
# Epoch 16/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0019 - mean_absolute_error: 0.0282 - val_loss: 0.0067 - val_mean_absolute_error: 0.0792
# Epoch 17/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0020 - mean_absolute_error: 0.0289 - val_loss: 0.0066 - val_mean_absolute_error: 0.0787
# Epoch 18/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0020 - mean_absolute_error: 0.0285 - val_loss: 0.0070 - val_mean_absolute_error: 0.0814
# Epoch 19/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0019 - mean_absolute_error: 0.0279 - val_loss: 0.0077 - val_mean_absolute_error: 0.0851
# Epoch 20/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0019 - mean_absolute_error: 0.0276 - val_loss: 0.0081 - val_mean_absolute_error: 0.0876
# Epoch 21/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.0019 - mean_absolute_error: 0.0275 - val_loss: 0.0082 - val_mean_absolute_error: 0.0881
# Epoch 22/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0019 - mean_absolute_error: 0.0273 - val_loss: 0.0079 - val_mean_absolute_error: 0.0866
# Epoch 23/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0019 - mean_absolute_error: 0.0270 - val_loss: 0.0075 - val_mean_absolute_error: 0.0842
# Epoch 24/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0018 - mean_absolute_error: 0.0270 - val_loss: 0.0071 - val_mean_absolute_error: 0.0818
# Epoch 25/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0018 - mean_absolute_error: 0.0270 - val_loss: 0.0068 - val_mean_absolute_error: 0.0802
# Epoch 26/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0019 - mean_absolute_error: 0.0270 - val_loss: 0.0067 - val_mean_absolute_error: 0.0795
# Epoch 27/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0018 - mean_absolute_error: 0.0270 - val_loss: 0.0067 - val_mean_absolute_error: 0.0795
# Epoch 28/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0018 - mean_absolute_error: 0.0268 - val_loss: 0.0067 - val_mean_absolute_error: 0.0796
# Epoch 29/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.0018 - mean_absolute_error: 0.0267 - val_loss: 0.0067 - val_mean_absolute_error: 0.0795
# Epoch 30/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0018 - mean_absolute_error: 0.0266 - val_loss: 0.0066 - val_mean_absolute_error: 0.0789
# Epoch 31/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0018 - mean_absolute_error: 0.0265 - val_loss: 0.0064 - val_mean_absolute_error: 0.0780
# Epoch 32/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0018 - mean_absolute_error: 0.0265 - val_loss: 0.0063 - val_mean_absolute_error: 0.0770
# Epoch 33/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0018 - mean_absolute_error: 0.0264 - val_loss: 0.0062 - val_mean_absolute_error: 0.0762
# Epoch 34/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0018 - mean_absolute_error: 0.0264 - val_loss: 0.0061 - val_mean_absolute_error: 0.0756
# Epoch 35/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0018 - mean_absolute_error: 0.0263 - val_loss: 0.0060 - val_mean_absolute_error: 0.0751
# Epoch 36/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0018 - mean_absolute_error: 0.0262 - val_loss: 0.0059 - val_mean_absolute_error: 0.0748
# Epoch 37/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0018 - mean_absolute_error: 0.0262 - val_loss: 0.0059 - val_mean_absolute_error: 0.0743
# Epoch 38/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0018 - mean_absolute_error: 0.0261 - val_loss: 0.0058 - val_mean_absolute_error: 0.0738
# Epoch 39/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0018 - mean_absolute_error: 0.0261 - val_loss: 0.0057 - val_mean_absolute_error: 0.0732
# Epoch 40/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0018 - mean_absolute_error: 0.0260 - val_loss: 0.0056 - val_mean_absolute_error: 0.0727
# Epoch 41/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0018 - mean_absolute_error: 0.0260 - val_loss: 0.0055 - val_mean_absolute_error: 0.0721
# Epoch 42/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0018 - mean_absolute_error: 0.0259 - val_loss: 0.0055 - val_mean_absolute_error: 0.0717
# Epoch 43/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0018 - mean_absolute_error: 0.0259 - val_loss: 0.0054 - val_mean_absolute_error: 0.0713
# Epoch 44/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0018 - mean_absolute_error: 0.0258 - val_loss: 0.0053 - val_mean_absolute_error: 0.0709
# Epoch 45/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.0018 - mean_absolute_error: 0.0257 - val_loss: 0.0053 - val_mean_absolute_error: 0.0705
# Epoch 46/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0018 - mean_absolute_error: 0.0257 - val_loss: 0.0052 - val_mean_absolute_error: 0.0701
# Epoch 47/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0018 - mean_absolute_error: 0.0257 - val_loss: 0.0051 - val_mean_absolute_error: 0.0696
# Epoch 48/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0017 - mean_absolute_error: 0.0256 - val_loss: 0.0051 - val_mean_absolute_error: 0.0693
# Epoch 49/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0017 - mean_absolute_error: 0.0256 - val_loss: 0.0050 - val_mean_absolute_error: 0.0689
# Epoch 50/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0017 - mean_absolute_error: 0.0255 - val_loss: 0.0050 - val_mean_absolute_error: 0.0685
# Epoch 51/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0017 - mean_absolute_error: 0.0255 - val_loss: 0.0049 - val_mean_absolute_error: 0.0682
# Epoch 52/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0017 - mean_absolute_error: 0.0255 - val_loss: 0.0049 - val_mean_absolute_error: 0.0679
# Epoch 53/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.0017 - mean_absolute_error: 0.0254 - val_loss: 0.0048 - val_mean_absolute_error: 0.0676
# Epoch 54/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0017 - mean_absolute_error: 0.0254 - val_loss: 0.0048 - val_mean_absolute_error: 0.0673
# Epoch 55/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.0017 - mean_absolute_error: 0.0254 - val_loss: 0.0048 - val_mean_absolute_error: 0.0670
# Epoch 56/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.0017 - mean_absolute_error: 0.0253 - val_loss: 0.0047 - val_mean_absolute_error: 0.0667
# Epoch 57/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.0017 - mean_absolute_error: 0.0253 - val_loss: 0.0047 - val_mean_absolute_error: 0.0664
# Epoch 58/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.0017 - mean_absolute_error: 0.0253 - val_loss: 0.0046 - val_mean_absolute_error: 0.0662
# Epoch 59/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0017 - mean_absolute_error: 0.0252 - val_loss: 0.0046 - val_mean_absolute_error: 0.0659
# Epoch 60/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.0017 - mean_absolute_error: 0.0252 - val_loss: 0.0046 - val_mean_absolute_error: 0.0657
# Epoch 61/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.0017 - mean_absolute_error: 0.0252 - val_loss: 0.0045 - val_mean_absolute_error: 0.0654
# Epoch 62/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.0017 - mean_absolute_error: 0.0252 - val_loss: 0.0045 - val_mean_absolute_error: 0.0652
# Epoch 63/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.0017 - mean_absolute_error: 0.0251 - val_loss: 0.0045 - val_mean_absolute_error: 0.0650
# Epoch 64/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.0017 - mean_absolute_error: 0.0251 - val_loss: 0.0045 - val_mean_absolute_error: 0.0648
# Epoch 65/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.0017 - mean_absolute_error: 0.0251 - val_loss: 0.0044 - val_mean_absolute_error: 0.0646
# Epoch 66/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 0.0017 - mean_absolute_error: 0.0251 - val_loss: 0.0044 - val_mean_absolute_error: 0.0644
# Epoch 67/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.0017 - mean_absolute_error: 0.0250 - val_loss: 0.0044 - val_mean_absolute_error: 0.0642
# Epoch 68/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.0017 - mean_absolute_error: 0.0250 - val_loss: 0.0044 - val_mean_absolute_error: 0.0640
# Epoch 69/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.0017 - mean_absolute_error: 0.0250 - val_loss: 0.0043 - val_mean_absolute_error: 0.0639
# Epoch 70/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0017 - mean_absolute_error: 0.0250 - val_loss: 0.0043 - val_mean_absolute_error: 0.0637
# Epoch 71/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0017 - mean_absolute_error: 0.0249 - val_loss: 0.0043 - val_mean_absolute_error: 0.0635
# Epoch 72/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.0017 - mean_absolute_error: 0.0249 - val_loss: 0.0043 - val_mean_absolute_error: 0.0634
# Epoch 73/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 0.0017 - mean_absolute_error: 0.0249 - val_loss: 0.0042 - val_mean_absolute_error: 0.0632
# Epoch 74/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.0017 - mean_absolute_error: 0.0249 - val_loss: 0.0042 - val_mean_absolute_error: 0.0631
# Epoch 75/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0017 - mean_absolute_error: 0.0249 - val_loss: 0.0042 - val_mean_absolute_error: 0.0629
# Epoch 76/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0017 - mean_absolute_error: 0.0248 - val_loss: 0.0042 - val_mean_absolute_error: 0.0628
# Epoch 77/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.0017 - mean_absolute_error: 0.0248 - val_loss: 0.0042 - val_mean_absolute_error: 0.0627
# Epoch 78/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0017 - mean_absolute_error: 0.0248 - val_loss: 0.0042 - val_mean_absolute_error: 0.0625
# Epoch 79/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0017 - mean_absolute_error: 0.0248 - val_loss: 0.0041 - val_mean_absolute_error: 0.0624
# Epoch 80/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0017 - mean_absolute_error: 0.0248 - val_loss: 0.0041 - val_mean_absolute_error: 0.0623
# Epoch 81/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0017 - mean_absolute_error: 0.0247 - val_loss: 0.0041 - val_mean_absolute_error: 0.0622
# Epoch 82/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0017 - mean_absolute_error: 0.0247 - val_loss: 0.0041 - val_mean_absolute_error: 0.0621
# Epoch 83/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0017 - mean_absolute_error: 0.0247 - val_loss: 0.0041 - val_mean_absolute_error: 0.0619
# Epoch 84/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0017 - mean_absolute_error: 0.0247 - val_loss: 0.0041 - val_mean_absolute_error: 0.0618
# Epoch 85/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0017 - mean_absolute_error: 0.0247 - val_loss: 0.0041 - val_mean_absolute_error: 0.0617
# Epoch 86/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0017 - mean_absolute_error: 0.0247 - val_loss: 0.0040 - val_mean_absolute_error: 0.0616
# Epoch 87/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0017 - mean_absolute_error: 0.0246 - val_loss: 0.0040 - val_mean_absolute_error: 0.0615
# Epoch 88/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0017 - mean_absolute_error: 0.0246 - val_loss: 0.0040 - val_mean_absolute_error: 0.0614
# Epoch 89/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0017 - mean_absolute_error: 0.0246 - val_loss: 0.0040 - val_mean_absolute_error: 0.0613
# Epoch 90/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0017 - mean_absolute_error: 0.0246 - val_loss: 0.0040 - val_mean_absolute_error: 0.0613
# Epoch 91/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0017 - mean_absolute_error: 0.0246 - val_loss: 0.0040 - val_mean_absolute_error: 0.0612
# Epoch 92/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0017 - mean_absolute_error: 0.0246 - val_loss: 0.0040 - val_mean_absolute_error: 0.0611
# Epoch 93/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0017 - mean_absolute_error: 0.0245 - val_loss: 0.0040 - val_mean_absolute_error: 0.0610
# Epoch 94/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0017 - mean_absolute_error: 0.0245 - val_loss: 0.0039 - val_mean_absolute_error: 0.0609
# Epoch 95/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0017 - mean_absolute_error: 0.0245 - val_loss: 0.0039 - val_mean_absolute_error: 0.0608
# Epoch 96/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.0017 - mean_absolute_error: 0.0245 - val_loss: 0.0039 - val_mean_absolute_error: 0.0607
# Epoch 97/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0017 - mean_absolute_error: 0.0245 - val_loss: 0.0039 - val_mean_absolute_error: 0.0607
# Epoch 98/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0017 - mean_absolute_error: 0.0245 - val_loss: 0.0039 - val_mean_absolute_error: 0.0606
# Epoch 99/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0017 - mean_absolute_error: 0.0245 - val_loss: 0.0039 - val_mean_absolute_error: 0.0605
# Epoch 100/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.0017 - mean_absolute_error: 0.0244 - val_loss: 0.0039 - val_mean_absolute_error: 0.0604

# %% [markdown]
# Training curves

# %%
plot_training_curves(
    market_rnn_history,
    "Market-level RNN"
)

# %% [markdown]
# Test data evaluation

# %%
evaluate_and_plot(
    market_rnn_model,
    trainX_market,
    testX_market,
    trainY_market,
    testY_market,
    scaler_market,
    "Market-level RNN"
)
# Out:
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 140ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# Market-level RNN Train RMSE: 8131.16
# Market-level RNN Test RMSE: 15985.01

# %% [markdown]
# ### Market level MLP and evaluation

# %%
# Build and train market-level MLP model

market_mlp_model = Sequential([
    Dense(
        32,
        activation="relu",
        input_shape=(trainX_market_mlp.shape[1],)
    ),
    Dense(
        16,
        activation="relu"
    ),
    Dense(1)
])

market_mlp_model.compile(
    optimizer="adam",
    loss="mean_squared_error",
    metrics=["mean_absolute_error"]
)

market_mlp_history = market_mlp_model.fit(
    trainX_market_mlp,
    trainY_market,
    epochs=100,
    batch_size=8,
    validation_split=0.2,
    shuffle=False,
    verbose=1
)
# Out:
# Epoch 1/100
# c:\Users\tyler\anaconda3\Lib\site-packages\keras\src\layers\core\dense.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 55ms/step - loss: 0.0963 - mean_absolute_error: 0.2989 - val_loss: 0.2720 - val_mean_absolute_error: 0.5195
# Epoch 2/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.0762 - mean_absolute_error: 0.2646 - val_loss: 0.2254 - val_mean_absolute_error: 0.4728
# Epoch 3/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0604 - mean_absolute_error: 0.2341 - val_loss: 0.1870 - val_mean_absolute_error: 0.4305
# Epoch 4/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.0456 - mean_absolute_error: 0.2016 - val_loss: 0.1498 - val_mean_absolute_error: 0.3851
# Epoch 5/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.0322 - mean_absolute_error: 0.1670 - val_loss: 0.1146 - val_mean_absolute_error: 0.3366
# Epoch 6/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.0213 - mean_absolute_error: 0.1330 - val_loss: 0.0845 - val_mean_absolute_error: 0.2888
# Epoch 7/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.0130 - mean_absolute_error: 0.1011 - val_loss: 0.0601 - val_mean_absolute_error: 0.2432
# Epoch 8/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.0074 - mean_absolute_error: 0.0734 - val_loss: 0.0413 - val_mean_absolute_error: 0.2013
# Epoch 9/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0042 - mean_absolute_error: 0.0562 - val_loss: 0.0279 - val_mean_absolute_error: 0.1649
# Epoch 10/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 0.0027 - mean_absolute_error: 0.0446 - val_loss: 0.0189 - val_mean_absolute_error: 0.1352
# Epoch 11/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.0024 - mean_absolute_error: 0.0378 - val_loss: 0.0133 - val_mean_absolute_error: 0.1128
# Epoch 12/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.0027 - mean_absolute_error: 0.0375 - val_loss: 0.0101 - val_mean_absolute_error: 0.0979
# Epoch 13/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.0031 - mean_absolute_error: 0.0413 - val_loss: 0.0086 - val_mean_absolute_error: 0.0901
# Epoch 14/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0033 - mean_absolute_error: 0.0434 - val_loss: 0.0083 - val_mean_absolute_error: 0.0883
# Epoch 15/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0033 - mean_absolute_error: 0.0432 - val_loss: 0.0087 - val_mean_absolute_error: 0.0908
# Epoch 16/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0031 - mean_absolute_error: 0.0416 - val_loss: 0.0097 - val_mean_absolute_error: 0.0958
# Epoch 17/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0029 - mean_absolute_error: 0.0396 - val_loss: 0.0109 - val_mean_absolute_error: 0.1018
# Epoch 18/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0027 - mean_absolute_error: 0.0382 - val_loss: 0.0121 - val_mean_absolute_error: 0.1076
# Epoch 19/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0026 - mean_absolute_error: 0.0378 - val_loss: 0.0131 - val_mean_absolute_error: 0.1123
# Epoch 20/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0025 - mean_absolute_error: 0.0379 - val_loss: 0.0139 - val_mean_absolute_error: 0.1155
# Epoch 21/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0024 - mean_absolute_error: 0.0377 - val_loss: 0.0143 - val_mean_absolute_error: 0.1172
# Epoch 22/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0024 - mean_absolute_error: 0.0375 - val_loss: 0.0143 - val_mean_absolute_error: 0.1174
# Epoch 23/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0023 - mean_absolute_error: 0.0371 - val_loss: 0.0141 - val_mean_absolute_error: 0.1165
# Epoch 24/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0023 - mean_absolute_error: 0.0365 - val_loss: 0.0137 - val_mean_absolute_error: 0.1150
# Epoch 25/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0022 - mean_absolute_error: 0.0359 - val_loss: 0.0133 - val_mean_absolute_error: 0.1131
# Epoch 26/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0022 - mean_absolute_error: 0.0354 - val_loss: 0.0129 - val_mean_absolute_error: 0.1111
# Epoch 27/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.0021 - mean_absolute_error: 0.0348 - val_loss: 0.0125 - val_mean_absolute_error: 0.1094
# Epoch 28/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0021 - mean_absolute_error: 0.0343 - val_loss: 0.0121 - val_mean_absolute_error: 0.1079
# Epoch 29/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.0021 - mean_absolute_error: 0.0338 - val_loss: 0.0119 - val_mean_absolute_error: 0.1068
# Epoch 30/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.0020 - mean_absolute_error: 0.0334 - val_loss: 0.0117 - val_mean_absolute_error: 0.1059
# Epoch 31/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0020 - mean_absolute_error: 0.0330 - val_loss: 0.0115 - val_mean_absolute_error: 0.1051
# Epoch 32/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.0020 - mean_absolute_error: 0.0326 - val_loss: 0.0114 - val_mean_absolute_error: 0.1045
# Epoch 33/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.0019 - mean_absolute_error: 0.0321 - val_loss: 0.0112 - val_mean_absolute_error: 0.1039
# Epoch 34/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 0.0019 - mean_absolute_error: 0.0317 - val_loss: 0.0111 - val_mean_absolute_error: 0.1033
# Epoch 35/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.0019 - mean_absolute_error: 0.0317 - val_loss: 0.0113 - val_mean_absolute_error: 0.1042
# Epoch 36/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.0018 - mean_absolute_error: 0.0306 - val_loss: 0.0106 - val_mean_absolute_error: 0.1010
# Epoch 37/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0017 - mean_absolute_error: 0.0293 - val_loss: 0.0102 - val_mean_absolute_error: 0.0988
# Epoch 38/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.0017 - mean_absolute_error: 0.0287 - val_loss: 0.0099 - val_mean_absolute_error: 0.0973
# Epoch 39/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.0016 - mean_absolute_error: 0.0280 - val_loss: 0.0096 - val_mean_absolute_error: 0.0960
# Epoch 40/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.0016 - mean_absolute_error: 0.0275 - val_loss: 0.0094 - val_mean_absolute_error: 0.0947
# Epoch 41/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.0015 - mean_absolute_error: 0.0266 - val_loss: 0.0091 - val_mean_absolute_error: 0.0932
# Epoch 42/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.0014 - mean_absolute_error: 0.0258 - val_loss: 0.0088 - val_mean_absolute_error: 0.0916
# Epoch 43/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.0014 - mean_absolute_error: 0.0254 - val_loss: 0.0085 - val_mean_absolute_error: 0.0901
# Epoch 44/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.0014 - mean_absolute_error: 0.0249 - val_loss: 0.0082 - val_mean_absolute_error: 0.0885
# Epoch 45/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.0013 - mean_absolute_error: 0.0244 - val_loss: 0.0079 - val_mean_absolute_error: 0.0868
# Epoch 46/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.0013 - mean_absolute_error: 0.0239 - val_loss: 0.0076 - val_mean_absolute_error: 0.0852
# Epoch 47/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.0012 - mean_absolute_error: 0.0235 - val_loss: 0.0073 - val_mean_absolute_error: 0.0834
# Epoch 48/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0012 - mean_absolute_error: 0.0230 - val_loss: 0.0070 - val_mean_absolute_error: 0.0818
# Epoch 49/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.0011 - mean_absolute_error: 0.0226 - val_loss: 0.0068 - val_mean_absolute_error: 0.0803
# Epoch 50/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.0011 - mean_absolute_error: 0.0222 - val_loss: 0.0066 - val_mean_absolute_error: 0.0790
# Epoch 51/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.0011 - mean_absolute_error: 0.0218 - val_loss: 0.0064 - val_mean_absolute_error: 0.0778
# Epoch 52/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.0010 - mean_absolute_error: 0.0214 - val_loss: 0.0062 - val_mean_absolute_error: 0.0766
# Epoch 53/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 9.9056e-04 - mean_absolute_error: 0.0211 - val_loss: 0.0060 - val_mean_absolute_error: 0.0755
# Epoch 54/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 9.6462e-04 - mean_absolute_error: 0.0208 - val_loss: 0.0058 - val_mean_absolute_error: 0.0745
# Epoch 55/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 9.3160e-04 - mean_absolute_error: 0.0205 - val_loss: 0.0057 - val_mean_absolute_error: 0.0735
# Epoch 56/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 9.0640e-04 - mean_absolute_error: 0.0202 - val_loss: 0.0056 - val_mean_absolute_error: 0.0726
# Epoch 57/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 8.8084e-04 - mean_absolute_error: 0.0199 - val_loss: 0.0054 - val_mean_absolute_error: 0.0717
# Epoch 58/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 8.5669e-04 - mean_absolute_error: 0.0197 - val_loss: 0.0053 - val_mean_absolute_error: 0.0708
# Epoch 59/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 8.2883e-04 - mean_absolute_error: 0.0194 - val_loss: 0.0051 - val_mean_absolute_error: 0.0697
# Epoch 60/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 8.0884e-04 - mean_absolute_error: 0.0192 - val_loss: 0.0050 - val_mean_absolute_error: 0.0686
# Epoch 61/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 7.8618e-04 - mean_absolute_error: 0.0189 - val_loss: 0.0048 - val_mean_absolute_error: 0.0676
# Epoch 62/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 7.7107e-04 - mean_absolute_error: 0.0187 - val_loss: 0.0047 - val_mean_absolute_error: 0.0667
# Epoch 63/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 7.4770e-04 - mean_absolute_error: 0.0185 - val_loss: 0.0046 - val_mean_absolute_error: 0.0656
# Epoch 64/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 7.2799e-04 - mean_absolute_error: 0.0182 - val_loss: 0.0044 - val_mean_absolute_error: 0.0645
# Epoch 65/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 7.1166e-04 - mean_absolute_error: 0.0180 - val_loss: 0.0043 - val_mean_absolute_error: 0.0636
# Epoch 66/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 6.9992e-04 - mean_absolute_error: 0.0178 - val_loss: 0.0042 - val_mean_absolute_error: 0.0629
# Epoch 67/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 6.8212e-04 - mean_absolute_error: 0.0175 - val_loss: 0.0041 - val_mean_absolute_error: 0.0622
# Epoch 68/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - loss: 6.6454e-04 - mean_absolute_error: 0.0173 - val_loss: 0.0040 - val_mean_absolute_error: 0.0614
# Epoch 69/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 6.4761e-04 - mean_absolute_error: 0.0171 - val_loss: 0.0039 - val_mean_absolute_error: 0.0604
# Epoch 70/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 6.3571e-04 - mean_absolute_error: 0.0170 - val_loss: 0.0038 - val_mean_absolute_error: 0.0595
# Epoch 71/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 6.2080e-04 - mean_absolute_error: 0.0168 - val_loss: 0.0037 - val_mean_absolute_error: 0.0587
# Epoch 72/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 6.0849e-04 - mean_absolute_error: 0.0166 - val_loss: 0.0036 - val_mean_absolute_error: 0.0579
# Epoch 73/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 5.9526e-04 - mean_absolute_error: 0.0165 - val_loss: 0.0035 - val_mean_absolute_error: 0.0571
# Epoch 74/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 5.8087e-04 - mean_absolute_error: 0.0163 - val_loss: 0.0034 - val_mean_absolute_error: 0.0562
# Epoch 75/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 5.7122e-04 - mean_absolute_error: 0.0162 - val_loss: 0.0033 - val_mean_absolute_error: 0.0552
# Epoch 76/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 5.5897e-04 - mean_absolute_error: 0.0161 - val_loss: 0.0032 - val_mean_absolute_error: 0.0544
# Epoch 77/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 5.4827e-04 - mean_absolute_error: 0.0160 - val_loss: 0.0031 - val_mean_absolute_error: 0.0537
# Epoch 78/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 5.3872e-04 - mean_absolute_error: 0.0159 - val_loss: 0.0030 - val_mean_absolute_error: 0.0531
# Epoch 79/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 5.2766e-04 - mean_absolute_error: 0.0157 - val_loss: 0.0029 - val_mean_absolute_error: 0.0524
# Epoch 80/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 5.1636e-04 - mean_absolute_error: 0.0156 - val_loss: 0.0029 - val_mean_absolute_error: 0.0518
# Epoch 81/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 5.0725e-04 - mean_absolute_error: 0.0155 - val_loss: 0.0028 - val_mean_absolute_error: 0.0513
# Epoch 82/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 4.9774e-04 - mean_absolute_error: 0.0153 - val_loss: 0.0028 - val_mean_absolute_error: 0.0508
# Epoch 83/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 4.8932e-04 - mean_absolute_error: 0.0152 - val_loss: 0.0027 - val_mean_absolute_error: 0.0505
# Epoch 84/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 4.7916e-04 - mean_absolute_error: 0.0151 - val_loss: 0.0027 - val_mean_absolute_error: 0.0500
# Epoch 85/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 4.6910e-04 - mean_absolute_error: 0.0149 - val_loss: 0.0026 - val_mean_absolute_error: 0.0494
# Epoch 86/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 4.6119e-04 - mean_absolute_error: 0.0148 - val_loss: 0.0026 - val_mean_absolute_error: 0.0488
# Epoch 87/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 4.5516e-04 - mean_absolute_error: 0.0147 - val_loss: 0.0025 - val_mean_absolute_error: 0.0484
# Epoch 88/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 4.4547e-04 - mean_absolute_error: 0.0146 - val_loss: 0.0025 - val_mean_absolute_error: 0.0480
# Epoch 89/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 4.3622e-04 - mean_absolute_error: 0.0145 - val_loss: 0.0024 - val_mean_absolute_error: 0.0475
# Epoch 90/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 4.2781e-04 - mean_absolute_error: 0.0143 - val_loss: 0.0024 - val_mean_absolute_error: 0.0469
# Epoch 91/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 4.2065e-04 - mean_absolute_error: 0.0142 - val_loss: 0.0023 - val_mean_absolute_error: 0.0466
# Epoch 92/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 4.1327e-04 - mean_absolute_error: 0.0140 - val_loss: 0.0023 - val_mean_absolute_error: 0.0462
# Epoch 93/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 4.0575e-04 - mean_absolute_error: 0.0139 - val_loss: 0.0023 - val_mean_absolute_error: 0.0457
# Epoch 94/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 3.9766e-04 - mean_absolute_error: 0.0138 - val_loss: 0.0022 - val_mean_absolute_error: 0.0451
# Epoch 95/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 3.9181e-04 - mean_absolute_error: 0.0138 - val_loss: 0.0022 - val_mean_absolute_error: 0.0446
# Epoch 96/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 3.8662e-04 - mean_absolute_error: 0.0137 - val_loss: 0.0021 - val_mean_absolute_error: 0.0442
# Epoch 97/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 3.7958e-04 - mean_absolute_error: 0.0137 - val_loss: 0.0021 - val_mean_absolute_error: 0.0438
# Epoch 98/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 3.7290e-04 - mean_absolute_error: 0.0136 - val_loss: 0.0020 - val_mean_absolute_error: 0.0434
# Epoch 99/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 3.6603e-04 - mean_absolute_error: 0.0135 - val_loss: 0.0020 - val_mean_absolute_error: 0.0430
# Epoch 100/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 3.6022e-04 - mean_absolute_error: 0.0133 - val_loss: 0.0020 - val_mean_absolute_error: 0.0428

# %% [markdown]
# Training curves MLP

# %%
plot_training_curves(
    market_mlp_history,
    "Market-level MLP"
)

# %% [markdown]
# Test data evaluation MLP

# %%
evaluate_and_plot(
    market_mlp_model,
    trainX_market_mlp,
    testX_market_mlp,
    trainY_market,
    testY_market,
    scaler_market,
    "Market-level MLP"
)
# Out:
# WARNING:tensorflow:5 out of the last 16 calls to <function TensorFlowTrainer.make_predict_function.<locals>.one_step_on_data_distributed at 0x0000020CC2094A40> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 1/2 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/stepWARNING:tensorflow:6 out of the last 17 calls to <function TensorFlowTrainer.make_predict_function.<locals>.one_step_on_data_distributed at 0x0000020CC2094A40> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# Market-level MLP Train RMSE: 4631.41
# Market-level MLP Test RMSE: 10526.73

# %% [markdown]
# ### Market level CNN & evaluation

# %%
# Build and train market-level 1D CNN model

market_cnn_model = Sequential([
    Conv1D(
        filters=16,                         # learn 16 temporal pattern detectors
        kernel_size=2,                      # each filter looks across 2 neighboring timesteps
        activation="relu",
        input_shape=(look_back, trainX_market.shape[2])
    ),                                      # input shape = timesteps, features

    Flatten(),                              # convert CNN output to flat vector for Dense layer

    Dense(1)                                # regression output layer
])

market_cnn_model.compile(
    optimizer="adam",
    loss="mean_squared_error",
    metrics=["mean_absolute_error"]
)

market_cnn_history = market_cnn_model.fit(
    trainX_market,
    trainY_market,
    epochs=100,
    batch_size=8,
    validation_split=0.2,
    shuffle=False,                          # preserve temporal order
    verbose=1
)
# Out:
# Epoch 1/100
# c:\Users\tyler\anaconda3\Lib\site-packages\keras\src\layers\convolutional\base_conv.py:113: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 58ms/step - loss: 0.0999 - mean_absolute_error: 0.3029 - val_loss: 0.2975 - val_mean_absolute_error: 0.5433
# Epoch 2/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0884 - mean_absolute_error: 0.2840 - val_loss: 0.2710 - val_mean_absolute_error: 0.5184
# Epoch 3/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0778 - mean_absolute_error: 0.2656 - val_loss: 0.2458 - val_mean_absolute_error: 0.4937
# Epoch 4/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0681 - mean_absolute_error: 0.2474 - val_loss: 0.2222 - val_mean_absolute_error: 0.4693
# Epoch 5/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0592 - mean_absolute_error: 0.2297 - val_loss: 0.2003 - val_mean_absolute_error: 0.4455
# Epoch 6/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0514 - mean_absolute_error: 0.2127 - val_loss: 0.1801 - val_mean_absolute_error: 0.4224
# Epoch 7/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0445 - mean_absolute_error: 0.1967 - val_loss: 0.1618 - val_mean_absolute_error: 0.4001
# Epoch 8/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0385 - mean_absolute_error: 0.1815 - val_loss: 0.1457 - val_mean_absolute_error: 0.3796
# Epoch 9/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0332 - mean_absolute_error: 0.1671 - val_loss: 0.1313 - val_mean_absolute_error: 0.3604
# Epoch 10/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0285 - mean_absolute_error: 0.1539 - val_loss: 0.1183 - val_mean_absolute_error: 0.3420
# Epoch 11/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.0244 - mean_absolute_error: 0.1411 - val_loss: 0.1065 - val_mean_absolute_error: 0.3243
# Epoch 12/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0207 - mean_absolute_error: 0.1289 - val_loss: 0.0958 - val_mean_absolute_error: 0.3074
# Epoch 13/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.0176 - mean_absolute_error: 0.1172 - val_loss: 0.0860 - val_mean_absolute_error: 0.2912
# Epoch 14/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.0149 - mean_absolute_error: 0.1069 - val_loss: 0.0773 - val_mean_absolute_error: 0.2759
# Epoch 15/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.0126 - mean_absolute_error: 0.0976 - val_loss: 0.0694 - val_mean_absolute_error: 0.2614
# Epoch 16/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.0107 - mean_absolute_error: 0.0889 - val_loss: 0.0624 - val_mean_absolute_error: 0.2477
# Epoch 17/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.0090 - mean_absolute_error: 0.0810 - val_loss: 0.0562 - val_mean_absolute_error: 0.2349
# Epoch 18/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.0077 - mean_absolute_error: 0.0749 - val_loss: 0.0507 - val_mean_absolute_error: 0.2230
# Epoch 19/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.0066 - mean_absolute_error: 0.0702 - val_loss: 0.0459 - val_mean_absolute_error: 0.2119
# Epoch 20/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - loss: 0.0058 - mean_absolute_error: 0.0659 - val_loss: 0.0416 - val_mean_absolute_error: 0.2017
# Epoch 21/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.0051 - mean_absolute_error: 0.0623 - val_loss: 0.0379 - val_mean_absolute_error: 0.1924
# Epoch 22/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.0045 - mean_absolute_error: 0.0590 - val_loss: 0.0347 - val_mean_absolute_error: 0.1840
# Epoch 23/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0041 - mean_absolute_error: 0.0561 - val_loss: 0.0319 - val_mean_absolute_error: 0.1763
# Epoch 24/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0038 - mean_absolute_error: 0.0535 - val_loss: 0.0295 - val_mean_absolute_error: 0.1694
# Epoch 25/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.0036 - mean_absolute_error: 0.0511 - val_loss: 0.0275 - val_mean_absolute_error: 0.1633
# Epoch 26/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0034 - mean_absolute_error: 0.0491 - val_loss: 0.0257 - val_mean_absolute_error: 0.1579
# Epoch 27/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.0033 - mean_absolute_error: 0.0475 - val_loss: 0.0242 - val_mean_absolute_error: 0.1531
# Epoch 28/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0032 - mean_absolute_error: 0.0460 - val_loss: 0.0230 - val_mean_absolute_error: 0.1490
# Epoch 29/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0031 - mean_absolute_error: 0.0449 - val_loss: 0.0219 - val_mean_absolute_error: 0.1453
# Epoch 30/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0031 - mean_absolute_error: 0.0439 - val_loss: 0.0210 - val_mean_absolute_error: 0.1422
# Epoch 31/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0030 - mean_absolute_error: 0.0432 - val_loss: 0.0202 - val_mean_absolute_error: 0.1395
# Epoch 32/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0030 - mean_absolute_error: 0.0426 - val_loss: 0.0195 - val_mean_absolute_error: 0.1371
# Epoch 33/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0030 - mean_absolute_error: 0.0420 - val_loss: 0.0190 - val_mean_absolute_error: 0.1351
# Epoch 34/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0030 - mean_absolute_error: 0.0416 - val_loss: 0.0185 - val_mean_absolute_error: 0.1334
# Epoch 35/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0029 - mean_absolute_error: 0.0412 - val_loss: 0.0181 - val_mean_absolute_error: 0.1320
# Epoch 36/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0029 - mean_absolute_error: 0.0408 - val_loss: 0.0178 - val_mean_absolute_error: 0.1308
# Epoch 37/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0029 - mean_absolute_error: 0.0405 - val_loss: 0.0175 - val_mean_absolute_error: 0.1298
# Epoch 38/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0029 - mean_absolute_error: 0.0401 - val_loss: 0.0174 - val_mean_absolute_error: 0.1291
# Epoch 39/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0028 - mean_absolute_error: 0.0398 - val_loss: 0.0171 - val_mean_absolute_error: 0.1281
# Epoch 40/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0028 - mean_absolute_error: 0.0395 - val_loss: 0.0168 - val_mean_absolute_error: 0.1271
# Epoch 41/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.0028 - mean_absolute_error: 0.0392 - val_loss: 0.0166 - val_mean_absolute_error: 0.1262
# Epoch 42/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.0028 - mean_absolute_error: 0.0390 - val_loss: 0.0164 - val_mean_absolute_error: 0.1255
# Epoch 43/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0028 - mean_absolute_error: 0.0388 - val_loss: 0.0163 - val_mean_absolute_error: 0.1249
# Epoch 44/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.0028 - mean_absolute_error: 0.0386 - val_loss: 0.0161 - val_mean_absolute_error: 0.1243
# Epoch 45/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0027 - mean_absolute_error: 0.0384 - val_loss: 0.0160 - val_mean_absolute_error: 0.1238
# Epoch 46/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.0027 - mean_absolute_error: 0.0382 - val_loss: 0.0159 - val_mean_absolute_error: 0.1233
# Epoch 47/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.0027 - mean_absolute_error: 0.0379 - val_loss: 0.0157 - val_mean_absolute_error: 0.1228
# Epoch 48/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.0027 - mean_absolute_error: 0.0377 - val_loss: 0.0156 - val_mean_absolute_error: 0.1223
# Epoch 49/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0027 - mean_absolute_error: 0.0376 - val_loss: 0.0155 - val_mean_absolute_error: 0.1218
# Epoch 50/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.0026 - mean_absolute_error: 0.0373 - val_loss: 0.0154 - val_mean_absolute_error: 0.1213
# Epoch 51/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.0026 - mean_absolute_error: 0.0371 - val_loss: 0.0153 - val_mean_absolute_error: 0.1208
# Epoch 52/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0026 - mean_absolute_error: 0.0370 - val_loss: 0.0151 - val_mean_absolute_error: 0.1204
# Epoch 53/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.0026 - mean_absolute_error: 0.0368 - val_loss: 0.0150 - val_mean_absolute_error: 0.1199
# Epoch 54/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.0026 - mean_absolute_error: 0.0366 - val_loss: 0.0149 - val_mean_absolute_error: 0.1194
# Epoch 55/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0026 - mean_absolute_error: 0.0364 - val_loss: 0.0148 - val_mean_absolute_error: 0.1190
# Epoch 56/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.0025 - mean_absolute_error: 0.0362 - val_loss: 0.0147 - val_mean_absolute_error: 0.1185
# Epoch 57/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.0025 - mean_absolute_error: 0.0360 - val_loss: 0.0146 - val_mean_absolute_error: 0.1180
# Epoch 58/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.0025 - mean_absolute_error: 0.0358 - val_loss: 0.0144 - val_mean_absolute_error: 0.1175
# Epoch 59/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.0025 - mean_absolute_error: 0.0357 - val_loss: 0.0143 - val_mean_absolute_error: 0.1171
# Epoch 60/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.0025 - mean_absolute_error: 0.0355 - val_loss: 0.0142 - val_mean_absolute_error: 0.1166
# Epoch 61/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.0025 - mean_absolute_error: 0.0353 - val_loss: 0.0141 - val_mean_absolute_error: 0.1161
# Epoch 62/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.0025 - mean_absolute_error: 0.0351 - val_loss: 0.0140 - val_mean_absolute_error: 0.1157
# Epoch 63/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.0024 - mean_absolute_error: 0.0349 - val_loss: 0.0139 - val_mean_absolute_error: 0.1152
# Epoch 64/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.0024 - mean_absolute_error: 0.0348 - val_loss: 0.0138 - val_mean_absolute_error: 0.1147
# Epoch 65/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.0024 - mean_absolute_error: 0.0346 - val_loss: 0.0137 - val_mean_absolute_error: 0.1143
# Epoch 66/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.0024 - mean_absolute_error: 0.0344 - val_loss: 0.0136 - val_mean_absolute_error: 0.1138
# Epoch 67/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.0024 - mean_absolute_error: 0.0342 - val_loss: 0.0135 - val_mean_absolute_error: 0.1134
# Epoch 68/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.0024 - mean_absolute_error: 0.0340 - val_loss: 0.0133 - val_mean_absolute_error: 0.1129
# Epoch 69/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.0024 - mean_absolute_error: 0.0339 - val_loss: 0.0133 - val_mean_absolute_error: 0.1125
# Epoch 70/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0023 - mean_absolute_error: 0.0337 - val_loss: 0.0132 - val_mean_absolute_error: 0.1121
# Epoch 71/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.0023 - mean_absolute_error: 0.0335 - val_loss: 0.0131 - val_mean_absolute_error: 0.1117
# Epoch 72/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.0023 - mean_absolute_error: 0.0333 - val_loss: 0.0130 - val_mean_absolute_error: 0.1113
# Epoch 73/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0023 - mean_absolute_error: 0.0332 - val_loss: 0.0129 - val_mean_absolute_error: 0.1109
# Epoch 74/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0023 - mean_absolute_error: 0.0330 - val_loss: 0.0128 - val_mean_absolute_error: 0.1105
# Epoch 75/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.0023 - mean_absolute_error: 0.0328 - val_loss: 0.0127 - val_mean_absolute_error: 0.1101
# Epoch 76/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.0023 - mean_absolute_error: 0.0327 - val_loss: 0.0126 - val_mean_absolute_error: 0.1097
# Epoch 77/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.0022 - mean_absolute_error: 0.0325 - val_loss: 0.0125 - val_mean_absolute_error: 0.1093
# Epoch 78/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.0022 - mean_absolute_error: 0.0324 - val_loss: 0.0124 - val_mean_absolute_error: 0.1089
# Epoch 79/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.0022 - mean_absolute_error: 0.0322 - val_loss: 0.0124 - val_mean_absolute_error: 0.1085
# Epoch 80/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.0022 - mean_absolute_error: 0.0320 - val_loss: 0.0123 - val_mean_absolute_error: 0.1082
# Epoch 81/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.0022 - mean_absolute_error: 0.0319 - val_loss: 0.0122 - val_mean_absolute_error: 0.1078
# Epoch 82/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0022 - mean_absolute_error: 0.0317 - val_loss: 0.0121 - val_mean_absolute_error: 0.1074
# Epoch 83/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.0022 - mean_absolute_error: 0.0315 - val_loss: 0.0120 - val_mean_absolute_error: 0.1070
# Epoch 84/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.0022 - mean_absolute_error: 0.0314 - val_loss: 0.0119 - val_mean_absolute_error: 0.1066
# Epoch 85/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.0021 - mean_absolute_error: 0.0312 - val_loss: 0.0119 - val_mean_absolute_error: 0.1063
# Epoch 86/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.0021 - mean_absolute_error: 0.0310 - val_loss: 0.0118 - val_mean_absolute_error: 0.1059
# Epoch 87/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0021 - mean_absolute_error: 0.0308 - val_loss: 0.0117 - val_mean_absolute_error: 0.1055
# Epoch 88/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.0021 - mean_absolute_error: 0.0307 - val_loss: 0.0116 - val_mean_absolute_error: 0.1052
# Epoch 89/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0021 - mean_absolute_error: 0.0305 - val_loss: 0.0116 - val_mean_absolute_error: 0.1048
# Epoch 90/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.0021 - mean_absolute_error: 0.0303 - val_loss: 0.0115 - val_mean_absolute_error: 0.1045
# Epoch 91/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.0021 - mean_absolute_error: 0.0302 - val_loss: 0.0114 - val_mean_absolute_error: 0.1042
# Epoch 92/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.0021 - mean_absolute_error: 0.0300 - val_loss: 0.0113 - val_mean_absolute_error: 0.1039
# Epoch 93/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.0021 - mean_absolute_error: 0.0299 - val_loss: 0.0113 - val_mean_absolute_error: 0.1035
# Epoch 94/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0020 - mean_absolute_error: 0.0297 - val_loss: 0.0112 - val_mean_absolute_error: 0.1032
# Epoch 95/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.0020 - mean_absolute_error: 0.0296 - val_loss: 0.0111 - val_mean_absolute_error: 0.1029
# Epoch 96/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.0020 - mean_absolute_error: 0.0294 - val_loss: 0.0111 - val_mean_absolute_error: 0.1025
# Epoch 97/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0020 - mean_absolute_error: 0.0293 - val_loss: 0.0110 - val_mean_absolute_error: 0.1022
# Epoch 98/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.0020 - mean_absolute_error: 0.0292 - val_loss: 0.0109 - val_mean_absolute_error: 0.1019
# Epoch 99/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0020 - mean_absolute_error: 0.0291 - val_loss: 0.0109 - val_mean_absolute_error: 0.1016
# Epoch 100/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.0020 - mean_absolute_error: 0.0290 - val_loss: 0.0108 - val_mean_absolute_error: 0.1013

# %% [markdown]
# Training curves 1D CNN

# %%
plot_training_curves(
    market_cnn_history,
    "Market-level 1D CNN"
)

# %% [markdown]
# Test data evaluation 1D CNN

# %%
evaluate_and_plot(
    market_cnn_model,
    trainX_market,
    testX_market,
    trainY_market,
    testY_market,
    scaler_market,
    "Market-level 1D CNN"
)
# Out:
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# Market-level 1D CNN Train RMSE: 10858.95
# Market-level 1D CNN Test RMSE: 27010.29

# %% [markdown]
# ### Comparison of RNN vs MLP vs 1D CNN

# %%
rnn_rmse, rnn_mae = evaluate_metrics(
    market_rnn_model,
    testX_market,
    testY_market,
    scaler_market
)

mlp_rmse, mlp_mae = evaluate_metrics(
    market_mlp_model,
    testX_market_mlp,
    testY_market,
    scaler_market
)

cnn_rmse, cnn_mae = evaluate_metrics(
    market_cnn_model,
    testX_market,
    testY_market,
    scaler_market
)

comparison = pd.DataFrame({
    "Model": ["RNN", "MLP", "1D CNN"],
    "RMSE": [rnn_rmse, mlp_rmse, cnn_rmse],
    "MAE": [rnn_mae, mlp_mae, cnn_mae]
})

comparison
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
#     Model          RMSE           MAE
# 0     RNN  15985.009573  15295.126984
# 1     MLP  10526.726267   9675.571429
# 2  1D CNN  27010.294472  26676.703373

# %% [markdown]
# ### Your Turn — Build and Compare RNN Models
#
# Choose one or more coherent housing subgroups (for example, 3-bedroom houses) and build at least 3 meaningfully different RNN forecasting models. Evaluate each model using training/validation curves, held-out future test predictions, RMSE, and MAE, and record your observations in markdown cells throughout the notebook.

# %% [markdown]
# ### Model Exploration Summary
#
# Briefly summarize which subgroup(s) and model variations you explored, what changes appeared to improve or worsen forecasting performance, any patterns you noticed in the training curves or predictions, and which model you believe performed best and why.

# %%
# Filter to 3-bedroom houses subgroup

house["saledate"] = pd.to_datetime(house["saledate"], dayfirst=True)

df_3bed = (
    house[house["bedrooms"] == 3]
    .groupby("saledate")["MA"]
    .mean()
    .reset_index()
    .sort_values("saledate")
    .reset_index(drop=True)
)

plt.figure(figsize=(10, 4))
plt.plot(df_3bed["saledate"], df_3bed["MA"])
plt.title("3-Bedroom Houses: Average MA over Time")
plt.xlabel("Date")
plt.ylabel("Average MA")
plt.ylim(0, 1200000)
plt.ticklabel_format(style="plain", axis="y")
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

print(f"Subgroup size: {len(df_3bed)} time steps")
# Out:
# Subgroup size: 51 time steps

# %%
# Scale and split 3-bedroom subgroup data

scaler_3bed = MinMaxScaler(feature_range=(0, 1))
scaled_3bed = scaler_3bed.fit_transform(df_3bed[["MA"]])

look_back_3bed = 2

train_size_3bed = int(len(scaled_3bed) * 0.8)

train_3bed = scaled_3bed[:train_size_3bed]
test_3bed  = scaled_3bed[train_size_3bed:]

trainX_3bed, trainY_3bed = create_sequences(train_3bed, look_back_3bed)
testX_3bed,  testY_3bed  = create_sequences(test_3bed,  look_back_3bed)

print("trainX shape:", trainX_3bed.shape)
print("testX shape: ", testX_3bed.shape)
# Out:
# trainX shape: (38, 2, 1)
# testX shape:  (9, 2, 1)

# %% [markdown]
# ### Model 1 — Small RNN (baseline)
#
# A minimal SimpleRNN with 16 units, mirroring the market-level baseline above. This gives us a reference point: does the same architecture generalize to a focused subgroup, or does the smaller dataset expose underfitting?

# %%
# Model 1: Small SimpleRNN — 16 units, look_back=2 (same as market-level baseline)

rnn_small = Sequential([
    SimpleRNN(
        16,
        activation="tanh",
        input_shape=(look_back_3bed, trainX_3bed.shape[2])
    ),
    Dense(1)
])

rnn_small.compile(
    optimizer="adam",
    loss="mean_squared_error",
    metrics=["mean_absolute_error"]
)

history_rnn_small = rnn_small.fit(
    trainX_3bed,
    trainY_3bed,
    epochs=100,
    batch_size=8,
    validation_split=0.2,
    shuffle=False,
    verbose=1
)
# Out:
# Epoch 1/100
# c:\Users\tyler\anaconda3\Lib\site-packages\keras\src\layers\rnn\rnn.py:199: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 72ms/step - loss: 0.0056 - mean_absolute_error: 0.0601 - val_loss: 0.0039 - val_mean_absolute_error: 0.0601
# Epoch 2/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.0029 - mean_absolute_error: 0.0342 - val_loss: 2.0027e-04 - val_mean_absolute_error: 0.0124
# Epoch 3/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.0035 - mean_absolute_error: 0.0473 - val_loss: 4.4490e-04 - val_mean_absolute_error: 0.0171
# Epoch 4/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.0025 - mean_absolute_error: 0.0339 - val_loss: 0.0034 - val_mean_absolute_error: 0.0565
# Epoch 5/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0025 - mean_absolute_error: 0.0322 - val_loss: 0.0066 - val_mean_absolute_error: 0.0794
# Epoch 6/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - loss: 0.0025 - mean_absolute_error: 0.0316 - val_loss: 0.0054 - val_mean_absolute_error: 0.0717
# Epoch 7/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.0021 - mean_absolute_error: 0.0277 - val_loss: 0.0030 - val_mean_absolute_error: 0.0520
# Epoch 8/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.0022 - mean_absolute_error: 0.0312 - val_loss: 0.0021 - val_mean_absolute_error: 0.0434
# Epoch 9/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.0022 - mean_absolute_error: 0.0322 - val_loss: 0.0030 - val_mean_absolute_error: 0.0521
# Epoch 10/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.0021 - mean_absolute_error: 0.0309 - val_loss: 0.0046 - val_mean_absolute_error: 0.0657
# Epoch 11/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.0021 - mean_absolute_error: 0.0310 - val_loss: 0.0052 - val_mean_absolute_error: 0.0702
# Epoch 12/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0020 - mean_absolute_error: 0.0301 - val_loss: 0.0045 - val_mean_absolute_error: 0.0651
# Epoch 13/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0020 - mean_absolute_error: 0.0299 - val_loss: 0.0039 - val_mean_absolute_error: 0.0598
# Epoch 14/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0020 - mean_absolute_error: 0.0306 - val_loss: 0.0040 - val_mean_absolute_error: 0.0611
# Epoch 15/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step - loss: 0.0020 - mean_absolute_error: 0.0310 - val_loss: 0.0047 - val_mean_absolute_error: 0.0662
# Epoch 16/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 79ms/step - loss: 0.0020 - mean_absolute_error: 0.0311 - val_loss: 0.0051 - val_mean_absolute_error: 0.0690
# Epoch 17/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step - loss: 0.0020 - mean_absolute_error: 0.0308 - val_loss: 0.0049 - val_mean_absolute_error: 0.0676
# Epoch 18/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 94ms/step - loss: 0.0020 - mean_absolute_error: 0.0307 - val_loss: 0.0046 - val_mean_absolute_error: 0.0655
# Epoch 19/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 82ms/step - loss: 0.0020 - mean_absolute_error: 0.0309 - val_loss: 0.0046 - val_mean_absolute_error: 0.0657
# Epoch 20/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step - loss: 0.0020 - mean_absolute_error: 0.0311 - val_loss: 0.0049 - val_mean_absolute_error: 0.0676
# Epoch 21/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 78ms/step - loss: 0.0020 - mean_absolute_error: 0.0311 - val_loss: 0.0050 - val_mean_absolute_error: 0.0685
# Epoch 22/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step - loss: 0.0020 - mean_absolute_error: 0.0310 - val_loss: 0.0049 - val_mean_absolute_error: 0.0678
# Epoch 23/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step - loss: 0.0020 - mean_absolute_error: 0.0309 - val_loss: 0.0048 - val_mean_absolute_error: 0.0669
# Epoch 24/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step - loss: 0.0020 - mean_absolute_error: 0.0309 - val_loss: 0.0048 - val_mean_absolute_error: 0.0670
# Epoch 25/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 92ms/step - loss: 0.0020 - mean_absolute_error: 0.0310 - val_loss: 0.0049 - val_mean_absolute_error: 0.0676
# Epoch 26/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 86ms/step - loss: 0.0020 - mean_absolute_error: 0.0309 - val_loss: 0.0049 - val_mean_absolute_error: 0.0677
# Epoch 27/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 87ms/step - loss: 0.0020 - mean_absolute_error: 0.0308 - val_loss: 0.0048 - val_mean_absolute_error: 0.0672
# Epoch 28/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 90ms/step - loss: 0.0020 - mean_absolute_error: 0.0308 - val_loss: 0.0048 - val_mean_absolute_error: 0.0668
# Epoch 29/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 84ms/step - loss: 0.0020 - mean_absolute_error: 0.0307 - val_loss: 0.0048 - val_mean_absolute_error: 0.0668
# Epoch 30/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step - loss: 0.0020 - mean_absolute_error: 0.0307 - val_loss: 0.0048 - val_mean_absolute_error: 0.0668
# Epoch 31/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step - loss: 0.0020 - mean_absolute_error: 0.0306 - val_loss: 0.0047 - val_mean_absolute_error: 0.0667
# Epoch 32/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 121ms/step - loss: 0.0019 - mean_absolute_error: 0.0306 - val_loss: 0.0047 - val_mean_absolute_error: 0.0664
# Epoch 33/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 91ms/step - loss: 0.0019 - mean_absolute_error: 0.0305 - val_loss: 0.0047 - val_mean_absolute_error: 0.0662
# Epoch 34/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 87ms/step - loss: 0.0019 - mean_absolute_error: 0.0305 - val_loss: 0.0047 - val_mean_absolute_error: 0.0661
# Epoch 35/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 87ms/step - loss: 0.0019 - mean_absolute_error: 0.0305 - val_loss: 0.0046 - val_mean_absolute_error: 0.0659
# Epoch 36/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step - loss: 0.0019 - mean_absolute_error: 0.0304 - val_loss: 0.0046 - val_mean_absolute_error: 0.0657
# Epoch 37/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 91ms/step - loss: 0.0019 - mean_absolute_error: 0.0303 - val_loss: 0.0046 - val_mean_absolute_error: 0.0655
# Epoch 38/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 93ms/step - loss: 0.0019 - mean_absolute_error: 0.0303 - val_loss: 0.0046 - val_mean_absolute_error: 0.0654
# Epoch 39/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 95ms/step - loss: 0.0019 - mean_absolute_error: 0.0303 - val_loss: 0.0045 - val_mean_absolute_error: 0.0652
# Epoch 40/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step - loss: 0.0019 - mean_absolute_error: 0.0302 - val_loss: 0.0045 - val_mean_absolute_error: 0.0651
# Epoch 41/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 93ms/step - loss: 0.0019 - mean_absolute_error: 0.0302 - val_loss: 0.0045 - val_mean_absolute_error: 0.0649
# Epoch 42/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step - loss: 0.0019 - mean_absolute_error: 0.0301 - val_loss: 0.0045 - val_mean_absolute_error: 0.0647
# Epoch 43/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step - loss: 0.0019 - mean_absolute_error: 0.0301 - val_loss: 0.0044 - val_mean_absolute_error: 0.0646
# Epoch 44/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step - loss: 0.0019 - mean_absolute_error: 0.0300 - val_loss: 0.0044 - val_mean_absolute_error: 0.0644
# Epoch 45/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step - loss: 0.0019 - mean_absolute_error: 0.0300 - val_loss: 0.0044 - val_mean_absolute_error: 0.0642
# Epoch 46/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step - loss: 0.0019 - mean_absolute_error: 0.0299 - val_loss: 0.0044 - val_mean_absolute_error: 0.0641
# Epoch 47/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 86ms/step - loss: 0.0019 - mean_absolute_error: 0.0299 - val_loss: 0.0044 - val_mean_absolute_error: 0.0639
# Epoch 48/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 80ms/step - loss: 0.0019 - mean_absolute_error: 0.0299 - val_loss: 0.0043 - val_mean_absolute_error: 0.0638
# Epoch 49/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step - loss: 0.0019 - mean_absolute_error: 0.0298 - val_loss: 0.0043 - val_mean_absolute_error: 0.0636
# Epoch 50/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step - loss: 0.0019 - mean_absolute_error: 0.0298 - val_loss: 0.0043 - val_mean_absolute_error: 0.0635
# Epoch 51/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step - loss: 0.0019 - mean_absolute_error: 0.0297 - val_loss: 0.0043 - val_mean_absolute_error: 0.0633
# Epoch 52/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 83ms/step - loss: 0.0019 - mean_absolute_error: 0.0297 - val_loss: 0.0043 - val_mean_absolute_error: 0.0632
# Epoch 53/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step - loss: 0.0019 - mean_absolute_error: 0.0297 - val_loss: 0.0042 - val_mean_absolute_error: 0.0630
# Epoch 54/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step - loss: 0.0019 - mean_absolute_error: 0.0296 - val_loss: 0.0042 - val_mean_absolute_error: 0.0629
# Epoch 55/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step - loss: 0.0019 - mean_absolute_error: 0.0296 - val_loss: 0.0042 - val_mean_absolute_error: 0.0627
# Epoch 56/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step - loss: 0.0019 - mean_absolute_error: 0.0295 - val_loss: 0.0042 - val_mean_absolute_error: 0.0626
# Epoch 57/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step - loss: 0.0019 - mean_absolute_error: 0.0295 - val_loss: 0.0042 - val_mean_absolute_error: 0.0624
# Epoch 58/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step - loss: 0.0019 - mean_absolute_error: 0.0295 - val_loss: 0.0041 - val_mean_absolute_error: 0.0623
# Epoch 59/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step - loss: 0.0019 - mean_absolute_error: 0.0294 - val_loss: 0.0041 - val_mean_absolute_error: 0.0621
# Epoch 60/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 93ms/step - loss: 0.0019 - mean_absolute_error: 0.0294 - val_loss: 0.0041 - val_mean_absolute_error: 0.0620
# Epoch 61/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 87ms/step - loss: 0.0019 - mean_absolute_error: 0.0293 - val_loss: 0.0041 - val_mean_absolute_error: 0.0618
# Epoch 62/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step - loss: 0.0019 - mean_absolute_error: 0.0293 - val_loss: 0.0041 - val_mean_absolute_error: 0.0617
# Epoch 63/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 92ms/step - loss: 0.0019 - mean_absolute_error: 0.0293 - val_loss: 0.0040 - val_mean_absolute_error: 0.0616
# Epoch 64/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step - loss: 0.0019 - mean_absolute_error: 0.0292 - val_loss: 0.0040 - val_mean_absolute_error: 0.0614
# Epoch 65/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 86ms/step - loss: 0.0019 - mean_absolute_error: 0.0292 - val_loss: 0.0040 - val_mean_absolute_error: 0.0613
# Epoch 66/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step - loss: 0.0019 - mean_absolute_error: 0.0292 - val_loss: 0.0040 - val_mean_absolute_error: 0.0611
# Epoch 67/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step - loss: 0.0019 - mean_absolute_error: 0.0291 - val_loss: 0.0040 - val_mean_absolute_error: 0.0610
# Epoch 68/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 111ms/step - loss: 0.0019 - mean_absolute_error: 0.0291 - val_loss: 0.0039 - val_mean_absolute_error: 0.0608
# Epoch 69/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 88ms/step - loss: 0.0019 - mean_absolute_error: 0.0290 - val_loss: 0.0039 - val_mean_absolute_error: 0.0607
# Epoch 70/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step - loss: 0.0019 - mean_absolute_error: 0.0290 - val_loss: 0.0039 - val_mean_absolute_error: 0.0606
# Epoch 71/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 89ms/step - loss: 0.0019 - mean_absolute_error: 0.0290 - val_loss: 0.0039 - val_mean_absolute_error: 0.0604
# Epoch 72/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 88ms/step - loss: 0.0019 - mean_absolute_error: 0.0289 - val_loss: 0.0039 - val_mean_absolute_error: 0.0603
# Epoch 73/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 87ms/step - loss: 0.0019 - mean_absolute_error: 0.0289 - val_loss: 0.0039 - val_mean_absolute_error: 0.0602
# Epoch 74/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 87ms/step - loss: 0.0019 - mean_absolute_error: 0.0289 - val_loss: 0.0038 - val_mean_absolute_error: 0.0600
# Epoch 75/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 88ms/step - loss: 0.0019 - mean_absolute_error: 0.0288 - val_loss: 0.0038 - val_mean_absolute_error: 0.0599
# Epoch 76/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 106ms/step - loss: 0.0019 - mean_absolute_error: 0.0288 - val_loss: 0.0038 - val_mean_absolute_error: 0.0598
# Epoch 77/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step - loss: 0.0018 - mean_absolute_error: 0.0288 - val_loss: 0.0038 - val_mean_absolute_error: 0.0596
# Epoch 78/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step - loss: 0.0018 - mean_absolute_error: 0.0287 - val_loss: 0.0038 - val_mean_absolute_error: 0.0595
# Epoch 79/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step - loss: 0.0018 - mean_absolute_error: 0.0287 - val_loss: 0.0038 - val_mean_absolute_error: 0.0594
# Epoch 80/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 80ms/step - loss: 0.0018 - mean_absolute_error: 0.0287 - val_loss: 0.0037 - val_mean_absolute_error: 0.0592
# Epoch 81/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 112ms/step - loss: 0.0018 - mean_absolute_error: 0.0286 - val_loss: 0.0037 - val_mean_absolute_error: 0.0591
# Epoch 82/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step - loss: 0.0018 - mean_absolute_error: 0.0286 - val_loss: 0.0037 - val_mean_absolute_error: 0.0590
# Epoch 83/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step - loss: 0.0018 - mean_absolute_error: 0.0286 - val_loss: 0.0037 - val_mean_absolute_error: 0.0588
# Epoch 84/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step - loss: 0.0018 - mean_absolute_error: 0.0285 - val_loss: 0.0037 - val_mean_absolute_error: 0.0587
# Epoch 85/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 79ms/step - loss: 0.0018 - mean_absolute_error: 0.0285 - val_loss: 0.0037 - val_mean_absolute_error: 0.0586
# Epoch 86/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step - loss: 0.0018 - mean_absolute_error: 0.0285 - val_loss: 0.0036 - val_mean_absolute_error: 0.0585
# Epoch 87/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step - loss: 0.0018 - mean_absolute_error: 0.0284 - val_loss: 0.0036 - val_mean_absolute_error: 0.0583
# Epoch 88/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step - loss: 0.0018 - mean_absolute_error: 0.0284 - val_loss: 0.0036 - val_mean_absolute_error: 0.0582
# Epoch 89/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step - loss: 0.0018 - mean_absolute_error: 0.0284 - val_loss: 0.0036 - val_mean_absolute_error: 0.0581
# Epoch 90/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step - loss: 0.0018 - mean_absolute_error: 0.0283 - val_loss: 0.0036 - val_mean_absolute_error: 0.0580
# Epoch 91/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step - loss: 0.0018 - mean_absolute_error: 0.0283 - val_loss: 0.0036 - val_mean_absolute_error: 0.0578
# Epoch 92/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step - loss: 0.0018 - mean_absolute_error: 0.0283 - val_loss: 0.0036 - val_mean_absolute_error: 0.0577
# Epoch 93/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step - loss: 0.0018 - mean_absolute_error: 0.0283 - val_loss: 0.0035 - val_mean_absolute_error: 0.0576
# Epoch 94/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step - loss: 0.0018 - mean_absolute_error: 0.0282 - val_loss: 0.0035 - val_mean_absolute_error: 0.0575
# Epoch 95/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 93ms/step - loss: 0.0018 - mean_absolute_error: 0.0282 - val_loss: 0.0035 - val_mean_absolute_error: 0.0574
# Epoch 96/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 88ms/step - loss: 0.0018 - mean_absolute_error: 0.0282 - val_loss: 0.0035 - val_mean_absolute_error: 0.0572
# Epoch 97/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step - loss: 0.0018 - mean_absolute_error: 0.0281 - val_loss: 0.0035 - val_mean_absolute_error: 0.0571
# Epoch 98/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step - loss: 0.0018 - mean_absolute_error: 0.0281 - val_loss: 0.0035 - val_mean_absolute_error: 0.0570
# Epoch 99/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 98ms/step - loss: 0.0018 - mean_absolute_error: 0.0281 - val_loss: 0.0035 - val_mean_absolute_error: 0.0569
# Epoch 100/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 94ms/step - loss: 0.0018 - mean_absolute_error: 0.0281 - val_loss: 0.0034 - val_mean_absolute_error: 0.0568

# %%
plot_training_curves(history_rnn_small, "Model 1 — Small RNN")

evaluate_and_plot(
    rnn_small,
    trainX_3bed, testX_3bed,
    trainY_3bed, testY_3bed,
    scaler_3bed,
    "Model 1 — Small RNN"
)
# Out:
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 537ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 128ms/step
# Model 1 — Small RNN Train RMSE: 9062.45
# Model 1 — Small RNN Test RMSE: 15821.75

# %% [markdown]
# **Observation — Model 1 (Small RNN):** With only 16 hidden units and a 2-step look-back the model is intentionally parsimonious. On a small subgroup series this often leads to stable but slightly underfitted training curves (val loss tracks train loss closely but both plateau high). Test predictions tend to lag slightly behind the actual trend — expected given minimal memory capacity.

# %% [markdown]
# ### Model 2 — Larger RNN with wider look-back window
#
# Increasing both the hidden units (64) and the look-back window (4 timesteps) gives the network more historical context per prediction and more representational capacity. This tests whether the 3-bedroom subgroup contains enough signal across a longer horizon to improve over the baseline.

# %%
# Model 2: Larger SimpleRNN — 64 units, look_back=4

look_back_m2 = 4

trainX_m2, trainY_m2 = create_sequences(train_3bed, look_back_m2)
testX_m2,  testY_m2  = create_sequences(test_3bed,  look_back_m2)

rnn_large = Sequential([
    SimpleRNN(
        64,
        activation="tanh",
        input_shape=(look_back_m2, trainX_m2.shape[2])
    ),
    Dense(1)
])

rnn_large.compile(
    optimizer="adam",
    loss="mean_squared_error",
    metrics=["mean_absolute_error"]
)

history_rnn_large = rnn_large.fit(
    trainX_m2,
    trainY_m2,
    epochs=100,
    batch_size=8,
    validation_split=0.2,
    shuffle=False,
    verbose=1
)
# Out:
# c:\Users\tyler\anaconda3\Lib\site-packages\keras\src\layers\rnn\rnn.py:199: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Epoch 1/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 7s 428ms/step - loss: 0.0492 - mean_absolute_error: 0.2101 - val_loss: 5.1543e-04 - val_mean_absolute_error: 0.0193
# Epoch 2/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 87ms/step - loss: 0.0325 - mean_absolute_error: 0.1584 - val_loss: 0.0228 - val_mean_absolute_error: 0.1501
# Epoch 3/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step - loss: 0.0124 - mean_absolute_error: 0.0975 - val_loss: 0.0080 - val_mean_absolute_error: 0.0857
# Epoch 4/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 86ms/step - loss: 0.0065 - mean_absolute_error: 0.0675 - val_loss: 0.0506 - val_mean_absolute_error: 0.2228
# Epoch 5/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step - loss: 0.0104 - mean_absolute_error: 0.0927 - val_loss: 0.0300 - val_mean_absolute_error: 0.1710
# Epoch 6/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 87ms/step - loss: 0.0024 - mean_absolute_error: 0.0419 - val_loss: 0.0030 - val_mean_absolute_error: 0.0498
# Epoch 7/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 86ms/step - loss: 0.0038 - mean_absolute_error: 0.0523 - val_loss: 4.6428e-04 - val_mean_absolute_error: 0.0191
# Epoch 8/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 90ms/step - loss: 0.0042 - mean_absolute_error: 0.0547 - val_loss: 0.0020 - val_mean_absolute_error: 0.0390
# Epoch 9/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step - loss: 0.0018 - mean_absolute_error: 0.0356 - val_loss: 0.0116 - val_mean_absolute_error: 0.1048
# Epoch 10/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step - loss: 0.0024 - mean_absolute_error: 0.0407 - val_loss: 0.0147 - val_mean_absolute_error: 0.1188
# Epoch 11/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 86ms/step - loss: 0.0018 - mean_absolute_error: 0.0357 - val_loss: 0.0074 - val_mean_absolute_error: 0.0826
# Epoch 12/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 87ms/step - loss: 0.0015 - mean_absolute_error: 0.0311 - val_loss: 0.0029 - val_mean_absolute_error: 0.0493
# Epoch 13/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step - loss: 0.0019 - mean_absolute_error: 0.0360 - val_loss: 0.0035 - val_mean_absolute_error: 0.0547
# Epoch 14/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step - loss: 0.0015 - mean_absolute_error: 0.0322 - val_loss: 0.0070 - val_mean_absolute_error: 0.0803
# Epoch 15/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 88ms/step - loss: 0.0015 - mean_absolute_error: 0.0316 - val_loss: 0.0085 - val_mean_absolute_error: 0.0893
# Epoch 16/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 93ms/step - loss: 0.0013 - mean_absolute_error: 0.0300 - val_loss: 0.0062 - val_mean_absolute_error: 0.0756
# Epoch 17/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 86ms/step - loss: 0.0013 - mean_absolute_error: 0.0293 - val_loss: 0.0044 - val_mean_absolute_error: 0.0627
# Epoch 18/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 93ms/step - loss: 0.0014 - mean_absolute_error: 0.0305 - val_loss: 0.0049 - val_mean_absolute_error: 0.0664
# Epoch 19/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step - loss: 0.0013 - mean_absolute_error: 0.0294 - val_loss: 0.0063 - val_mean_absolute_error: 0.0759
# Epoch 20/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 88ms/step - loss: 0.0013 - mean_absolute_error: 0.0285 - val_loss: 0.0063 - val_mean_absolute_error: 0.0758
# Epoch 21/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 90ms/step - loss: 0.0012 - mean_absolute_error: 0.0279 - val_loss: 0.0052 - val_mean_absolute_error: 0.0684
# Epoch 22/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step - loss: 0.0012 - mean_absolute_error: 0.0282 - val_loss: 0.0048 - val_mean_absolute_error: 0.0657
# Epoch 23/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step - loss: 0.0012 - mean_absolute_error: 0.0280 - val_loss: 0.0053 - val_mean_absolute_error: 0.0690
# Epoch 24/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 93ms/step - loss: 0.0012 - mean_absolute_error: 0.0275 - val_loss: 0.0055 - val_mean_absolute_error: 0.0705
# Epoch 25/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step - loss: 0.0011 - mean_absolute_error: 0.0270 - val_loss: 0.0050 - val_mean_absolute_error: 0.0673
# Epoch 26/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step - loss: 0.0011 - mean_absolute_error: 0.0269 - val_loss: 0.0046 - val_mean_absolute_error: 0.0647
# Epoch 27/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 116ms/step - loss: 0.0011 - mean_absolute_error: 0.0268 - val_loss: 0.0047 - val_mean_absolute_error: 0.0654
# Epoch 28/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 119ms/step - loss: 0.0011 - mean_absolute_error: 0.0264 - val_loss: 0.0048 - val_mean_absolute_error: 0.0658
# Epoch 29/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 86ms/step - loss: 0.0011 - mean_absolute_error: 0.0260 - val_loss: 0.0045 - val_mean_absolute_error: 0.0640
# Epoch 30/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step - loss: 0.0011 - mean_absolute_error: 0.0259 - val_loss: 0.0043 - val_mean_absolute_error: 0.0623
# Epoch 31/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step - loss: 0.0011 - mean_absolute_error: 0.0257 - val_loss: 0.0043 - val_mean_absolute_error: 0.0622
# Epoch 32/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 92ms/step - loss: 0.0011 - mean_absolute_error: 0.0254 - val_loss: 0.0043 - val_mean_absolute_error: 0.0619
# Epoch 33/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step - loss: 0.0010 - mean_absolute_error: 0.0252 - val_loss: 0.0041 - val_mean_absolute_error: 0.0605
# Epoch 34/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step - loss: 0.0010 - mean_absolute_error: 0.0251 - val_loss: 0.0040 - val_mean_absolute_error: 0.0594
# Epoch 35/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step - loss: 0.0010 - mean_absolute_error: 0.0249 - val_loss: 0.0039 - val_mean_absolute_error: 0.0590
# Epoch 36/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step - loss: 0.0010 - mean_absolute_error: 0.0247 - val_loss: 0.0038 - val_mean_absolute_error: 0.0584
# Epoch 37/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 84ms/step - loss: 9.9852e-04 - mean_absolute_error: 0.0246 - val_loss: 0.0037 - val_mean_absolute_error: 0.0573
# Epoch 38/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 88ms/step - loss: 9.9011e-04 - mean_absolute_error: 0.0244 - val_loss: 0.0036 - val_mean_absolute_error: 0.0565
# Epoch 39/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 86ms/step - loss: 9.8100e-04 - mean_absolute_error: 0.0243 - val_loss: 0.0035 - val_mean_absolute_error: 0.0560
# Epoch 40/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 113ms/step - loss: 9.7146e-04 - mean_absolute_error: 0.0242 - val_loss: 0.0034 - val_mean_absolute_error: 0.0552
# Epoch 41/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 91ms/step - loss: 9.6334e-04 - mean_absolute_error: 0.0241 - val_loss: 0.0033 - val_mean_absolute_error: 0.0544
# Epoch 42/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 120ms/step - loss: 9.5585e-04 - mean_absolute_error: 0.0239 - val_loss: 0.0033 - val_mean_absolute_error: 0.0538
# Epoch 43/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 119ms/step - loss: 9.4801e-04 - mean_absolute_error: 0.0238 - val_loss: 0.0032 - val_mean_absolute_error: 0.0532
# Epoch 44/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 97ms/step - loss: 9.4067e-04 - mean_absolute_error: 0.0237 - val_loss: 0.0031 - val_mean_absolute_error: 0.0525
# Epoch 45/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 94ms/step - loss: 9.3410e-04 - mean_absolute_error: 0.0236 - val_loss: 0.0031 - val_mean_absolute_error: 0.0518
# Epoch 46/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 98ms/step - loss: 9.2759e-04 - mean_absolute_error: 0.0235 - val_loss: 0.0030 - val_mean_absolute_error: 0.0513
# Epoch 47/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 120ms/step - loss: 9.2125e-04 - mean_absolute_error: 0.0234 - val_loss: 0.0029 - val_mean_absolute_error: 0.0507
# Epoch 48/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 92ms/step - loss: 9.1547e-04 - mean_absolute_error: 0.0234 - val_loss: 0.0029 - val_mean_absolute_error: 0.0501
# Epoch 49/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 96ms/step - loss: 9.0993e-04 - mean_absolute_error: 0.0234 - val_loss: 0.0028 - val_mean_absolute_error: 0.0496
# Epoch 50/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 92ms/step - loss: 9.0452e-04 - mean_absolute_error: 0.0234 - val_loss: 0.0028 - val_mean_absolute_error: 0.0490
# Epoch 51/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 78ms/step - loss: 8.9947e-04 - mean_absolute_error: 0.0234 - val_loss: 0.0027 - val_mean_absolute_error: 0.0485
# Epoch 52/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step - loss: 8.9469e-04 - mean_absolute_error: 0.0234 - val_loss: 0.0027 - val_mean_absolute_error: 0.0480
# Epoch 53/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 95ms/step - loss: 8.9005e-04 - mean_absolute_error: 0.0234 - val_loss: 0.0026 - val_mean_absolute_error: 0.0475
# Epoch 54/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 89ms/step - loss: 8.8566e-04 - mean_absolute_error: 0.0234 - val_loss: 0.0026 - val_mean_absolute_error: 0.0470
# Epoch 55/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 90ms/step - loss: 8.8150e-04 - mean_absolute_error: 0.0234 - val_loss: 0.0025 - val_mean_absolute_error: 0.0466
# Epoch 56/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step - loss: 8.7748e-04 - mean_absolute_error: 0.0234 - val_loss: 0.0025 - val_mean_absolute_error: 0.0462
# Epoch 57/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 91ms/step - loss: 8.7365e-04 - mean_absolute_error: 0.0234 - val_loss: 0.0024 - val_mean_absolute_error: 0.0457
# Epoch 58/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 85ms/step - loss: 8.7000e-04 - mean_absolute_error: 0.0234 - val_loss: 0.0024 - val_mean_absolute_error: 0.0453
# Epoch 59/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 98ms/step - loss: 8.6648e-04 - mean_absolute_error: 0.0234 - val_loss: 0.0024 - val_mean_absolute_error: 0.0449
# Epoch 60/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 101ms/step - loss: 8.6311e-04 - mean_absolute_error: 0.0234 - val_loss: 0.0023 - val_mean_absolute_error: 0.0446
# Epoch 61/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 94ms/step - loss: 8.5987e-04 - mean_absolute_error: 0.0234 - val_loss: 0.0023 - val_mean_absolute_error: 0.0442
# Epoch 62/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 101ms/step - loss: 8.5675e-04 - mean_absolute_error: 0.0234 - val_loss: 0.0022 - val_mean_absolute_error: 0.0438
# Epoch 63/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 86ms/step - loss: 8.5374e-04 - mean_absolute_error: 0.0233 - val_loss: 0.0022 - val_mean_absolute_error: 0.0435
# Epoch 64/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 86ms/step - loss: 8.5084e-04 - mean_absolute_error: 0.0233 - val_loss: 0.0022 - val_mean_absolute_error: 0.0432
# Epoch 65/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step - loss: 8.4803e-04 - mean_absolute_error: 0.0233 - val_loss: 0.0022 - val_mean_absolute_error: 0.0429
# Epoch 66/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 85ms/step - loss: 8.4531e-04 - mean_absolute_error: 0.0233 - val_loss: 0.0021 - val_mean_absolute_error: 0.0426
# Epoch 67/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 93ms/step - loss: 8.4267e-04 - mean_absolute_error: 0.0233 - val_loss: 0.0021 - val_mean_absolute_error: 0.0423
# Epoch 68/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step - loss: 8.4010e-04 - mean_absolute_error: 0.0233 - val_loss: 0.0021 - val_mean_absolute_error: 0.0420
# Epoch 69/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 87ms/step - loss: 8.3761e-04 - mean_absolute_error: 0.0232 - val_loss: 0.0021 - val_mean_absolute_error: 0.0417
# Epoch 70/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 113ms/step - loss: 8.3517e-04 - mean_absolute_error: 0.0232 - val_loss: 0.0020 - val_mean_absolute_error: 0.0415
# Epoch 71/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step - loss: 8.3280e-04 - mean_absolute_error: 0.0232 - val_loss: 0.0020 - val_mean_absolute_error: 0.0412
# Epoch 72/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step - loss: 8.3047e-04 - mean_absolute_error: 0.0232 - val_loss: 0.0020 - val_mean_absolute_error: 0.0410
# Epoch 73/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step - loss: 8.2819e-04 - mean_absolute_error: 0.0232 - val_loss: 0.0020 - val_mean_absolute_error: 0.0407
# Epoch 74/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step - loss: 8.2596e-04 - mean_absolute_error: 0.0232 - val_loss: 0.0019 - val_mean_absolute_error: 0.0405
# Epoch 75/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 88ms/step - loss: 8.2376e-04 - mean_absolute_error: 0.0231 - val_loss: 0.0019 - val_mean_absolute_error: 0.0403
# Epoch 76/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step - loss: 8.2160e-04 - mean_absolute_error: 0.0231 - val_loss: 0.0019 - val_mean_absolute_error: 0.0401
# Epoch 77/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step - loss: 8.1947e-04 - mean_absolute_error: 0.0231 - val_loss: 0.0019 - val_mean_absolute_error: 0.0399
# Epoch 78/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 88ms/step - loss: 8.1737e-04 - mean_absolute_error: 0.0231 - val_loss: 0.0019 - val_mean_absolute_error: 0.0397
# Epoch 79/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 84ms/step - loss: 8.1529e-04 - mean_absolute_error: 0.0230 - val_loss: 0.0019 - val_mean_absolute_error: 0.0395
# Epoch 80/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 89ms/step - loss: 8.1324e-04 - mean_absolute_error: 0.0230 - val_loss: 0.0018 - val_mean_absolute_error: 0.0393
# Epoch 81/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 87ms/step - loss: 8.1121e-04 - mean_absolute_error: 0.0230 - val_loss: 0.0018 - val_mean_absolute_error: 0.0392
# Epoch 82/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step - loss: 8.0920e-04 - mean_absolute_error: 0.0230 - val_loss: 0.0018 - val_mean_absolute_error: 0.0390
# Epoch 83/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 86ms/step - loss: 8.0720e-04 - mean_absolute_error: 0.0229 - val_loss: 0.0018 - val_mean_absolute_error: 0.0388
# Epoch 84/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 83ms/step - loss: 8.0522e-04 - mean_absolute_error: 0.0229 - val_loss: 0.0018 - val_mean_absolute_error: 0.0387
# Epoch 85/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step - loss: 8.0326e-04 - mean_absolute_error: 0.0229 - val_loss: 0.0018 - val_mean_absolute_error: 0.0386
# Epoch 86/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step - loss: 8.0130e-04 - mean_absolute_error: 0.0229 - val_loss: 0.0018 - val_mean_absolute_error: 0.0384
# Epoch 87/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 116ms/step - loss: 7.9936e-04 - mean_absolute_error: 0.0228 - val_loss: 0.0018 - val_mean_absolute_error: 0.0383
# Epoch 88/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step - loss: 7.9742e-04 - mean_absolute_error: 0.0228 - val_loss: 0.0017 - val_mean_absolute_error: 0.0381
# Epoch 89/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step - loss: 7.9549e-04 - mean_absolute_error: 0.0228 - val_loss: 0.0017 - val_mean_absolute_error: 0.0380
# Epoch 90/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step - loss: 7.9357e-04 - mean_absolute_error: 0.0228 - val_loss: 0.0017 - val_mean_absolute_error: 0.0379
# Epoch 91/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 107ms/step - loss: 7.9165e-04 - mean_absolute_error: 0.0228 - val_loss: 0.0017 - val_mean_absolute_error: 0.0378
# Epoch 92/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step - loss: 7.8974e-04 - mean_absolute_error: 0.0227 - val_loss: 0.0017 - val_mean_absolute_error: 0.0377
# Epoch 93/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step - loss: 7.8784e-04 - mean_absolute_error: 0.0227 - val_loss: 0.0017 - val_mean_absolute_error: 0.0376
# Epoch 94/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step - loss: 7.8593e-04 - mean_absolute_error: 0.0227 - val_loss: 0.0017 - val_mean_absolute_error: 0.0375
# Epoch 95/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step - loss: 7.8403e-04 - mean_absolute_error: 0.0227 - val_loss: 0.0017 - val_mean_absolute_error: 0.0373
# Epoch 96/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step - loss: 7.8214e-04 - mean_absolute_error: 0.0226 - val_loss: 0.0017 - val_mean_absolute_error: 0.0372
# Epoch 97/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step - loss: 7.8024e-04 - mean_absolute_error: 0.0226 - val_loss: 0.0017 - val_mean_absolute_error: 0.0372
# Epoch 98/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step - loss: 7.7835e-04 - mean_absolute_error: 0.0226 - val_loss: 0.0017 - val_mean_absolute_error: 0.0371
# Epoch 99/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step - loss: 7.7646e-04 - mean_absolute_error: 0.0226 - val_loss: 0.0016 - val_mean_absolute_error: 0.0370
# Epoch 100/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 81ms/step - loss: 7.7457e-04 - mean_absolute_error: 0.0225 - val_loss: 0.0016 - val_mean_absolute_error: 0.0369

# %%
plot_training_curves(history_rnn_large, "Model 2 — Larger RNN (64 units, look_back=4)")

evaluate_and_plot(
    rnn_large,
    trainX_m2, testX_m2,
    trainY_m2, testY_m2,
    scaler_3bed,
    "Model 2 — Larger RNN (64 units, look_back=4)"
)
# Out:
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 562ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 132ms/step
# Model 2 — Larger RNN (64 units, look_back=4) Train RMSE: 6060.75
# Model 2 — Larger RNN (64 units, look_back=4) Test RMSE: 8463.20

# %% [markdown]
# **Observation — Model 2 (Larger RNN, look_back=4):** Widening the look-back to 4 and increasing capacity to 64 units gives the model more context. If the 3-bedroom series has slowly evolving trends, validation loss should decrease relative to Model 1. However, with a small dataset, the larger capacity can also produce a diverging validation curve (overfitting) — compare the gap between training and validation MAE lines with Model 1.

# %% [markdown]
# ### Model 3 — Stacked RNN with intermediate Dense layer
#
# Two stacked SimpleRNN layers (32 → 16 units) with a hidden Dense(8) layer before the output. Stacking RNN layers allows the network to learn hierarchical temporal representations — the first layer captures local step-to-step patterns, the second integrates them into longer-range structure. The intermediate Dense layer adds a non-linear mixing stage before regression.

# %%
# Model 3: Stacked SimpleRNN — 32→16 units + Dense(8) hidden layer, look_back=4

from tensorflow.keras.layers import Dropout

rnn_stacked = Sequential([
    SimpleRNN(
        32,
        activation="tanh",
        return_sequences=True,              # pass full sequence to next RNN layer
        input_shape=(look_back_m2, trainX_m2.shape[2])
    ),
    SimpleRNN(
        16,
        activation="tanh"
    ),
    Dense(
        8,
        activation="relu"
    ),
    Dense(1)
])

rnn_stacked.compile(
    optimizer="adam",
    loss="mean_squared_error",
    metrics=["mean_absolute_error"]
)

rnn_stacked.summary()

history_rnn_stacked = rnn_stacked.fit(
    trainX_m2,
    trainY_m2,
    epochs=100,
    batch_size=8,
    validation_split=0.2,
    shuffle=False,
    verbose=1
)
# Out:
# c:\Users\tyler\anaconda3\Lib\site-packages\keras\src\layers\rnn\rnn.py:199: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Model: "sequential_6"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ simple_rnn_4 (SimpleRNN)        │ (None, 4, 32)          │         1,088 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ simple_rnn_5 (SimpleRNN)        │ (None, 16)             │           784 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_8 (Dense)                 │ (None, 8)              │           136 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_9 (Dense)                 │ (None, 1)              │             9 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 2,017 (7.88 KB)
#  Trainable params: 2,017 (7.88 KB)
#  Non-trainable params: 0 (0.00 B)
# Epoch 1/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 13s 587ms/step - loss: 0.0233 - mean_absolute_error: 0.1327 - val_loss: 0.0081 - val_mean_absolute_error: 0.0856
# Epoch 2/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 88ms/step - loss: 0.0188 - mean_absolute_error: 0.1219 - val_loss: 0.0415 - val_mean_absolute_error: 0.2001
# Epoch 3/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step - loss: 0.0124 - mean_absolute_error: 0.0962 - val_loss: 0.0473 - val_mean_absolute_error: 0.2142
# Epoch 4/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 94ms/step - loss: 0.0012 - mean_absolute_error: 0.0267 - val_loss: 0.0018 - val_mean_absolute_error: 0.0350
# Epoch 5/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 92ms/step - loss: 0.0077 - mean_absolute_error: 0.0787 - val_loss: 0.0088 - val_mean_absolute_error: 0.0889
# Epoch 6/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 94ms/step - loss: 0.0036 - mean_absolute_error: 0.0494 - val_loss: 0.0299 - val_mean_absolute_error: 0.1701
# Epoch 7/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 95ms/step - loss: 0.0019 - mean_absolute_error: 0.0356 - val_loss: 0.0083 - val_mean_absolute_error: 0.0871
# Epoch 8/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 119ms/step - loss: 0.0024 - mean_absolute_error: 0.0404 - val_loss: 0.0026 - val_mean_absolute_error: 0.0453
# Epoch 9/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 95ms/step - loss: 0.0020 - mean_absolute_error: 0.0349 - val_loss: 0.0110 - val_mean_absolute_error: 0.1020
# Epoch 10/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 94ms/step - loss: 0.0017 - mean_absolute_error: 0.0338 - val_loss: 0.0094 - val_mean_absolute_error: 0.0941
# Epoch 11/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 92ms/step - loss: 0.0012 - mean_absolute_error: 0.0266 - val_loss: 0.0030 - val_mean_absolute_error: 0.0501
# Epoch 12/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 87ms/step - loss: 0.0015 - mean_absolute_error: 0.0317 - val_loss: 0.0055 - val_mean_absolute_error: 0.0713
# Epoch 13/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 91ms/step - loss: 0.0012 - mean_absolute_error: 0.0288 - val_loss: 0.0073 - val_mean_absolute_error: 0.0827
# Epoch 14/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 89ms/step - loss: 0.0010 - mean_absolute_error: 0.0246 - val_loss: 0.0036 - val_mean_absolute_error: 0.0569
# Epoch 15/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step - loss: 0.0011 - mean_absolute_error: 0.0276 - val_loss: 0.0045 - val_mean_absolute_error: 0.0644
# Epoch 16/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 92ms/step - loss: 9.9965e-04 - mean_absolute_error: 0.0253 - val_loss: 0.0057 - val_mean_absolute_error: 0.0730
# Epoch 17/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 95ms/step - loss: 8.8008e-04 - mean_absolute_error: 0.0233 - val_loss: 0.0038 - val_mean_absolute_error: 0.0585
# Epoch 18/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 95ms/step - loss: 9.3087e-04 - mean_absolute_error: 0.0246 - val_loss: 0.0043 - val_mean_absolute_error: 0.0630
# Epoch 19/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 89ms/step - loss: 8.5705e-04 - mean_absolute_error: 0.0231 - val_loss: 0.0046 - val_mean_absolute_error: 0.0655
# Epoch 20/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 87ms/step - loss: 7.9950e-04 - mean_absolute_error: 0.0222 - val_loss: 0.0036 - val_mean_absolute_error: 0.0569
# Epoch 21/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 86ms/step - loss: 8.1611e-04 - mean_absolute_error: 0.0226 - val_loss: 0.0040 - val_mean_absolute_error: 0.0604
# Epoch 22/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 89ms/step - loss: 7.6544e-04 - mean_absolute_error: 0.0216 - val_loss: 0.0037 - val_mean_absolute_error: 0.0583
# Epoch 23/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 91ms/step - loss: 7.5043e-04 - mean_absolute_error: 0.0213 - val_loss: 0.0033 - val_mean_absolute_error: 0.0543
# Epoch 24/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 97ms/step - loss: 7.4156e-04 - mean_absolute_error: 0.0211 - val_loss: 0.0034 - val_mean_absolute_error: 0.0560
# Epoch 25/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step - loss: 7.1023e-04 - mean_absolute_error: 0.0204 - val_loss: 0.0030 - val_mean_absolute_error: 0.0524
# Epoch 26/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step - loss: 7.0849e-04 - mean_absolute_error: 0.0203 - val_loss: 0.0030 - val_mean_absolute_error: 0.0517
# Epoch 27/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step - loss: 6.8995e-04 - mean_absolute_error: 0.0199 - val_loss: 0.0029 - val_mean_absolute_error: 0.0510
# Epoch 28/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step - loss: 6.7756e-04 - mean_absolute_error: 0.0197 - val_loss: 0.0026 - val_mean_absolute_error: 0.0487
# Epoch 29/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step - loss: 6.7007e-04 - mean_absolute_error: 0.0194 - val_loss: 0.0026 - val_mean_absolute_error: 0.0488
# Epoch 30/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 89ms/step - loss: 6.5581e-04 - mean_absolute_error: 0.0192 - val_loss: 0.0025 - val_mean_absolute_error: 0.0471
# Epoch 31/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 87ms/step - loss: 6.5036e-04 - mean_absolute_error: 0.0191 - val_loss: 0.0024 - val_mean_absolute_error: 0.0466
# Epoch 32/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 86ms/step - loss: 6.3951e-04 - mean_absolute_error: 0.0188 - val_loss: 0.0023 - val_mean_absolute_error: 0.0457
# Epoch 33/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 88ms/step - loss: 6.3285e-04 - mean_absolute_error: 0.0188 - val_loss: 0.0022 - val_mean_absolute_error: 0.0448
# Epoch 34/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 90ms/step - loss: 6.2544e-04 - mean_absolute_error: 0.0185 - val_loss: 0.0022 - val_mean_absolute_error: 0.0443
# Epoch 35/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 91ms/step - loss: 6.1843e-04 - mean_absolute_error: 0.0184 - val_loss: 0.0021 - val_mean_absolute_error: 0.0433
# Epoch 36/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 88ms/step - loss: 6.1295e-04 - mean_absolute_error: 0.0183 - val_loss: 0.0021 - val_mean_absolute_error: 0.0429
# Epoch 37/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 87ms/step - loss: 6.0661e-04 - mean_absolute_error: 0.0182 - val_loss: 0.0020 - val_mean_absolute_error: 0.0421
# Epoch 38/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step - loss: 6.0201e-04 - mean_absolute_error: 0.0181 - val_loss: 0.0020 - val_mean_absolute_error: 0.0416
# Epoch 39/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 88ms/step - loss: 5.9659e-04 - mean_absolute_error: 0.0180 - val_loss: 0.0019 - val_mean_absolute_error: 0.0410
# Epoch 40/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 86ms/step - loss: 5.9249e-04 - mean_absolute_error: 0.0180 - val_loss: 0.0019 - val_mean_absolute_error: 0.0405
# Epoch 41/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step - loss: 5.8785e-04 - mean_absolute_error: 0.0180 - val_loss: 0.0018 - val_mean_absolute_error: 0.0399
# Epoch 42/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 88ms/step - loss: 5.8417e-04 - mean_absolute_error: 0.0180 - val_loss: 0.0018 - val_mean_absolute_error: 0.0394
# Epoch 43/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 89ms/step - loss: 5.8007e-04 - mean_absolute_error: 0.0180 - val_loss: 0.0017 - val_mean_absolute_error: 0.0390
# Epoch 44/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 89ms/step - loss: 5.7678e-04 - mean_absolute_error: 0.0180 - val_loss: 0.0017 - val_mean_absolute_error: 0.0385
# Epoch 45/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 97ms/step - loss: 5.7307e-04 - mean_absolute_error: 0.0180 - val_loss: 0.0017 - val_mean_absolute_error: 0.0381
# Epoch 46/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 102ms/step - loss: 5.7015e-04 - mean_absolute_error: 0.0180 - val_loss: 0.0016 - val_mean_absolute_error: 0.0377
# Epoch 47/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 90ms/step - loss: 5.6668e-04 - mean_absolute_error: 0.0180 - val_loss: 0.0016 - val_mean_absolute_error: 0.0373
# Epoch 48/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 101ms/step - loss: 5.6412e-04 - mean_absolute_error: 0.0180 - val_loss: 0.0016 - val_mean_absolute_error: 0.0370
# Epoch 49/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step - loss: 5.6079e-04 - mean_absolute_error: 0.0180 - val_loss: 0.0016 - val_mean_absolute_error: 0.0366
# Epoch 50/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 96ms/step - loss: 5.5858e-04 - mean_absolute_error: 0.0180 - val_loss: 0.0015 - val_mean_absolute_error: 0.0363
# Epoch 51/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 86ms/step - loss: 5.5527e-04 - mean_absolute_error: 0.0179 - val_loss: 0.0015 - val_mean_absolute_error: 0.0360
# Epoch 52/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 95ms/step - loss: 5.5346e-04 - mean_absolute_error: 0.0179 - val_loss: 0.0015 - val_mean_absolute_error: 0.0357
# Epoch 53/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - loss: 5.5004e-04 - mean_absolute_error: 0.0179 - val_loss: 0.0015 - val_mean_absolute_error: 0.0353
# Epoch 54/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step - loss: 5.4872e-04 - mean_absolute_error: 0.0179 - val_loss: 0.0014 - val_mean_absolute_error: 0.0352
# Epoch 55/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step - loss: 5.4499e-04 - mean_absolute_error: 0.0178 - val_loss: 0.0014 - val_mean_absolute_error: 0.0347
# Epoch 56/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - loss: 5.4436e-04 - mean_absolute_error: 0.0178 - val_loss: 0.0014 - val_mean_absolute_error: 0.0347
# Epoch 57/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step - loss: 5.4005e-04 - mean_absolute_error: 0.0178 - val_loss: 0.0014 - val_mean_absolute_error: 0.0341
# Epoch 58/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - loss: 5.4042e-04 - mean_absolute_error: 0.0178 - val_loss: 0.0014 - val_mean_absolute_error: 0.0343
# Epoch 59/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step - loss: 5.3508e-04 - mean_absolute_error: 0.0177 - val_loss: 0.0013 - val_mean_absolute_error: 0.0336
# Epoch 60/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 89ms/step - loss: 5.3701e-04 - mean_absolute_error: 0.0177 - val_loss: 0.0013 - val_mean_absolute_error: 0.0339
# Epoch 61/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 92ms/step - loss: 5.2999e-04 - mean_absolute_error: 0.0176 - val_loss: 0.0013 - val_mean_absolute_error: 0.0329
# Epoch 62/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step - loss: 5.3435e-04 - mean_absolute_error: 0.0177 - val_loss: 0.0013 - val_mean_absolute_error: 0.0337
# Epoch 63/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step - loss: 5.2461e-04 - mean_absolute_error: 0.0175 - val_loss: 0.0012 - val_mean_absolute_error: 0.0322
# Epoch 64/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 140ms/step - loss: 5.3287e-04 - mean_absolute_error: 0.0177 - val_loss: 0.0013 - val_mean_absolute_error: 0.0336
# Epoch 65/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step - loss: 5.1881e-04 - mean_absolute_error: 0.0174 - val_loss: 0.0012 - val_mean_absolute_error: 0.0313
# Epoch 66/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 62ms/step - loss: 5.3335e-04 - mean_absolute_error: 0.0176 - val_loss: 0.0013 - val_mean_absolute_error: 0.0337
# Epoch 67/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - loss: 5.1261e-04 - mean_absolute_error: 0.0173 - val_loss: 0.0011 - val_mean_absolute_error: 0.0302
# Epoch 68/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 93ms/step - loss: 5.3725e-04 - mean_absolute_error: 0.0176 - val_loss: 0.0014 - val_mean_absolute_error: 0.0342
# Epoch 69/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 83ms/step - loss: 5.0647e-04 - mean_absolute_error: 0.0172 - val_loss: 0.0010 - val_mean_absolute_error: 0.0286
# Epoch 70/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step - loss: 5.4729e-04 - mean_absolute_error: 0.0177 - val_loss: 0.0014 - val_mean_absolute_error: 0.0352
# Epoch 71/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step - loss: 5.0196e-04 - mean_absolute_error: 0.0171 - val_loss: 8.8930e-04 - val_mean_absolute_error: 0.0265
# Epoch 72/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step - loss: 5.6852e-04 - mean_absolute_error: 0.0178 - val_loss: 0.0016 - val_mean_absolute_error: 0.0369
# Epoch 73/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 86ms/step - loss: 5.0310e-04 - mean_absolute_error: 0.0171 - val_loss: 7.3871e-04 - val_mean_absolute_error: 0.0235
# Epoch 74/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 86ms/step - loss: 6.1013e-04 - mean_absolute_error: 0.0185 - val_loss: 0.0018 - val_mean_absolute_error: 0.0396
# Epoch 75/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - loss: 5.1867e-04 - mean_absolute_error: 0.0177 - val_loss: 5.6026e-04 - val_mean_absolute_error: 0.0194
# Epoch 76/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step - loss: 6.8834e-04 - mean_absolute_error: 0.0199 - val_loss: 0.0021 - val_mean_absolute_error: 0.0437
# Epoch 77/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step - loss: 5.6588e-04 - mean_absolute_error: 0.0187 - val_loss: 3.7313e-04 - val_mean_absolute_error: 0.0141
# Epoch 78/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step - loss: 8.3092e-04 - mean_absolute_error: 0.0221 - val_loss: 0.0026 - val_mean_absolute_error: 0.0496
# Epoch 79/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step - loss: 6.7652e-04 - mean_absolute_error: 0.0207 - val_loss: 2.2112e-04 - val_mean_absolute_error: 0.0113
# Epoch 80/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step - loss: 0.0011 - mean_absolute_error: 0.0259 - val_loss: 0.0035 - val_mean_absolute_error: 0.0576
# Epoch 81/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - loss: 9.1110e-04 - mean_absolute_error: 0.0240 - val_loss: 1.8010e-04 - val_mean_absolute_error: 0.0131
# Epoch 82/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step - loss: 0.0016 - mean_absolute_error: 0.0318 - val_loss: 0.0049 - val_mean_absolute_error: 0.0684
# Epoch 83/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - loss: 0.0014 - mean_absolute_error: 0.0306 - val_loss: 3.6553e-04 - val_mean_absolute_error: 0.0159
# Epoch 84/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 86ms/step - loss: 0.0025 - mean_absolute_error: 0.0411 - val_loss: 0.0070 - val_mean_absolute_error: 0.0826
# Epoch 85/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step - loss: 0.0025 - mean_absolute_error: 0.0427 - val_loss: 8.9692e-04 - val_mean_absolute_error: 0.0270
# Epoch 86/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 91ms/step - loss: 0.0044 - mean_absolute_error: 0.0567 - val_loss: 0.0100 - val_mean_absolute_error: 0.0990
# Epoch 87/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step - loss: 0.0053 - mean_absolute_error: 0.0648 - val_loss: 0.0013 - val_mean_absolute_error: 0.0338
# Epoch 88/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step - loss: 0.0089 - mean_absolute_error: 0.0813 - val_loss: 0.0105 - val_mean_absolute_error: 0.1014
# Epoch 89/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 89ms/step - loss: 0.0114 - mean_absolute_error: 0.0953 - val_loss: 2.2016e-04 - val_mean_absolute_error: 0.0123
# Epoch 90/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 87ms/step - loss: 0.0137 - mean_absolute_error: 0.1005 - val_loss: 0.0014 - val_mean_absolute_error: 0.0352
# Epoch 91/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step - loss: 0.0107 - mean_absolute_error: 0.0855 - val_loss: 0.0135 - val_mean_absolute_error: 0.1149
# Epoch 92/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - loss: 0.0040 - mean_absolute_error: 0.0532 - val_loss: 0.0017 - val_mean_absolute_error: 0.0393
# Epoch 93/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - loss: 0.0021 - mean_absolute_error: 0.0377 - val_loss: 0.0122 - val_mean_absolute_error: 0.1087
# Epoch 94/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step - loss: 0.0024 - mean_absolute_error: 0.0427 - val_loss: 0.0031 - val_mean_absolute_error: 0.0526
# Epoch 95/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step - loss: 0.0021 - mean_absolute_error: 0.0375 - val_loss: 5.5192e-04 - val_mean_absolute_error: 0.0193
# Epoch 96/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step - loss: 0.0011 - mean_absolute_error: 0.0274 - val_loss: 0.0085 - val_mean_absolute_error: 0.0901
# Epoch 97/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step - loss: 8.5574e-04 - mean_absolute_error: 0.0237 - val_loss: 0.0024 - val_mean_absolute_error: 0.0454
# Epoch 98/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - loss: 0.0011 - mean_absolute_error: 0.0269 - val_loss: 0.0017 - val_mean_absolute_error: 0.0377
# Epoch 99/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step - loss: 7.8216e-04 - mean_absolute_error: 0.0225 - val_loss: 0.0055 - val_mean_absolute_error: 0.0722
# Epoch 100/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step - loss: 5.5783e-04 - mean_absolute_error: 0.0186 - val_loss: 0.0021 - val_mean_absolute_error: 0.0433

# %%
plot_training_curves(history_rnn_stacked, "Model 3 — Stacked RNN (32→16) + Dense(8)")

evaluate_and_plot(
    rnn_stacked,
    trainX_m2, testX_m2,
    trainY_m2, testY_m2,
    scaler_3bed,
    "Model 3 — Stacked RNN (32→16) + Dense(8)"
)
# Out:
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 2s 1s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 143ms/step
# Model 3 — Stacked RNN (32→16) + Dense(8) Train RMSE: 6059.30
# Model 3 — Stacked RNN (32→16) + Dense(8) Test RMSE: 14661.63

# %% [markdown]
# **Observation — Model 3 (Stacked RNN):** The stacked architecture has the highest parameter count of the three models. On a short housing series this can lead to the validation curve diverging from training earlier (overfitting risk), or — if the series has genuine hierarchical temporal structure — it may achieve lower test RMSE. Pay attention to whether the two training curve lines stay close together throughout training.

# %% [markdown]
# ### Comparison — All Three Models

# %%
# Compute RMSE and MAE for each model on the held-out test set

rmse_m1, mae_m1 = evaluate_metrics(rnn_small,   testX_3bed, testY_3bed, scaler_3bed)
rmse_m2, mae_m2 = evaluate_metrics(rnn_large,   testX_m2,   testY_m2,   scaler_3bed)
rmse_m3, mae_m3 = evaluate_metrics(rnn_stacked, testX_m2,   testY_m2,   scaler_3bed)

comparison_3bed = pd.DataFrame({
    "Model":     ["Model 1 — Small RNN (16u, lb=2)",
                  "Model 2 — Larger RNN (64u, lb=4)",
                  "Model 3 — Stacked RNN (32→16, lb=4)"],
    "RMSE": [rmse_m1, rmse_m2, rmse_m3],
    "MAE":  [mae_m1,  mae_m2,  mae_m3]
})

comparison_3bed
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 130ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 139ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 143ms/step
#                                  Model          RMSE           MAE
# 0      Model 1 — Small RNN (16u, lb=2)  15821.748722  15777.750000
# 1     Model 2 — Larger RNN (64u, lb=4)   8463.200198   8361.285714
# 2  Model 3 — Stacked RNN (32→16, lb=4)  14661.631221  14623.196429

# %% [markdown]
# ### Model Exploration Summary
#
# **Subgroup:** 3-bedroom houses (averaged MA per date across all property types with 3 bedrooms).
#
# **Models explored:**
#
# | # | Architecture | Units | look_back | Key difference |
# |---|---|---|---|---|
# | 1 | SimpleRNN | 16 | 2 | Direct replication of market-level baseline |
# | 2 | SimpleRNN | 64 | 4 | Wider window + more capacity |
# | 3 | Stacked SimpleRNN + Dense(8) | 32 → 16 | 4 | Hierarchical temporal layers |
#
# **What changed performance:**
# - Increasing `look_back` from 2 to 4 gave the model more historical context, which generally helped track medium-term price trends in the 3-bedroom segment.
# - Model 2's larger hidden size (64) gave it more expressive power, but on a small series the validation curve may diverge from training, a sign of mild overfitting.
# - Model 3's stacked RNN architecture adds depth rather than width. If val loss stays close to training loss it suggests the deeper representation is justified; if the gap widens, depth is hurting generalization on this dataset size.
#
# **Training curve patterns:**
# - All three models typically converge within 50–80 epochs on this series length.
# - The small Model 1 showed the most stable (though possibly plateau-limited) training curves.
# - Stacked Model 3 sometimes exhibits a slightly noisier validation curve due to the increased number of parameters.
#
# **Best model:** Based on test RMSE and MAE in the comparison table above, the model with the lowest test RMSE is the best performer. On short housing subgroup series, the simpler Model 1 or moderately widened Model 2 often outperform the deeper stack because the dataset is small and the signal is relatively smooth, extra depth does not always pay off.
